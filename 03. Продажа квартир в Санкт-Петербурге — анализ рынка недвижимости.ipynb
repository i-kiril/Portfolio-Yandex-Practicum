# %% [markdown]
# # Исследование объявлений о продаже квартир

# %% [markdown]
# <h1>Содержание<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Изучение-данных-из-файла" data-toc-modified-id="Изучение-данных-из-файла-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Изучение данных из файла</a></span><ul class="toc-item"><li><span><a href="#Вывод" data-toc-modified-id="Вывод-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Вывод</a></span></li></ul></li><li><span><a href="#Предобработка-данных" data-toc-modified-id="Предобработка-данных-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Предобработка данных</a></span><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#last_price-преобразуем-в-int." data-toc-modified-id="last_price-преобразуем-в-int.-2.0.1"><span class="toc-item-num">2.0.1&nbsp;&nbsp;</span>last_price преобразуем в int.</a></span></li><li><span><a href="#Вывод:-переводим-в-целые-числа,-рубли." data-toc-modified-id="Вывод:-переводим-в-целые-числа,-рубли.-2.0.2"><span class="toc-item-num">2.0.2&nbsp;&nbsp;</span>Вывод: переводим в целые числа, рубли.</a></span></li><li><span><a href="#floors_total-преобразуем-в-int." data-toc-modified-id="floors_total-преобразуем-в-int.-2.0.3"><span class="toc-item-num">2.0.3&nbsp;&nbsp;</span>floors_total преобразуем в int.</a></span></li><li><span><a href="#Вывод-floors_total:-этажность-измеряется-в-целых-этажах." data-toc-modified-id="Вывод-floors_total:-этажность-измеряется-в-целых-этажах.-2.0.4"><span class="toc-item-num">2.0.4&nbsp;&nbsp;</span>Вывод floors_total: этажность измеряется в целых этажах.</a></span></li><li><span><a href="#Переименуем-столбец-cityCenters_nearest-в-city_centers_nearest." data-toc-modified-id="Переименуем-столбец-cityCenters_nearest-в-city_centers_nearest.-2.0.5"><span class="toc-item-num">2.0.5&nbsp;&nbsp;</span>Переименуем столбец cityCenters_nearest в city_centers_nearest.</a></span></li><li><span><a href="#Преобразуем-дату-до-удобной-формы-G-M-D." data-toc-modified-id="Преобразуем-дату-до-удобной-формы-G-M-D.-2.0.6"><span class="toc-item-num">2.0.6&nbsp;&nbsp;</span>Преобразуем дату до удобной формы G-M-D.</a></span></li><li><span><a href="#В-is_apartment,-studio-и-open_plan-типами-данных-bool,-исследуем." data-toc-modified-id="В-is_apartment,-studio-и-open_plan-типами-данных-bool,-исследуем.-2.0.7"><span class="toc-item-num">2.0.7&nbsp;&nbsp;</span>В is_apartment, studio и open_plan типами данных bool, исследуем.</a></span></li><li><span><a href="#is_apartment-исследуем." data-toc-modified-id="is_apartment-исследуем.-2.0.8"><span class="toc-item-num">2.0.8&nbsp;&nbsp;</span>is_apartment исследуем.</a></span></li><li><span><a href="#Вывод-is_apartment:" data-toc-modified-id="Вывод-is_apartment:-2.0.9"><span class="toc-item-num">2.0.9&nbsp;&nbsp;</span>Вывод is_apartment:</a></span></li><li><span><a href="#ceiling_height-проверим-на-на-аномалии-и-пропуски." data-toc-modified-id="ceiling_height-проверим-на-на-аномалии-и-пропуски.-2.0.10"><span class="toc-item-num">2.0.10&nbsp;&nbsp;</span>ceiling_height проверим на на аномалии и пропуски.</a></span></li><li><span><a href="#Вывод-ceiling_height:" data-toc-modified-id="Вывод-ceiling_height:-2.0.11"><span class="toc-item-num">2.0.11&nbsp;&nbsp;</span>Вывод ceiling_height:</a></span></li><li><span><a href="#living_area-исследуем-на-пропуски-и-аномалии." data-toc-modified-id="living_area-исследуем-на-пропуски-и-аномалии.-2.0.12"><span class="toc-item-num">2.0.12&nbsp;&nbsp;</span>living_area исследуем на пропуски и аномалии.</a></span></li><li><span><a href="#Вывод-living_area:" data-toc-modified-id="Вывод-living_area:-2.0.13"><span class="toc-item-num">2.0.13&nbsp;&nbsp;</span>Вывод living_area:</a></span></li><li><span><a href="#kitchen_area-исследуем-пропуски." data-toc-modified-id="kitchen_area-исследуем-пропуски.-2.0.14"><span class="toc-item-num">2.0.14&nbsp;&nbsp;</span>kitchen_area исследуем пропуски.</a></span></li><li><span><a href="#Вывод-kitchen_area:" data-toc-modified-id="Вывод-kitchen_area:-2.0.15"><span class="toc-item-num">2.0.15&nbsp;&nbsp;</span>Вывод kitchen_area:</a></span></li><li><span><a href="#balcony-исследуем-пропуски." data-toc-modified-id="balcony-исследуем-пропуски.-2.0.16"><span class="toc-item-num">2.0.16&nbsp;&nbsp;</span>balcony исследуем пропуски.</a></span></li><li><span><a href="#Вывод-balcony:" data-toc-modified-id="Вывод-balcony:-2.0.17"><span class="toc-item-num">2.0.17&nbsp;&nbsp;</span>Вывод balcony:</a></span></li><li><span><a href="#airports_nearest-исследуем-на-уникальные-значения-и-пропуски." data-toc-modified-id="airports_nearest-исследуем-на-уникальные-значения-и-пропуски.-2.0.18"><span class="toc-item-num">2.0.18&nbsp;&nbsp;</span>airports_nearest исследуем на уникальные значения и пропуски.</a></span></li><li><span><a href="#Вывод-airports_nearest:" data-toc-modified-id="Вывод-airports_nearest:-2.0.19"><span class="toc-item-num">2.0.19&nbsp;&nbsp;</span>Вывод airports_nearest:</a></span></li><li><span><a href="#Вывод-city_centers_nearest:" data-toc-modified-id="Вывод-city_centers_nearest:-2.0.20"><span class="toc-item-num">2.0.20&nbsp;&nbsp;</span>Вывод city_centers_nearest:</a></span></li><li><span><a href="#Вывод-parks_nearest:" data-toc-modified-id="Вывод-parks_nearest:-2.0.21"><span class="toc-item-num">2.0.21&nbsp;&nbsp;</span>Вывод parks_nearest:</a></span></li><li><span><a href="#Вывод-ponds_nearest:" data-toc-modified-id="Вывод-ponds_nearest:-2.0.22"><span class="toc-item-num">2.0.22&nbsp;&nbsp;</span>Вывод ponds_nearest:</a></span></li><li><span><a href="#parks_around3000-исследуем-на-уникальные-значения-и-пропуски." data-toc-modified-id="parks_around3000-исследуем-на-уникальные-значения-и-пропуски.-2.0.23"><span class="toc-item-num">2.0.23&nbsp;&nbsp;</span>parks_around3000 исследуем на уникальные значения и пропуски.</a></span></li><li><span><a href="#ponds_around3000-исследуем-на-уникальные-значения-и-пропуски." data-toc-modified-id="ponds_around3000-исследуем-на-уникальные-значения-и-пропуски.-2.0.24"><span class="toc-item-num">2.0.24&nbsp;&nbsp;</span>ponds_around3000 исследуем на уникальные значения и пропуски.</a></span></li><li><span><a href="#Вывод-parks_around3000-и-ponds_around3000:" data-toc-modified-id="Вывод-parks_around3000-и-ponds_around3000:-2.0.25"><span class="toc-item-num">2.0.25&nbsp;&nbsp;</span>Вывод parks_around3000 и ponds_around3000:</a></span></li><li><span><a href="#days_exposition-исследуем-на-аномалии-и-пропуски." data-toc-modified-id="days_exposition-исследуем-на-аномалии-и-пропуски.-2.0.26"><span class="toc-item-num">2.0.26&nbsp;&nbsp;</span>days_exposition исследуем на аномалии и пропуски.</a></span></li><li><span><a href="#Вывод-days_exposition:" data-toc-modified-id="Вывод-days_exposition:-2.0.27"><span class="toc-item-num">2.0.27&nbsp;&nbsp;</span>Вывод days_exposition:</a></span></li></ul></li><li><span><a href="#Вывод-Предобработка-данных." data-toc-modified-id="Вывод-Предобработка-данных.-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Вывод Предобработка данных.</a></span></li></ul></li><li><span><a href="#Расчёты-и-добавление-результатов-в-таблицу" data-toc-modified-id="Расчёты-и-добавление-результатов-в-таблицу-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Расчёты и добавление результатов в таблицу</a></span><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#Добавляем-в-df-цену-квадрантного-метра." data-toc-modified-id="Добавляем-в-df-цену-квадрантного-метра.-3.0.1"><span class="toc-item-num">3.0.1&nbsp;&nbsp;</span>Добавляем в df цену квадрантного метра.</a></span></li><li><span><a href="#Добавим-день-недели,-месяц-и-год-публикации-объявления." data-toc-modified-id="Добавим-день-недели,-месяц-и-год-публикации-объявления.-3.0.2"><span class="toc-item-num">3.0.2&nbsp;&nbsp;</span>Добавим день недели, месяц и год публикации объявления.</a></span></li><li><span><a href="#Вывод-день-недели:" data-toc-modified-id="Вывод-день-недели:-3.0.3"><span class="toc-item-num">3.0.3&nbsp;&nbsp;</span>Вывод день недели:</a></span></li><li><span><a href="#Добавляем-категорию-этажниости-квартир:-варианты-—-первый,-последний,-другой." data-toc-modified-id="Добавляем-категорию-этажниости-квартир:-варианты-—-первый,-последний,-другой.-3.0.4"><span class="toc-item-num">3.0.4&nbsp;&nbsp;</span>Добавляем категорию этажниости квартир: варианты — первый, последний, другой.</a></span></li><li><span><a href="#Вывод:-меньше-всего-продаются-крайние-этажи." data-toc-modified-id="Вывод:-меньше-всего-продаются-крайние-этажи.-3.0.5"><span class="toc-item-num">3.0.5&nbsp;&nbsp;</span>Вывод: меньше всего продаются крайние этажи.</a></span></li><li><span><a href="#Соотношение-жилой-и-общей-площади" data-toc-modified-id="Соотношение-жилой-и-общей-площади-3.0.6"><span class="toc-item-num">3.0.6&nbsp;&nbsp;</span>Соотношение жилой и общей площади</a></span></li><li><span><a href="#Cоотношение-площади-кухни-к-общей." data-toc-modified-id="Cоотношение-площади-кухни-к-общей.-3.0.7"><span class="toc-item-num">3.0.7&nbsp;&nbsp;</span>Cоотношение площади кухни к общей.</a></span></li></ul></li><li><span><a href="#Вывод-расчетов-и-результатов:" data-toc-modified-id="Вывод-расчетов-и-результатов:-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Вывод расчетов и результатов:</a></span></li></ul></li><li><span><a href="#Исследовательский-анализ-данных" data-toc-modified-id="Исследовательский-анализ-данных-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Исследовательский анализ данных</a></span><ul class="toc-item"><li><span><a href="#Исследование-следующих-параметров:-площадь,-цена,-число-комнат,-высота-потолков." data-toc-modified-id="Исследование-следующих-параметров:-площадь,-цена,-число-комнат,-высота-потолков.-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Исследование следующих параметров: площадь, цена, число комнат, высота потолков.</a></span><ul class="toc-item"><li><span><a href="#total_area-отображаем-диаграмму-размаха," data-toc-modified-id="total_area-отображаем-диаграмму-размаха,-4.1.1"><span class="toc-item-num">4.1.1&nbsp;&nbsp;</span>total_area отображаем диаграмму размаха,</a></span></li><li><span><a href="#total_area-отображение-гистограммы," data-toc-modified-id="total_area-отображение-гистограммы,-4.1.2"><span class="toc-item-num">4.1.2&nbsp;&nbsp;</span>total_area отображение гистограммы,</a></span></li><li><span><a href="#Вывод-total_area:" data-toc-modified-id="Вывод-total_area:-4.1.3"><span class="toc-item-num">4.1.3&nbsp;&nbsp;</span>Вывод total_area:</a></span></li><li><span><a href="#last_price-отображение-гистограммы," data-toc-modified-id="last_price-отображение-гистограммы,-4.1.4"><span class="toc-item-num">4.1.4&nbsp;&nbsp;</span>last_price отображение гистограммы,</a></span></li><li><span><a href="#Вывод-last_price:" data-toc-modified-id="Вывод-last_price:-4.1.5"><span class="toc-item-num">4.1.5&nbsp;&nbsp;</span>Вывод last_price:</a></span></li><li><span><a href="#rooms-отображение-гистограммы," data-toc-modified-id="rooms-отображение-гистограммы,-4.1.6"><span class="toc-item-num">4.1.6&nbsp;&nbsp;</span>rooms отображение гистограммы,</a></span></li><li><span><a href="#Вывод-rooms:" data-toc-modified-id="Вывод-rooms:-4.1.7"><span class="toc-item-num">4.1.7&nbsp;&nbsp;</span>Вывод rooms:</a></span></li><li><span><a href="#ceiling_height-отображение-гистограммы," data-toc-modified-id="ceiling_height-отображение-гистограммы,-4.1.8"><span class="toc-item-num">4.1.8&nbsp;&nbsp;</span>ceiling_height отображение гистограммы,</a></span></li><li><span><a href="#Вывод-ceiling_height:" data-toc-modified-id="Вывод-ceiling_height:-4.1.9"><span class="toc-item-num">4.1.9&nbsp;&nbsp;</span>Вывод ceiling_height:</a></span></li><li><span><a href="#Вывод-по-гистограммам:" data-toc-modified-id="Вывод-по-гистограммам:-4.1.10"><span class="toc-item-num">4.1.10&nbsp;&nbsp;</span>Вывод по гистограммам:</a></span></li></ul></li><li><span><a href="#Время-продажи-квартир." data-toc-modified-id="Время-продажи-квартир.-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>Время продажи квартир.</a></span><ul class="toc-item"><li><span><a href="#числовой-анализ" data-toc-modified-id="числовой-анализ-4.2.1"><span class="toc-item-num">4.2.1&nbsp;&nbsp;</span>числовой анализ</a></span></li><li><span><a href="#days_exposition-отображение-гистограммы," data-toc-modified-id="days_exposition-отображение-гистограммы,-4.2.2"><span class="toc-item-num">4.2.2&nbsp;&nbsp;</span>days_exposition отображение гистограммы,</a></span></li><li><span><a href="#Вывод-days_exposition:" data-toc-modified-id="Вывод-days_exposition:-4.2.3"><span class="toc-item-num">4.2.3&nbsp;&nbsp;</span>Вывод days_exposition:</a></span></li><li><span><a href="#Редкие-и-выбивающиеся-значения." data-toc-modified-id="Редкие-и-выбивающиеся-значения.-4.2.4"><span class="toc-item-num">4.2.4&nbsp;&nbsp;</span>Редкие и выбивающиеся значения.</a></span></li><li><span><a href="#Вывод-редкие-и-выбивающиеся-значения:" data-toc-modified-id="Вывод-редкие-и-выбивающиеся-значения:-4.2.5"><span class="toc-item-num">4.2.5&nbsp;&nbsp;</span>Вывод редкие и выбивающиеся значения:</a></span></li><li><span><a href="#Факторы-влияют-на-стоимость-квартиры." data-toc-modified-id="Факторы-влияют-на-стоимость-квартиры.-4.2.6"><span class="toc-item-num">4.2.6&nbsp;&nbsp;</span>Факторы влияют на стоимость квартиры.</a></span></li><li><span><a href="#Вывод-по-факторам-влияют-на-стоимость-квартиры:" data-toc-modified-id="Вывод-по-факторам-влияют-на-стоимость-квартиры:-4.2.7"><span class="toc-item-num">4.2.7&nbsp;&nbsp;</span>Вывод по факторам влияют на стоимость квартиры:</a></span></li><li><span><a href="#10-населённых-пунктов-с-наибольшим-числом-объявлений." data-toc-modified-id="10-населённых-пунктов-с-наибольшим-числом-объявлений.-4.2.8"><span class="toc-item-num">4.2.8&nbsp;&nbsp;</span>10 населённых пунктов с наибольшим числом объявлений.</a></span></li><li><span><a href="#Населённый-пункт-с-самой-высокой-ценой-квартиры." data-toc-modified-id="Населённый-пункт-с-самой-высокой-ценой-квартиры.-4.2.9"><span class="toc-item-num">4.2.9&nbsp;&nbsp;</span>Населённый пункт с самой высокой ценой квартиры.</a></span></li><li><span><a href="#Населённый-пункт-с-самой-низкой-ценой-квартиры." data-toc-modified-id="Населённый-пункт-с-самой-низкой-ценой-квартиры.-4.2.10"><span class="toc-item-num">4.2.10&nbsp;&nbsp;</span>Населённый пункт с самой низкой ценой квартиры.</a></span></li><li><span><a href="#Вывод-10-населённых-пунктов:" data-toc-modified-id="Вывод-10-населённых-пунктов:-4.2.11"><span class="toc-item-num">4.2.11&nbsp;&nbsp;</span>Вывод 10 населённых пунктов:</a></span></li><li><span><a href="#Центральная-область-Санкт-Петербурга." data-toc-modified-id="Центральная-область-Санкт-Петербурга.-4.2.12"><span class="toc-item-num">4.2.12&nbsp;&nbsp;</span>Центральная область Санкт-Петербурга.</a></span></li><li><span><a href="#Вывод-центральной-зоны:" data-toc-modified-id="Вывод-центральной-зоны:-4.2.13"><span class="toc-item-num">4.2.13&nbsp;&nbsp;</span>Вывод центральной зоны:</a></span></li><li><span><a href="#Сегмент-квартир-в-центре." data-toc-modified-id="Сегмент-квартир-в-центре.-4.2.14"><span class="toc-item-num">4.2.14&nbsp;&nbsp;</span>Сегмент квартир в центре.</a></span></li><li><span><a href="#Вывод-время-продажи-квартир:" data-toc-modified-id="Вывод-время-продажи-квартир:-4.2.15"><span class="toc-item-num">4.2.15&nbsp;&nbsp;</span>Вывод время продажи квартир:</a></span></li></ul></li></ul></li><li><span><a href="#Общий-вывод" data-toc-modified-id="Общий-вывод-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Общий вывод</a></span><ul class="toc-item"><li><span><a href="#На-основе-анализа-полученных-данных," data-toc-modified-id="На-основе-анализа-полученных-данных,-5.1"><span class="toc-item-num">5.1&nbsp;&nbsp;</span>На основе анализа полученных данных,</a></span></li><li><span><a href="#Нормальное-распределение-по-площади" data-toc-modified-id="Нормальное-распределение-по-площади-5.2"><span class="toc-item-num">5.2&nbsp;&nbsp;</span>Нормальное распределение по площади</a></span></li><li><span><a href="#Нормальное-распределение-по-стоимости" data-toc-modified-id="Нормальное-распределение-по-стоимости-5.3"><span class="toc-item-num">5.3&nbsp;&nbsp;</span>Нормальное распределение по стоимости</a></span></li><li><span><a href="#Нормальное-распределение-количества-комнат" data-toc-modified-id="Нормальное-распределение-количества-комнат-5.4"><span class="toc-item-num">5.4&nbsp;&nbsp;</span>Нормальное распределение количества комнат</a></span></li><li><span><a href="#Нормальное-распределение-количества" data-toc-modified-id="Нормальное-распределение-количества-5.5"><span class="toc-item-num">5.5&nbsp;&nbsp;</span>Нормальное распределение количества</a></span></li><li><span><a href="#days_exposition:" data-toc-modified-id="days_exposition:-5.6"><span class="toc-item-num">5.6&nbsp;&nbsp;</span>days_exposition:</a></span></li><li><span><a href="#Зависимость-цены-от-площади-квартиры." data-toc-modified-id="Зависимость-цены-от-площади-квартиры.-5.7"><span class="toc-item-num">5.7&nbsp;&nbsp;</span>Зависимость цены от площади квартиры.</a></span></li><li><span><a href="#Зависимость-цены-от-числа-комнат." data-toc-modified-id="Зависимость-цены-от-числа-комнат.-5.8"><span class="toc-item-num">5.8&nbsp;&nbsp;</span>Зависимость цены от числа комнат.</a></span></li><li><span><a href="#Зависимость-цены-по-удалённости-от-центра." data-toc-modified-id="Зависимость-цены-по-удалённости-от-центра.-5.9"><span class="toc-item-num">5.9&nbsp;&nbsp;</span>Зависимость цены по удалённости от центра.</a></span></li><li><span><a href="#Зависимость-цены-от-этажа." data-toc-modified-id="Зависимость-цены-от-этажа.-5.10"><span class="toc-item-num">5.10&nbsp;&nbsp;</span>Зависимость цены от этажа.</a></span></li><li><span><a href="#Зависимость-цены-от-даты-размещения-по-годам." data-toc-modified-id="Зависимость-цены-от-даты-размещения-по-годам.-5.11"><span class="toc-item-num">5.11&nbsp;&nbsp;</span>Зависимость цены от даты размещения по годам.</a></span></li><li><span><a href="#Зависимость-цены-от-даты-размещения-по-месяцам." data-toc-modified-id="Зависимость-цены-от-даты-размещения-по-месяцам.-5.12"><span class="toc-item-num">5.12&nbsp;&nbsp;</span>Зависимость цены от даты размещения по месяцам.</a></span></li><li><span><a href="#Зависимость-цены-от-даты-размещения-по-дням-недели." data-toc-modified-id="Зависимость-цены-от-даты-размещения-по-дням-недели.-5.13"><span class="toc-item-num">5.13&nbsp;&nbsp;</span>Зависимость цены от даты размещения по дням недели.</a></span></li><li><span><a href="#Вывод-10-населённых-пунктов:" data-toc-modified-id="Вывод-10-населённых-пунктов:-5.14"><span class="toc-item-num">5.14&nbsp;&nbsp;</span>Вывод 10 населённых пунктов:</a></span></li><li><span><a href="#Центральная-область-Санкт-Петербурга." data-toc-modified-id="Центральная-область-Санкт-Петербурга.-5.15"><span class="toc-item-num">5.15&nbsp;&nbsp;</span>Центральная область Санкт-Петербурга.</a></span></li><li><span><a href="#Сегмент-квартир-в-центре." data-toc-modified-id="Сегмент-квартир-в-центре.-5.16"><span class="toc-item-num">5.16&nbsp;&nbsp;</span>Сегмент квартир в центре.</a></span></li><li><span><a href="#Количество-квартир,-выставленных-на-продажу:" data-toc-modified-id="Количество-квартир,-выставленных-на-продажу:-5.17"><span class="toc-item-num">5.17&nbsp;&nbsp;</span>Количество квартир, выставленных на продажу:</a></span></li><li><span><a href="#Количество-и-доля-квартир-по-комнатам." data-toc-modified-id="Количество-и-доля-квартир-по-комнатам.-5.18"><span class="toc-item-num">5.18&nbsp;&nbsp;</span>Количество и доля квартир по комнатам.</a></span></li><li><span><a href="#Высота-потолков-находится-в-пределах-одного-показателя-2.65-метра." data-toc-modified-id="Высота-потолков-находится-в-пределах-одного-показателя-2.65-метра.-5.19"><span class="toc-item-num">5.19&nbsp;&nbsp;</span>Высота потолков находится в пределах одного показателя 2.65 метра.</a></span></li><li><span><a href="#Зависимость-цены-от-этажа." data-toc-modified-id="Зависимость-цены-от-этажа.-5.20"><span class="toc-item-num">5.20&nbsp;&nbsp;</span>Зависимость цены от этажа.</a></span></li><li><span><a href="#Зависимость-цены-по-удаленности" data-toc-modified-id="Зависимость-цены-по-удаленности-5.21"><span class="toc-item-num">5.21&nbsp;&nbsp;</span>Зависимость цены по удаленности</a></span></li><li><span><a href="#Зависимость-цены-от-даты-размещения-объявления." data-toc-modified-id="Зависимость-цены-от-даты-размещения-объявления.-5.22"><span class="toc-item-num">5.22&nbsp;&nbsp;</span>Зависимость цены от даты размещения объявления.</a></span></li></ul></li><li><span><a href="#Чек-лист-готовности-проекта" data-toc-modified-id="Чек-лист-готовности-проекта-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Чек-лист готовности проекта</a></span></li></ul></div>

# %% [markdown]
# # Описание проекта
#
# В вашем распоряжении данные сервиса Яндекc Недвижимость — архив объявлений о продаже квартир в Санкт-Петербурге и соседних населённых пунктах за несколько лет. Нужно научиться определять рыночную стоимость объектов недвижимости. Ваша задача — установить параметры. Это позволит построить автоматизированную систему: она отследит аномалии и мошенническую деятельность.
#
# По каждой квартире на продажу доступны два вида данных. Первые вписаны пользователем, вторые получены автоматически на основе картографических данных. Например, расстояние до центра, аэропорта, ближайшего парка и водоёма.

# %% [markdown]
# ## Изучение данных из файла

# %%
import pandas as pd #загрузка библиотек
import numpy as np
from datetime import datetime
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('/datasets/real_estate_data.csv') # читаем файл.
print(df.head())
# Out:
#   total_images\tlast_price\ttotal_area\tfirst_day_exposition\trooms\tceiling_height\tfloors_total\tliving_area\tfloor\tis_apartment\tstudio\topen_plan\tkitchen_area\tbalcony\tlocality_name\tairports_nearest\tcityCenters_nearest\tparks_around3000\tparks_nearest\tponds_around3000\tponds_nearest\tdays_exposition
# 0  20\t13000000.0\t108.0\t2019-03-07T00:00:00\t3\...
# 1  7\t3350000.0\t40.4\t2018-12-04T00:00:00\t1\t\t...
# 2  10\t5196000.0\t56.0\t2015-08-20T00:00:00\t2\t\...
# 3  0\t64900000.0\t159.0\t2015-07-24T00:00:00\t3\t...
# 4  2\t10000000.0\t100.0\t2018-06-19T00:00:00\t2\t...

# %% [markdown]
# Определяем разделитель. Читаем файл с разделителем колонок и дробей.

# %%
df = pd.read_csv('/datasets/real_estate_data.csv', sep='\t', decimal='.') 
pd.set_option('display.max_columns', 30) # более 20 колонок используем метод set_option.
df # выводим начало и конец таблици.
# Out:
#        total_images  last_price  total_area first_day_exposition  rooms  \
# 0                20  13000000.0      108.00  2019-03-07T00:00:00      3
# 1                 7   3350000.0       40.40  2018-12-04T00:00:00      1
# 2                10   5196000.0       56.00  2015-08-20T00:00:00      2
# 3                 0  64900000.0      159.00  2015-07-24T00:00:00      3
# 4                 2  10000000.0      100.00  2018-06-19T00:00:00      2
# ...             ...         ...         ...                  ...    ...
# 23694             9   9700000.0      133.81  2017-03-21T00:00:00      3
# 23695            14   3100000.0       59.00  2018-01-15T00:00:00      3
# 23696            18   2500000.0       56.70  2018-02-11T00:00:00      2
# 23697            13  11475000.0       76.75  2017-03-28T00:00:00      2
# 23698             4   1350000.0       32.30  2017-07-21T00:00:00      1
#
#        ceiling_height  floors_total  living_area  floor is_apartment  studio  \
# ...

# %% [markdown]
# В целом все нормально, много пропусков, посмотрим общую информацию.

# %%
df.describe()
# Out:
#        total_images    last_price    total_area         rooms  ceiling_height  \
# count  23699.000000  2.369900e+04  23699.000000  23699.000000    14504.000000
# mean       9.858475  6.541549e+06     60.348651      2.070636        2.771499
# std        5.682529  1.088701e+07     35.654083      1.078405        1.261056
# min        0.000000  1.219000e+04     12.000000      0.000000        1.000000
# 25%        6.000000  3.400000e+06     40.000000      1.000000        2.520000
# 50%        9.000000  4.650000e+06     52.000000      2.000000        2.650000
# 75%       14.000000  6.800000e+06     69.900000      3.000000        2.800000
# max       50.000000  7.630000e+08    900.000000     19.000000      100.000000
#
#        floors_total   living_area         floor  kitchen_area       balcony  \
# count  23613.000000  21796.000000  23699.000000  21421.000000  12180.000000
# mean      10.673824     34.457852      5.892358     10.569807      1.150082
# ...

# %% [markdown]
# Есть отклонения по площади 900/409/112 кв.м., но возможно, количеству комнат 19 и высоте потолков 100 м.

# %%
df.info() # Получаем информацию о данных.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23699 entries, 0 to 23698
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   total_images          23699 non-null  int64
#  1   last_price            23699 non-null  float64
#  2   total_area            23699 non-null  float64
#  3   first_day_exposition  23699 non-null  object
#  4   rooms                 23699 non-null  int64
#  5   ceiling_height        14504 non-null  float64
#  6   floors_total          23613 non-null  float64
#  7   living_area           21796 non-null  float64
#  8   floor                 23699 non-null  int64
#  9   is_apartment          2775 non-null   object
#  10  studio                23699 non-null  bool
#  11  open_plan             23699 non-null  bool
#  12  kitchen_area          21421 non-null  float64
#  13  balcony               12180 non-null  float64
#  14  locality_name         23650 non-null  object
# ...

# %% [markdown]
# Посчитаем суммарное значение и долю пропусков.

# %%
df.isna().sum() # Суммарное значение пропусков.
# Out:
# total_images                0
# last_price                  0
# total_area                  0
# first_day_exposition        0
# rooms                       0
# ceiling_height           9195
# floors_total               86
# living_area              1903
# floor                       0
# is_apartment            20924
# studio                      0
# open_plan                   0
# kitchen_area             2278
# balcony                 11519
# locality_name              49
# airports_nearest         5542
# cityCenters_nearest      5519
# parks_around3000         5518
# parks_nearest           15620
# ponds_around3000         5518
# ponds_nearest           14589
# days_exposition          3181
# dtype: int64

# %%
df.isna().mean() * 100 # Доля пропусков в % от общего количества строк.
# Out:
# total_images             0.000000
# last_price               0.000000
# total_area               0.000000
# first_day_exposition     0.000000
# rooms                    0.000000
# ceiling_height          38.799105
# floors_total             0.362885
# living_area              8.029875
# floor                    0.000000
# is_apartment            88.290645
# studio                   0.000000
# open_plan                0.000000
# kitchen_area             9.612220
# balcony                 48.605426
# locality_name            0.206760
# airports_nearest        23.384953
# cityCenters_nearest     23.287902
# parks_around3000        23.283683
# parks_nearest           65.909954
# ponds_around3000        23.283683
# ponds_nearest           61.559559
# days_exposition         13.422507
# dtype: float64

# %% [markdown]
# ### Вывод

# %% [markdown]
# В таблице 22 солонки, 23699 строк, имеются пропуски данных, которые составляют значительную часть информации.
# 2 колонок с типами данных bool, 14 - flot, 3 - int и 3 колонок - object:
#
# 1. В cityCenters_nearest есть нарушения стиля, строчные буквы сочетаются с прописными.
# 2. В first_day_exposition привести к формату G-M-D.
# 3. В is_apartment, studio и open_plan типами данных bool, исследовать пропуски.
# 4. В floors_total, balcony, parks_around3000, ponds_around3000 и days_exposition
# тип данных float, заменить на целые числа.
# 5. В airports_nearest, cityCenters_nearest, parks_nearest, ponds_nearest
# перевести в километры (целые числа).
# 6. Проанализировать аномалии с количеством комнат и высотой потолков.
# 7. Удалить строки с незначительными долями пропусков floors_total (0.362885) и locality_name (0.206760).

# %% [markdown]
# ## Предобработка данных

# %% [markdown]
# Удалим незначительную долю информации с пропусками floors_total (0.362885) и locality_name (0.206760),
# выяснить этажность дома и населенный пункт нет возможности.

# %%
df.dropna(subset=['locality_name', 'floors_total'], inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 23565 entries, 0 to 23698
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   total_images          23565 non-null  int64
#  1   last_price            23565 non-null  float64
#  2   total_area            23565 non-null  float64
#  3   first_day_exposition  23565 non-null  object
#  4   rooms                 23565 non-null  int64
#  5   ceiling_height        14481 non-null  float64
#  6   floors_total          23565 non-null  float64
#  7   living_area           21700 non-null  float64
#  8   floor                 23565 non-null  int64
#  9   is_apartment          2760 non-null   object
#  10  studio                23565 non-null  bool
#  11  open_plan             23565 non-null  bool
#  12  kitchen_area          21343 non-null  float64
#  13  balcony               12090 non-null  float64
#  14  locality_name         23565 non-null  object
# ...

# %% [markdown]
# #### last_price преобразуем в int.

# %%
df['last_price'] = df['last_price'].astype('int')

# %%
df.head()
# Out:
#    total_images  last_price  total_area first_day_exposition  rooms  \
# 0            20    13000000       108.0  2019-03-07T00:00:00      3
# 1             7     3350000        40.4  2018-12-04T00:00:00      1
# 2            10     5196000        56.0  2015-08-20T00:00:00      2
# 3             0    64900000       159.0  2015-07-24T00:00:00      3
# 4             2    10000000       100.0  2018-06-19T00:00:00      2
#
#    ceiling_height  floors_total  living_area  floor is_apartment  studio  \
# 0            2.70          16.0         51.0      8          NaN   False
# 1             NaN          11.0         18.6      1          NaN   False
# 2             NaN           5.0         34.3      4          NaN   False
# 3             NaN          14.0          NaN      9          NaN   False
# 4            3.03          14.0         32.0     13          NaN   False
#
#    open_plan  kitchen_area  balcony    locality_name  airports_nearest  \
# ...

# %% [markdown]
# #### Вывод: переводим в целые числа, рубли.

# %% [markdown]
# #### floors_total преобразуем в int.

# %%
df['floors_total'] = df['floors_total'].astype('int')

# %%
df.head()
# Out:
#    total_images  last_price  total_area first_day_exposition  rooms  \
# 0            20    13000000       108.0  2019-03-07T00:00:00      3
# 1             7     3350000        40.4  2018-12-04T00:00:00      1
# 2            10     5196000        56.0  2015-08-20T00:00:00      2
# 3             0    64900000       159.0  2015-07-24T00:00:00      3
# 4             2    10000000       100.0  2018-06-19T00:00:00      2
#
#    ceiling_height  floors_total  living_area  floor is_apartment  studio  \
# 0            2.70            16         51.0      8          NaN   False
# 1             NaN            11         18.6      1          NaN   False
# 2             NaN             5         34.3      4          NaN   False
# 3             NaN            14          NaN      9          NaN   False
# 4            3.03            14         32.0     13          NaN   False
#
#    open_plan  kitchen_area  balcony    locality_name  airports_nearest  \
# ...

# %% [markdown]
# #### Вывод floors_total: этажность измеряется в целых этажах.

# %% [markdown]
# #### Переименуем столбец cityCenters_nearest в city_centers_nearest.

# %%
df.rename(columns = {'cityCenters_nearest':'city_centers_nearest'}, inplace=True)
df.columns # проверка результатов - перечень названий столбцов
# Out:
# Index(['total_images', 'last_price', 'total_area', 'first_day_exposition',
#        'rooms', 'ceiling_height', 'floors_total', 'living_area', 'floor',
#        'is_apartment', 'studio', 'open_plan', 'kitchen_area', 'balcony',
#        'locality_name', 'airports_nearest', 'city_centers_nearest',
#        'parks_around3000', 'parks_nearest', 'ponds_around3000',
#        'ponds_nearest', 'days_exposition'],
#       dtype='object')

# %% [markdown]
# #### Преобразуем дату до удобной формы G-M-D.

# %%
df['first_day_exposition'] = pd.to_datetime(df['first_day_exposition'])
df.head()
# Out:
#    total_images  last_price  total_area first_day_exposition  rooms  \
# 0            20    13000000       108.0           2019-03-07      3
# 1             7     3350000        40.4           2018-12-04      1
# 2            10     5196000        56.0           2015-08-20      2
# 3             0    64900000       159.0           2015-07-24      3
# 4             2    10000000       100.0           2018-06-19      2
#
#    ceiling_height  floors_total  living_area  floor is_apartment  studio  \
# 0            2.70            16         51.0      8          NaN   False
# 1             NaN            11         18.6      1          NaN   False
# 2             NaN             5         34.3      4          NaN   False
# 3             NaN            14          NaN      9          NaN   False
# 4            3.03            14         32.0     13          NaN   False
#
#    open_plan  kitchen_area  balcony    locality_name  airports_nearest  \
# ...

# %% [markdown]
# #### В is_apartment, studio и open_plan типами данных bool, исследуем.

# %% [markdown]
# Методом isna() найдём все строки с пропусками в столбце is_apartment и просмотрим первые пять.

# %%
df[df['is_apartment'].isna()].head()
# Out:
#    total_images  last_price  total_area first_day_exposition  rooms  \
# 0            20    13000000       108.0           2019-03-07      3
# 1             7     3350000        40.4           2018-12-04      1
# 2            10     5196000        56.0           2015-08-20      2
# 3             0    64900000       159.0           2015-07-24      3
# 4             2    10000000       100.0           2018-06-19      2
#
#    ceiling_height  floors_total  living_area  floor is_apartment  studio  \
# 0            2.70            16         51.0      8          NaN   False
# 1             NaN            11         18.6      1          NaN   False
# 2             NaN             5         34.3      4          NaN   False
# 3             NaN            14          NaN      9          NaN   False
# 4            3.03            14         32.0     13          NaN   False
#
#    open_plan  kitchen_area  balcony    locality_name  airports_nearest  \
# ...

# %% [markdown]
# ####  is_apartment исследуем.
# Есть гипотеза, что пропуски возникли на ранних датах, когда небыли апартаментов.
# Сгруппируем по возрастанию.

# %%
df.sort_values(['first_day_exposition','is_apartment'],ascending=True).groupby('first_day_exposition').head(3)
# Out:
#        total_images  last_price  total_area first_day_exposition  rooms  \
# 3486              2    14500000       97.40           2014-11-27      2
# 8393             10     8037000       56.20           2014-11-27      1
# 15427             2     3550000       34.00           2014-11-27      1
# 19352             4     5500000       53.40           2014-11-29      2
# 12875             1     4421650       41.53           2014-12-04      1
# ...             ...         ...         ...                  ...    ...
# 1468              2     8500000       87.00           2019-05-02      4
# 1958              7     2750000       31.40           2019-05-02      1
# 9217              7     4300000       35.70           2019-05-03      1
# 12003            10      950000       37.10           2019-05-03      1
# 14424             1    14500000       91.40           2019-05-03      3
#
#        ceiling_height  floors_total  living_area  floor is_apartment  studio  \
# ...

# %% [markdown]
# Проверим взаимосвязь между is_apartment, studio и open_plan.

# %%
df.groupby(['is_apartment', 'studio', 'open_plan']).size().to_frame('count').reset_index()
# Out:
#    is_apartment  studio  open_plan  count
# 0         False   False      False   2688
# 1         False   False       True      7
# 2         False    True      False     15
# 3          True   False      False     50

# %% [markdown]
# Взаимосвязь на аномалии отсутствует.

# %% [markdown]
# Сгруппируем по значению False, True и возрастающей дате.

# %%
pd.pivot_table(df,
               index=['is_apartment', 'first_day_exposition'],
               values=['studio'],
               aggfunc=[len])
# Out:
#                                      len
#                                   studio
# is_apartment first_day_exposition
# False        2014-11-27                4
#              2014-12-09                8
#              2014-12-10                2
#              2014-12-14                3
#              2014-12-15                1
# ...                                  ...
# True         2019-02-12                1
#              2019-03-22                1
#              2019-03-25                1
#              2019-04-20                2
#              2019-04-26                1
#
# [1004 rows x 1 columns]

# %%
df.groupby(['is_apartment', 'first_day_exposition']).size().to_frame('count').reset_index()
# Out:
#       is_apartment first_day_exposition  count
# 0            False           2014-11-27      4
# 1            False           2014-12-09      8
# 2            False           2014-12-10      2
# 3            False           2014-12-14      3
# 4            False           2014-12-15      1
# ...            ...                  ...    ...
# 999           True           2019-02-12      1
# 1000          True           2019-03-22      1
# 1001          True           2019-03-25      1
# 1002          True           2019-04-20      2
# 1003          True           2019-04-26      1
#
# [1004 rows x 3 columns]

# %% [markdown]
# #### Вывод is_apartment:
# По ранним датам продажи можно судить, что is_apartment со значением NaN это не апартаменты,
# заполним значением False.

# %%
df['is_apartment'].fillna(False, inplace=True)

# %%
df['is_apartment'].value_counts() # проверим количество строк по значению.
# Out:
# False    23515
# True        50
# Name: is_apartment, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 23565 entries, 0 to 23698
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   total_images          23565 non-null  int64
#  1   last_price            23565 non-null  int64
#  2   total_area            23565 non-null  float64
#  3   first_day_exposition  23565 non-null  datetime64[ns]
#  4   rooms                 23565 non-null  int64
#  5   ceiling_height        14481 non-null  float64
#  6   floors_total          23565 non-null  int64
#  7   living_area           21700 non-null  float64
#  8   floor                 23565 non-null  int64
#  9   is_apartment          23565 non-null  bool
#  10  studio                23565 non-null  bool
#  11  open_plan             23565 non-null  bool
#  12  kitchen_area          21343 non-null  float64
#  13  balcony               12090 non-null  float64
#  14  locality_name         23565 non-null  object
# ...

# %% [markdown]
# Все строки в is_apartment заполнены.

# %% [markdown]
# #### ceiling_height проверим на на аномалии и пропуски.

# %%
df['ceiling_height'].value_counts()
# Out:
# 2.50     3515
# 2.60     1645
# 2.70     1571
# 3.00     1108
# 2.80      988
#          ...
# 4.25        1
# 3.39        1
# 3.93        1
# 10.30       1
# 4.65        1
# Name: ceiling_height, Length: 183, dtype: int64

# %% [markdown]
# Есть аномальные значения, но их мало, на статистику не повлияют, пропуски заменим медианным значением,
# так как среднее будет отличаться из за выбросов.

# %%
df['ceiling_height'].fillna(df['ceiling_height'].median(), inplace=True)

# %%
df.head() # проверяем.
# Out:
#    total_images  last_price  total_area first_day_exposition  rooms  \
# 0            20    13000000       108.0           2019-03-07      3
# 1             7     3350000        40.4           2018-12-04      1
# 2            10     5196000        56.0           2015-08-20      2
# 3             0    64900000       159.0           2015-07-24      3
# 4             2    10000000       100.0           2018-06-19      2
#
#    ceiling_height  floors_total  living_area  floor  is_apartment  studio  \
# 0            2.70            16         51.0      8         False   False
# 1            2.65            11         18.6      1         False   False
# 2            2.65             5         34.3      4         False   False
# 3            2.65            14          NaN      9         False   False
# 4            3.03            14         32.0     13         False   False
#
#    open_plan  kitchen_area  balcony    locality_name  airports_nearest  \
# ...

# %%
df.info() # сморим info.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 23565 entries, 0 to 23698
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   total_images          23565 non-null  int64
#  1   last_price            23565 non-null  int64
#  2   total_area            23565 non-null  float64
#  3   first_day_exposition  23565 non-null  datetime64[ns]
#  4   rooms                 23565 non-null  int64
#  5   ceiling_height        23565 non-null  float64
#  6   floors_total          23565 non-null  int64
#  7   living_area           21700 non-null  float64
#  8   floor                 23565 non-null  int64
#  9   is_apartment          23565 non-null  bool
#  10  studio                23565 non-null  bool
#  11  open_plan             23565 non-null  bool
#  12  kitchen_area          21343 non-null  float64
#  13  balcony               12090 non-null  float64
#  14  locality_name         23565 non-null  object
# ...

# %% [markdown]
# #### Вывод ceiling_height:
# значения заполнены.

# %% [markdown]
# #### living_area исследуем на пропуски и аномалии.

# %%
df['living_area'].value_counts()
# Out:
# 18.00    882
# 17.00    673
# 30.00    598
# 16.00    483
# 20.00    479
#         ...
# 43.81      1
# 54.43      1
# 86.10      1
# 99.70      1
# 16.74      1
# Name: living_area, Length: 1769, dtype: int64

# %% [markdown]
# 1769 пропущенных значений, выведем строки и проанализируем на взаимосвязь со студиями.

# %%
df[df['living_area'].isna()].head()
# Out:
#     total_images  last_price  total_area first_day_exposition  rooms  \
# 3              0    64900000       159.0           2015-07-24      3
# 7              5     7915000        71.6           2019-04-18      2
# 30            12     2200000        32.8           2018-02-19      1
# 37            10     1990000        45.8           2017-10-28      2
# 44            13     5350000        40.0           2018-11-18      1
#
#     ceiling_height  floors_total  living_area  floor  is_apartment  studio  \
# 3             2.65            14          NaN      9         False   False
# 7             2.65            24          NaN     22         False   False
# 30            2.65             9          NaN      2         False   False
# 37            2.50             5          NaN      1         False   False
# 44            2.65            22          NaN      3         False   False
#
#     open_plan  kitchen_area  balcony                        locality_name  \
# ...

# %%
df['living_area'].fillna(0, inplace=True) # заполняем пустые значения.

# %%
df.info() # проверим.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 23565 entries, 0 to 23698
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   total_images          23565 non-null  int64
#  1   last_price            23565 non-null  int64
#  2   total_area            23565 non-null  float64
#  3   first_day_exposition  23565 non-null  datetime64[ns]
#  4   rooms                 23565 non-null  int64
#  5   ceiling_height        23565 non-null  float64
#  6   floors_total          23565 non-null  int64
#  7   living_area           23565 non-null  float64
#  8   floor                 23565 non-null  int64
#  9   is_apartment          23565 non-null  bool
#  10  studio                23565 non-null  bool
#  11  open_plan             23565 non-null  bool
#  12  kitchen_area          21343 non-null  float64
#  13  balcony               12090 non-null  float64
#  14  locality_name         23565 non-null  object
# ...

# %% [markdown]
# #### Вывод living_area:
# Взаимосвязи нет и это не студии, площадь кухни тоже отсутствует поэтому для удобства заполнили пустые значения на '0'.

# %% [markdown]
# #### kitchen_area исследуем пропуски.

# %% [markdown]
# Выведем строки с пропусками и посмотрим.

# %%
df[df['kitchen_area'].isna()].head()
# Out:
#     total_images  last_price  total_area first_day_exposition  rooms  \
# 3              0    64900000       159.0           2015-07-24      3
# 30            12     2200000        32.8           2018-02-19      1
# 37            10     1990000        45.8           2017-10-28      2
# 44            13     5350000        40.0           2018-11-18      1
# 59            15     6300000        46.5           2017-03-06      1
#
#     ceiling_height  floors_total  living_area  floor  is_apartment  studio  \
# 3             2.65            14          0.0      9         False   False
# 30            2.65             9          0.0      2         False   False
# 37            2.50             5          0.0      1         False   False
# 44            2.65            22          0.0      3         False   False
# 59            2.65            13          0.0     13         False   False
#
#     open_plan  kitchen_area  balcony                        locality_name  \
# ...

# %%
df.groupby(['kitchen_area', 'studio']).size().to_frame('count').reset_index() # взаимосвязь со студией.
# Out:
#      kitchen_area  studio  count
# 0            1.30   False      1
# 1            2.00   False      7
# 2            2.30   False      1
# 3            2.40   False      1
# 4            2.89   False      1
# ..            ...     ...    ...
# 958         93.20   False      1
# 959        100.00   False      1
# 960        100.70   False      1
# 961        107.00   False      1
# 962        112.00   False      1
#
# [963 rows x 3 columns]

# %%
df['kitchen_area'].fillna(0, inplace=True) # заполняем пустые значения.

# %%
df.info() # проверяем.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 23565 entries, 0 to 23698
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   total_images          23565 non-null  int64
#  1   last_price            23565 non-null  int64
#  2   total_area            23565 non-null  float64
#  3   first_day_exposition  23565 non-null  datetime64[ns]
#  4   rooms                 23565 non-null  int64
#  5   ceiling_height        23565 non-null  float64
#  6   floors_total          23565 non-null  int64
#  7   living_area           23565 non-null  float64
#  8   floor                 23565 non-null  int64
#  9   is_apartment          23565 non-null  bool
#  10  studio                23565 non-null  bool
#  11  open_plan             23565 non-null  bool
#  12  kitchen_area          23565 non-null  float64
#  13  balcony               12090 non-null  float64
#  14  locality_name         23565 non-null  object
# ...

# %% [markdown]
# #### Вывод kitchen_area:
# Взаимосвязь со студией отсутствует, заменили на '0'.

# %% [markdown]
# #### balcony исследуем пропуски.

# %%
df['balcony'].value_counts()
# Out:
# 1.0    4187
# 0.0    3680
# 2.0    3656
# 5.0     304
# 4.0     182
# 3.0      81
# Name: balcony, dtype: int64

# %%
df['balcony'].fillna(0, inplace=True) # заполняем пустые значения.

# %%
df['balcony'].isnull().sum() # проверяем.
# Out:
# 0

# %% [markdown]
# Переводим float в целые числа int.

# %%
df['balcony'] = df['balcony'].astype('int')

# %%
df.head()
# Out:
#    total_images  last_price  total_area first_day_exposition  rooms  \
# 0            20    13000000       108.0           2019-03-07      3
# 1             7     3350000        40.4           2018-12-04      1
# 2            10     5196000        56.0           2015-08-20      2
# 3             0    64900000       159.0           2015-07-24      3
# 4             2    10000000       100.0           2018-06-19      2
#
#    ceiling_height  floors_total  living_area  floor  is_apartment  studio  \
# 0            2.70            16         51.0      8         False   False
# 1            2.65            11         18.6      1         False   False
# 2            2.65             5         34.3      4         False   False
# 3            2.65            14          0.0      9         False   False
# 4            3.03            14         32.0     13         False   False
#
#    open_plan  kitchen_area  balcony    locality_name  airports_nearest  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 23565 entries, 0 to 23698
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   total_images          23565 non-null  int64
#  1   last_price            23565 non-null  int64
#  2   total_area            23565 non-null  float64
#  3   first_day_exposition  23565 non-null  datetime64[ns]
#  4   rooms                 23565 non-null  int64
#  5   ceiling_height        23565 non-null  float64
#  6   floors_total          23565 non-null  int64
#  7   living_area           23565 non-null  float64
#  8   floor                 23565 non-null  int64
#  9   is_apartment          23565 non-null  bool
#  10  studio                23565 non-null  bool
#  11  open_plan             23565 non-null  bool
#  12  kitchen_area          23565 non-null  float64
#  13  balcony               23565 non-null  int64
#  14  locality_name         23565 non-null  object
# ...

# %% [markdown]
# #### Вывод balcony:
# По балконам аналогичная ситуация, заменили пропуски на '0' и перевели в целые числа.

# %% [markdown]
# #### airports_nearest исследуем на уникальные значения и пропуски.

# %%
df['airports_nearest'].value_counts()
# Out:
# 37434.0    61
# 21928.0    32
# 39946.0    30
# 44870.0    30
# 37407.0    27
#            ..
# 42695.0     1
# 53478.0     1
# 20335.0     1
# 33699.0     1
# 20875.0     1
# Name: airports_nearest, Length: 8251, dtype: int64

# %%
df['airports_nearest'].isnull().sum() # считаем пропуски.
# Out:
# 5524

# %%
df[df['airports_nearest'].isna()] # выводим первые и последние строки с пропусками.
# Out:
#        total_images  last_price  total_area first_day_exposition  rooms  \
# 5                10     2890000       30.40           2018-09-10      1
# 8                20     2900000       33.16           2018-05-23      1
# 12               10     3890000       54.00           2016-06-30      2
# 22               20     5000000       58.00           2017-04-24      2
# 30               12     2200000       32.80           2018-02-19      1
# ...             ...         ...         ...                  ...    ...
# 23683            16     2100000       62.80           2018-09-18      4
# 23692             2     1350000       30.00           2017-07-07      1
# 23695            14     3100000       59.00           2018-01-15      3
# 23696            18     2500000       56.70           2018-02-11      2
# 23698             4     1350000       32.30           2017-07-21      1
#
#        ceiling_height  floors_total  living_area  floor  is_apartment  studio  \
# ...

# %% [markdown]
# #### Вывод airports_nearest:
# В основном расстояние не указано из за отдаленности населенных пунктов, заполнить мы их не сможем, оставляем как есть.

# %% [markdown]
# #### Вывод city_centers_nearest:
# Аналогичная ситуация наблюдается с пропусками расстояния до центра города,
# из-за отдаленности населенных пунктов, заполнить мы их не сможем, оставляем как есть.

# %% [markdown]
# #### Вывод parks_nearest:
# Расстояние не указано из-за отдаленности населенных пунктов, заполнить мы их не сможем, оставляем как есть.

# %% [markdown]
# #### Вывод ponds_nearest:
# Расстояние не указано из-за отдаленности населенных пунктов, заполнить мы их не сможем, оставляем как есть.
#
# **В населенных пунктах как правило подобными показатели не учитывают.**

# %% [markdown]
# #### parks_around3000 исследуем на уникальные значения и пропуски.

# %%
df['parks_around3000'].value_counts()
# Out:
# 0.0    10039
# 1.0     5647
# 2.0     1736
# 3.0      643
# Name: parks_around3000, dtype: int64

# %%
df['parks_around3000'].isnull().sum() # считаем пропуски.
# Out:
# 5500

# %%
df[df['parks_around3000'].isna()].head() # выводим строки с пропусками.
# Out:
#     total_images  last_price  total_area first_day_exposition  rooms  \
# 5             10     2890000       30.40           2018-09-10      1
# 8             20     2900000       33.16           2018-05-23      1
# 12            10     3890000       54.00           2016-06-30      2
# 22            20     5000000       58.00           2017-04-24      2
# 30            12     2200000       32.80           2018-02-19      1
#
#     ceiling_height  floors_total  living_area  floor  is_apartment  studio  \
# 5             2.65            12        14.40      5         False   False
# 8             2.65            27        15.43     26         False   False
# 12            2.65             5        30.00      5         False   False
# 22            2.75            25        30.00     15         False   False
# 30            2.65             9         0.00      2         False   False
#
#     open_plan  kitchen_area  balcony              locality_name  \
# ...

# %% [markdown]
# В основном все пропуски связаны с локацией, заполним пропуски нулевыми значениями,
# взаимосвязь с датой и ponds_around3000 не выявлено.

# %%
df['parks_around3000'].fillna(0, inplace=True) # заполняем пустые значения.

# %%
df['parks_around3000'].isnull().sum() # считаем пропуски.
# Out:
# 0

# %% [markdown]
# Переводим в целые числа.

# %%
df['parks_around3000'] = df['parks_around3000'].astype('int')

# %% [markdown]
# #### ponds_around3000 исследуем на уникальные значения и пропуски.

# %%
df['ponds_around3000'].value_counts()
# Out:
# 0.0    9029
# 1.0    5662
# 2.0    1883
# 3.0    1491
# Name: ponds_around3000, dtype: int64

# %%
df['ponds_around3000'].isnull().sum() # считаем пропуски.
# Out:
# 5500

# %% [markdown]
# Проверим взаимосвязь по locality_name.

# %%
df.groupby(['locality_name', 'ponds_around3000']).size().to_frame('count').reset_index() # взаимосвязь локации.
# Out:
#          locality_name  ponds_around3000  count
# 0          Зеленогорск               0.0      6
# 1          Зеленогорск               1.0     15
# 2          Зеленогорск               2.0      3
# 3              Колпино               0.0    147
# 4              Колпино               1.0     88
# ..                 ...               ...    ...
# 57    посёлок Стрельна               2.0      4
# 58    посёлок Стрельна               3.0      9
# 59  посёлок Усть-Ижора               0.0      2
# 60      посёлок Шушары               0.0    284
# 61      посёлок Шушары               1.0    152
#
# [62 rows x 3 columns]

# %%
df['ponds_around3000'].fillna(0, inplace=True) # заполняем пустые значения.

# %%
df['ponds_around3000'].isnull().sum() # считаем пропуски.
# Out:
# 0

# %%
df['ponds_around3000'] = df['ponds_around3000'].astype('int') # переводим в int.

# %% [markdown]
# #### Вывод parks_around3000 и ponds_around3000:
# Пропуски в значениях связанны с локации в населенных пунктах, логично их заменить на ноль.

# %% [markdown]
# #### days_exposition исследуем на аномалии и пропуски.

# %%
df['days_exposition'].value_counts()
# Out:
# 45.0      879
# 60.0      538
# 7.0       234
# 30.0      208
# 90.0      200
#          ...
# 969.0       1
# 1147.0      1
# 1.0         1
# 1148.0      1
# 1174.0      1
# Name: days_exposition, Length: 1139, dtype: int64

# %%
df['days_exposition'].isnull().sum() # считаем пропуски.
# Out:
# 3171

# %% [markdown]
# Методом isna() найдём все строки с пропусками в столбце days_exposition и просмотрим.

# %%
df[df['days_exposition'].isna()]#.head() # строки с пропусками.
# Out:
#        total_images  last_price  total_area first_day_exposition  rooms  \
# 0                20    13000000      108.00           2019-03-07      3
# 7                 5     7915000       71.60           2019-04-18      2
# 44               13     5350000       40.00           2018-11-18      1
# 45               17     5200000       50.60           2018-12-02      2
# 46               17     6600000       52.10           2019-01-31      2
# ...             ...         ...         ...                  ...    ...
# 23684            20    21400000      145.00           2018-11-02      4
# 23685            15     2490000       31.00           2019-01-24      1
# 23694             9     9700000      133.81           2017-03-21      3
# 23696            18     2500000       56.70           2018-02-11      2
# 23698             4     1350000       32.30           2017-07-21      1
#
#        ceiling_height  floors_total  living_area  floor  is_apartment  studio  \
# ...

# %%
df.groupby(['first_day_exposition', 'days_exposition']).size().to_frame('count').reset_index() # взаимосвязь с датой.
# Out:
#       first_day_exposition  days_exposition  count
# 0               2014-11-27            573.0      1
# 1               2014-11-27            574.0      1
# 2               2014-11-27            583.0      1
# 3               2014-11-27            586.0      1
# 4               2014-11-27            606.0      1
# ...                    ...              ...    ...
# 17652           2019-04-26              4.0      1
# 17653           2019-04-26              5.0      1
# 17654           2019-04-29              2.0      1
# 17655           2019-04-30              2.0      2
# 17656           2019-05-01              1.0      1
#
# [17657 rows x 3 columns]

# %% [markdown]
# Взаимосвязь first_day_exposition и days_exposition отсутствует и по другим параметрам аномалий нет.
# Можно воспользоваться двумя способами:
# Заполнить пропуски '1', поскольку квартиры выставлялись, то и выставлены были хотя бы 1 день;
# Заменить NaN yна '0' и учесть в дальнейшем этот факт отсутствия данных.
# Но мы оставим все пропуски как есть.

# %% [markdown]
# #### Вывод days_exposition:
# Нет взаимосвязи между датой экспозицией и другими параметрами, пропуски оставляем,
# при дальнейшем анализе данные переведем в int.

# %% [markdown]
# -   Если рассматривать распределение пропусков относительно года выставления на продажу, можно заметить, что большая часть пропущенных значений - в 2019 году. Больше половины объектов, выставленных на продажу в 2019 году не имеет рассчитанного "времени продажи квартиры". Также высокая доля пропусков, хотя и меньшая - в 2018 году. Получается, чем свежей объявление - тем выше вероятность пропуска в этой колонке.
#
# Скорее всего, пропуск в этой колонке означает, что объект не продан и объявление не закрыто. Поэтому заполнять пропуски в этом столбце не надо - они не случайные и существенно влияют на статистику.

# %% [markdown]
# **Выодим итоговую таблицу.**

# %%
df
# Out:
#        total_images  last_price  total_area first_day_exposition  rooms  \
# 0                20    13000000      108.00           2019-03-07      3
# 1                 7     3350000       40.40           2018-12-04      1
# 2                10     5196000       56.00           2015-08-20      2
# 3                 0    64900000      159.00           2015-07-24      3
# 4                 2    10000000      100.00           2018-06-19      2
# ...             ...         ...         ...                  ...    ...
# 23694             9     9700000      133.81           2017-03-21      3
# 23695            14     3100000       59.00           2018-01-15      3
# 23696            18     2500000       56.70           2018-02-11      2
# 23697            13    11475000       76.75           2017-03-28      2
# 23698             4     1350000       32.30           2017-07-21      1
#
#        ceiling_height  floors_total  living_area  floor  is_apartment  studio  \
# ...

# %%
df.describe()
# Out:
#        total_images    last_price    total_area         rooms  ceiling_height  \
# count  23565.000000  2.356500e+04  23565.000000  23565.000000    23565.000000
# mean       9.878421  6.540058e+06     60.322824      2.070656        2.724530
# std        5.681156  1.091093e+07     35.657060      1.078591        0.991026
# min        0.000000  1.219000e+04     12.000000      0.000000        1.000000
# 25%        6.000000  3.400000e+06     40.000000      1.000000        2.600000
# 50%        9.000000  4.646000e+06     52.000000      2.000000        2.650000
# 75%       14.000000  6.790000e+06     69.700000      3.000000        2.700000
# max       50.000000  7.630000e+08    900.000000     19.000000      100.000000
#
#        floors_total   living_area         floor  kitchen_area       balcony  \
# count  23565.000000  23565.000000  23565.000000  23565.000000  23565.000000
# mean      10.675875     31.727971      5.878124      9.565173      0.593677
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 23565 entries, 0 to 23698
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   total_images          23565 non-null  int64
#  1   last_price            23565 non-null  int64
#  2   total_area            23565 non-null  float64
#  3   first_day_exposition  23565 non-null  datetime64[ns]
#  4   rooms                 23565 non-null  int64
#  5   ceiling_height        23565 non-null  float64
#  6   floors_total          23565 non-null  int64
#  7   living_area           23565 non-null  float64
#  8   floor                 23565 non-null  int64
#  9   is_apartment          23565 non-null  bool
#  10  studio                23565 non-null  bool
#  11  open_plan             23565 non-null  bool
#  12  kitchen_area          23565 non-null  float64
#  13  balcony               23565 non-null  int64
#  14  locality_name         23565 non-null  object
# ...

# %% [markdown]
# ### Вывод Предобработка данных.
#
#  - Удалили незначительную долю информации с пропусками floors_total (0.362885) и locality_name (0.206760),
# выяснить этажность дома без конкретного адреса и населенный пункт нет возможности.
#  - last_price преобразуем в int, цена лучше воспринимается в целых числах. Копейки здесь не указывают.
#  - Названия колонок привели в соответствие с хорошим стилем.
#  - Преобразовали дату даты в datetime, в удобную форму для восприятия.
#  - По ранним датам продажи можно судить, что is_apartment со значением NaN это не апартаменты,
# заполнили значением False.
#  - ceiling_height есть аномальные значения, но их мало, на статистику не повлияют,
#  пропуски заменили медианным значением, так как среднее будет отличаться из-за выбросов.
#  - living_area: взаимосвязи со студиями нет и это не студии, площадь кухни тоже отсутствует поэтому для удобства    заполнили пустые значения на '0'.
#  - kitchen_area: взаимосвязь со студией отсутствует, пропуски заменили на '0'.
#  - balcony: иследовали балконы, заменли пропуски на '0' и перевели в целые числа.
#  Дробного количества балконов не может быть.
#  - airports_nearest: в основном расстояние не указано из-за отдаленности населенных пунктов,
#  заполнить мы их не сможем, оставляем как есть.
#  - city_centers_nearest: аналогичная ситуация наблюдается с пропусками расстояние до центра города,
#  из за отдаленности населенных пунктов, заполнить мы их не сможем, оставляем как есть.
#  - parks_nearest: расстояние не указано из за отдаленности населенных пунктов,
#  заполнить мы их не сможем, оставляем как есть.
#  - ponds_nearest: растояние не указано из за отдаленности населенных пунктов,
#  заполнить мы их не сможем, оставляем как есть.
# **В населенных пунктах как правило подобными показатели не учитывают.**
#  - parks_around3000 и ponds_around3000: пропуски в значениях связанны с локацией в населенных пунктах, логично их заменить на ноль. Изменен тип данных на int, на целые числа. Дробного количества паркое не может быть.
#  - days_exposition: нет взаимосвязи между датой и экспозицией, оставляем пропуски.
#
#
#  **Полностью не удалось избавиться от всех пропусков.**

# %% [markdown]
# - Можно еще сэкономить память, изменяя типы данных, дополнительно изменить их у площадей квартир с float64 на float32.

# %% [markdown]
# ## Расчёты и добавление результатов в таблицу

# %% [markdown]
# #### Добавляем в df цену квадрантного метра.

# %%
df['price_m2'] = df['last_price']/df['total_area'] # дабавляем столбец.

# %%
df.head() # проверяем.
# Out:
#    total_images  last_price  total_area first_day_exposition  rooms  \
# 0            20    13000000       108.0           2019-03-07      3
# 1             7     3350000        40.4           2018-12-04      1
# 2            10     5196000        56.0           2015-08-20      2
# 3             0    64900000       159.0           2015-07-24      3
# 4             2    10000000       100.0           2018-06-19      2
#
#    ceiling_height  floors_total  living_area  floor  is_apartment  studio  \
# 0            2.70            16         51.0      8         False   False
# 1            2.65            11         18.6      1         False   False
# 2            2.65             5         34.3      4         False   False
# 3            2.65            14          0.0      9         False   False
# 4            3.03            14         32.0     13         False   False
#
#    open_plan  kitchen_area  balcony    locality_name  airports_nearest  \
# ...

# %% [markdown]
# #### Добавим день недели, месяц и год публикации объявления.

# %%
df['year'] = df['first_day_exposition'].dt.year # год.
df['month'] = df['first_day_exposition'].dt.month # месяц.
df['weekday'] = df['first_day_exposition'].dt.weekday # день недели int (Понедельник — день под номером 0).
df['day_week'] = df['first_day_exposition'].dt.day_name() # день недели.

# %%
df.head()
# Out:
#    total_images  last_price  total_area first_day_exposition  rooms  \
# 0            20    13000000       108.0           2019-03-07      3
# 1             7     3350000        40.4           2018-12-04      1
# 2            10     5196000        56.0           2015-08-20      2
# 3             0    64900000       159.0           2015-07-24      3
# 4             2    10000000       100.0           2018-06-19      2
#
#    ceiling_height  floors_total  living_area  floor  is_apartment  studio  \
# 0            2.70            16         51.0      8         False   False
# 1            2.65            11         18.6      1         False   False
# 2            2.65             5         34.3      4         False   False
# 3            2.65            14          0.0      9         False   False
# 4            3.03            14         32.0     13         False   False
#
#    open_plan  kitchen_area  balcony    locality_name  airports_nearest  \
# ...

# %%
df['day_week'].value_counts() # проверяем.
# Out:
# Thursday     4276
# Tuesday      4163
# Friday       3980
# Wednesday    3948
# Monday       3596
# Saturday     1919
# Sunday       1683
# Name: day_week, dtype: int64

# %% [markdown]
# #### Вывод день недели:
# •	Чаще всего выставляют в продажу в четверг, перед последним рабочим днем и перед выходными,
# это логично, для эффективной продажи.

# %% [markdown]
# #### Добавляем категорию этажниости квартир: варианты — первый, последний, другой.

# %%
# напишем функцию категоризации по этажам, используя метод apply применимо к каждой строке датафрейма через axis = 1.
def floor_category(row):
    floors_total = row['floors_total']
    floor = row['floor']
    if floor == 1:
        return 'первый'
    elif floor == floors_total:
        return 'последний'
    return 'другой'
    
df['floor_category'] = df.apply(floor_category, axis = 1) # категоризуем этажи с помощью функции.

# %%
df.head()
# Out:
#    total_images  last_price  total_area first_day_exposition  rooms  \
# 0            20    13000000       108.0           2019-03-07      3
# 1             7     3350000        40.4           2018-12-04      1
# 2            10     5196000        56.0           2015-08-20      2
# 3             0    64900000       159.0           2015-07-24      3
# 4             2    10000000       100.0           2018-06-19      2
#
#    ceiling_height  floors_total  living_area  floor  is_apartment  studio  \
# 0            2.70            16         51.0      8         False   False
# 1            2.65            11         18.6      1         False   False
# 2            2.65             5         34.3      4         False   False
# 3            2.65            14          0.0      9         False   False
# 4            3.03            14         32.0     13         False   False
#
#    open_plan  kitchen_area  balcony    locality_name  airports_nearest  \
# ...

# %%
df['floor_category'].value_counts() # проверяем.
# Out:
# другой       17326
# последний     3330
# первый        2909
# Name: floor_category, dtype: int64

# %% [markdown]
# #### Вывод: меньше всего продаются крайние этажи.

# %% [markdown]
# #### Соотношение жилой и общей площади

# %%
df['living_area_part'] = df['living_area'] / df['total_area']

# %% [markdown]
# #### Cоотношение площади кухни к общей.

# %%
df['kitchen_area_part'] = df['kitchen_area'] / df['total_area']

# %%
df.head()
# Out:
#    total_images  last_price  total_area first_day_exposition  rooms  \
# 0            20    13000000       108.0           2019-03-07      3
# 1             7     3350000        40.4           2018-12-04      1
# 2            10     5196000        56.0           2015-08-20      2
# 3             0    64900000       159.0           2015-07-24      3
# 4             2    10000000       100.0           2018-06-19      2
#
#    ceiling_height  floors_total  living_area  floor  is_apartment  studio  \
# 0            2.70            16         51.0      8         False   False
# 1            2.65            11         18.6      1         False   False
# 2            2.65             5         34.3      4         False   False
# 3            2.65            14          0.0      9         False   False
# 4            3.03            14         32.0     13         False   False
#
#    open_plan  kitchen_area  balcony    locality_name  airports_nearest  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 23565 entries, 0 to 23698
# Data columns (total 30 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   total_images          23565 non-null  int64
#  1   last_price            23565 non-null  int64
#  2   total_area            23565 non-null  float64
#  3   first_day_exposition  23565 non-null  datetime64[ns]
#  4   rooms                 23565 non-null  int64
#  5   ceiling_height        23565 non-null  float64
#  6   floors_total          23565 non-null  int64
#  7   living_area           23565 non-null  float64
#  8   floor                 23565 non-null  int64
#  9   is_apartment          23565 non-null  bool
#  10  studio                23565 non-null  bool
#  11  open_plan             23565 non-null  bool
#  12  kitchen_area          23565 non-null  float64
#  13  balcony               23565 non-null  int64
#  14  locality_name         23565 non-null  object
# ...

# %% [markdown]
# Округляем полученные значения до двух знаков после запятой.

# %%
list_to_float2 = ['price_m2', 'living_area_part', 'kitchen_area_part']

# %%
for column in list_to_float2:
    df[column] = df[df[column].notnull()][column].round(2)

# %%
df.head()
# Out:
#    total_images  last_price  total_area first_day_exposition  rooms  \
# 0            20    13000000       108.0           2019-03-07      3
# 1             7     3350000        40.4           2018-12-04      1
# 2            10     5196000        56.0           2015-08-20      2
# 3             0    64900000       159.0           2015-07-24      3
# 4             2    10000000       100.0           2018-06-19      2
#
#    ceiling_height  floors_total  living_area  floor  is_apartment  studio  \
# 0            2.70            16         51.0      8         False   False
# 1            2.65            11         18.6      1         False   False
# 2            2.65             5         34.3      4         False   False
# 3            2.65            14          0.0      9         False   False
# 4            3.03            14         32.0     13         False   False
#
#    open_plan  kitchen_area  balcony    locality_name  airports_nearest  \
# ...

# %% [markdown]
# ### Вывод расчетов и результатов:
#
# - Успешно добавлены новые столбцы в датафрейм с расчетами и результатами.
# - Произведена категоризация этажей: первый, последний, другой;
# - Добавим день недели, месяц и год публикации объявления;
# - Округлили значения float до двух знаков после запятой:
#   - price_m2 до руб.коп., необходимость для точного определения стоимости всей площади;
#   - living_area_part, kitchen_area_part необходимо для определения в % выражении.
#
# **С помощью дополнительной колонок можно произвести более точно исследовательский анализ.**

# %% [markdown]
# ## Исследовательский анализ данных

# %% [markdown]
# ### Исследование следующих параметров: площадь, цена, число комнат, высота потолков.

# %%
df[['total_area', 'last_price', 'rooms', 'ceiling_height']].describe()
# Out:
#          total_area    last_price         rooms  ceiling_height
# count  23565.000000  2.356500e+04  23565.000000    23565.000000
# mean      60.322824  6.540058e+06      2.070656        2.724530
# std       35.657060  1.091093e+07      1.078591        0.991026
# min       12.000000  1.219000e+04      0.000000        1.000000
# 25%       40.000000  3.400000e+06      1.000000        2.600000
# 50%       52.000000  4.646000e+06      2.000000        2.650000
# 75%       69.700000  6.790000e+06      3.000000        2.700000
# max      900.000000  7.630000e+08     19.000000      100.000000

# %% [markdown]
# **Предварительный анализ дал следующую информацию:**
#
# - площадь квартиры min - 12, max - 900, std - 35.65 и mean - 60.32 кв.м.;
# - стоимость квартиры min - 1.219000, max - 7.630000, std - 1.091093, mean - 6.540058 млн. руб.;
# - количество комнат от 0 - (студия) до 19, что в полне возможно, std - 1 и std - 2, вполне реально;
# - высота потолков min - 1, std - 0.99 и max - 100 метров аномальны,
#   остальные показатели mean - 2.72 в норме (2.6, 2.65, 2.7).

# %% [markdown]
# #### total_area отображаем диаграмму размаха,
# визуально оцениваем характеристики распределения.

# %%
df.boxplot(column='total_area')
plt.show()

# %% [markdown]
# Для построения гистограммы, критические значения с большими отклонениями можно отбросить.
# Для визуализации нормального распределения можно принять диапазон от 10 до 200 кв.м с числом корзин до 100.

# %% [markdown]
# #### total_area отображение гистограммы,
# с параметрами нормального распределения от 10 до 200 кв.м с числом корзин до 100.

# %%
df['total_area'].hist(bins=100, range=(10, 200))
plt.show()

# %% [markdown]
# #### Вывод total_area:
# Нормальное распределение по площади находится в диапазоне от 25 до 100 кв.м.
# Наибольшее число квартир продается с площадями 30 -45, чуть меньше 45 - 65 и с выше 70 кв.м идут по убывающей.

# %% [markdown]
# #### last_price отображение гистограммы,
# с параметрами нормального распределения от 1.2 млн. до 7.6 млн. руб. с числом корзин до 50.

# %%
df['last_price'].hist(bins=50, range=(1219000, 7630000))
plt.show()

# %% [markdown]
# #### Вывод last_price:
# Нормальное распределение по стоимости находится в диапазоне от 1.2 млн. до 7.6 млн. руб.
# Наибольшее количество продаж по цене в диапазоне от 3 до 5 млн. руб. с пиком 3,5 -3,8 млн. руб.,
# практически в равной степени продаются как меньше 3 млн. так и более 5 млн. руб.,
# гистограмма плавно возрастает и затем плана убывает. Показатели в норме.

# %% [markdown]
# #### rooms отображение гистограммы,
# с параметрами нормального распределения количества комнат от 0 до 8 и числом корзин 15.

# %%
df['rooms'].hist(bins=15, range=(0, 8))
plt.show()

# %% [markdown]
# #### Вывод rooms:
# Нормальное распределение количества комнат находится в диапазоне от 1 до 5.
# Наибольшее число квартир занимают 1 и 2 комнатные квартиры, чуть меньше 3 ком. кв.
# значительно меньше 4 и 5 ком. кв. и далее идут по убывающей с большим количеством комнат.

# %% [markdown]
# #### ceiling_height отображение гистограммы,
# с параметрами нормального распределения по высоте потолков от 2.3 до 3 метра и числом корзин 50.

# %%
df['ceiling_height'].hist(bins=50, range=(2.3, 3))
plt.show()

# %% [markdown]
# #### Вывод ceiling_height:
# Нормальное распределение количества продаваемых квартир по высоте потолков находится в диапазоне от 2.5 до 2.8.
# Основную долю на рынке составляют квартиры с высотой потолка 2.65 м., значительная часть 2.5 м.
# По гистограмме можно отметить стандартизацию потолков по высоте: 2.5, 2.55, 2.6, 2.65, 2.7, 2.75, а также 2.8 м.

# %% [markdown]
# #### Вывод по гистограммам:
# **Все гистограммы показывают нормальное распределение, данным можно доверять.**

# %% [markdown]
# ### Время продажи квартир.

# %%
df[['days_exposition']].describe()
# Out:
#        days_exposition
# count     20394.000000
# mean        180.741395
# std         219.732782
# min           1.000000
# 25%          45.000000
# 50%          95.000000
# 75%         231.000000
# max        1580.000000

# %% [markdown]
# #### числовой анализ
# дал следующую информацию:
#
# - по 20394 данным об экспозиции min - 1, max - 1580, std - 219 и mean - 180 дней.

# %% [markdown]
# #### days_exposition отображение гистограммы,
# с параметрами нормального распределения по дням экспозиции от 1 до 1580 дня и числом корзин 100.

# %%
df['days_exposition'].hist(bins=100, range=(0, 1580))
plt.show()

# %% [markdown]
# Находим среднее значение.

# %%
df['days_exposition'].mean()
# Out:
# 180.7413945278023

# %% [markdown]
# Находим медианну.

# %%
df['days_exposition'].median()
# Out:
# 95.0

# %% [markdown]
# Посмотрим интервал до 95 дней.

# %%
df['days_exposition'].hist(bins=100, range=(0, 95))
plt.show()

# %%
df['days_exposition'].hist(bins=100, range=(0, 60)) # узкий интервал.
plt.show()

# %% [markdown]
# #### Вывод days_exposition:
# Средняя длительность продажи составляет 180 дней;
# Медианное значение 95, является хорошим показателем спокойного рынка недвижимости;
# Наиболее быстрым сроком продажи можно считать до 30 дней;
# Средним до 95 дней;
# Долгим от 95 до 180;
# Очень долгим от 180 дней;
# Свыше одного года можно отнести в категорию не продаваемых, но продаются.
# По гистограмме можно отметить сроки пиковых продаж 7, 30, 45 и 60 дней.
# В целом данные заслуживают доверия.

# %% [markdown]
# #### Редкие и выбивающиеся значения.

# %% [markdown]
# Создаем функцию для подсчёта границ с учетом 1.5 размаха.

# %%
def quartile_range(df, column):
    q1 = df[column].quantile(0.25)
    q3 = df[column].quantile(0.75)
    iqr = q3 - q1
    dfq = df.loc[(df[column] < q3 + 1.5*iqr) & (df[column] > q1 - 1.5*iqr), column]
    return dfq

# %% [markdown]
# Убираем выбивающиеся значения.

# %%
list_features = ['last_price', 'total_area', 'kitchen_area', 'living_area', 'days_exposition', 'ceiling_height', 'rooms']
for col in list_features:
    df[col] = quartile_range(df, col)

# %% [markdown]
# Проверяем.

# %%
df.describe()
# Out:
#        total_images    last_price    total_area         rooms  ceiling_height  \
# count  23565.000000  2.151900e+04  22326.000000  23371.000000    20601.000000
# mean       9.878421  4.837115e+06     54.319704      2.030208        2.631089
# std        5.681156  2.215774e+06     19.331030      0.973563        0.081473
# min        0.000000  1.219000e+04     12.000000      0.000000        2.460000
# 25%        6.000000  3.300000e+06     39.400000      1.000000        2.600000
# 50%        9.000000  4.400000e+06     50.000000      2.000000        2.650000
# 75%       14.000000  6.000000e+06     65.500000      3.000000        2.650000
# max       50.000000  1.186686e+07    114.200000      5.000000        2.850000
#
#        floors_total   living_area         floor  kitchen_area       balcony  \
# count  23565.000000  22750.000000  23565.000000  22329.000000  23565.000000
# mean      10.675875     28.869024      5.878124      8.535411      0.593677
# ...

# %% [markdown]
# #### Вывод редкие и выбивающиеся значения:
# В датафрейме отброшены значения на основе 1.5 размаха, все квартильные показатели уменьшились.
# Значения стали лучше и адекватнее.

# %% [markdown]
# #### Факторы влияют на стоимость квартиры.

# %% [markdown]
# **Зависимость цены от площади квартиры.**

# %%
df.pivot_table(index='total_area', values='last_price').plot(grid=True, style='o', figsize=(15, 5))
plt.show()
df.pivot_table(index='floor', values=['total_area', 'last_price']).corr()
# Out:
#             last_price  total_area
# last_price    1.000000    0.905372
# total_area    0.905372    1.000000

# %% [markdown]
# По мере увеличения площади цена возрастает, а также увеличивается разброс цены.

# %% [markdown]
# **Зависимость цены от числа комнат.**

# %%
df.query('rooms > 0').pivot_table(index='rooms', values='last_price').plot(grid=True, style='o-', figsize=(10, 3))
plt.show()
df.query('rooms > 0').pivot_table(index='floor', values=['rooms', 'last_price']).corr()
# Out:
#             last_price     rooms
# last_price    1.000000  0.537551
# rooms         0.537551  1.000000

# %% [markdown]
# По мере увеличения количества комнат цена возрастает.

# %% [markdown]
# **Зависимость цены от удалённости от центра.**

# %%
df.query('city_centers_nearest > 0').pivot_table(index='city_centers_nearest', values='last_price').plot(grid=True, style='o', figsize=(20, 10))
plt.show()
df.query('city_centers_nearest > 0').pivot_table(index='floor', values=['city_centers_nearest', 'last_price']).corr()
# Out:
#                       city_centers_nearest  last_price
# city_centers_nearest              1.000000    0.702347
# last_price                        0.702347    1.000000

# %% [markdown]
# По мере удаленности от центра цена уменьшается.

# %% [markdown]
# **Зависимость цены от этажа.**

# %%
df.pivot_table(index='floor', values='last_price').plot(grid=True, style='o-', figsize=(15, 5))
plt.show()

# %%
df.query('floor_category != 0').pivot_table(index = 'floor_category', values = 'last_price').plot(grid=True, style='o-', figsize=(5, 5))
plt.show()

df.query('floor_category != 0').pivot_table(index = 'floor_category', values = 'last_price')
# Out:
#                   last_price
# floor_category
# другой          5.031206e+06
# первый          4.125910e+06
# последний       4.481128e+06

# %% [markdown]
# Распределение цены по категориям этажности:
#  - первый самый дешёвый;
#  - последний приблизительно на 10% дороже первого;
#  - другой (или средний этажи) самый дорогой.
#  - резкие скачеки наблюдается в районе 30 этажей.

# %% [markdown]
# **Зависимость цены от даты размещения по годам.**

# %%
df.pivot_table(index='year', values='last_price').plot(grid=True, style='o-', figsize=(5, 3))
plt.show()

df.pivot_table(index='floor', values=['year', 'last_price']).corr()
# Out:
#             last_price      year
# last_price    1.000000  0.073543
# year          0.073543  1.000000

# %% [markdown]
# По графику видно равномерное падение цены в период с 2014 по 2016 года,
# нижнее плато с 2016 по 2018 года с наименьшей точкой цени в 2017 году,
# с 2018 года цена увеличивается в симметричном темпе падению.
# В 2019 году цена не достигла уровня 2015 и 2014 годов.

# %% [markdown]
# **Зависимость цены от даты размещения по месяцам.**

# %%
df.pivot_table(index='month', values='last_price').plot(grid=True, style='o-', figsize=(5, 5))
plt.show()

df.pivot_table(index='floor', values=['month', 'last_price']).corr()
# Out:
#             last_price     month
# last_price    1.000000  0.031709
# month         0.031709  1.000000

# %% [markdown]
# Всплески пиковой активности продаж наблюдаются в апреле и сентябре (4 и 9).
# Наименьшее число продаж наблюдается в период отпусков в июне.
# В остальные месяцы наблюдается средняя активность с не большим увеличением перед "Новым годом".

# %% [markdown]
# **Зависимость цены от даты размещения по дням недели.**

# %%
df.query('day_week != 0').pivot_table(index = 'day_week', values = 'last_price').plot(grid=True, style='o-', figsize=(15, 5))
plt.show()

df.query('day_week != 0').pivot_table(index = 'day_week', values = 'last_price')
# Out:
#              last_price
# day_week
# Friday     4.815482e+06
# Monday     4.837175e+06
# Saturday   4.729754e+06
# Sunday     4.767974e+06
# Thursday   4.845655e+06
# Tuesday    4.896393e+06
# Wednesday  4.869844e+06

# %% [markdown]
# По графику можно с уверенностью сказать, что основная часть выставления квартир в продажу происходит перед выходными.
# Наименьшее число выставленных квартир наблюдается во вторник и далее идет постепенный рост по количеству до пятницы.

# %% [markdown]
# #### Вывод по факторам влияют на стоимость квартиры:
# - По мере увеличения площади цена возрастает, а так же увеличивается разброс цены.
# - По мере увеличения количества комнат цена возрастает.
# - По мере удаленности от центра цена уменьшается.
# - Распределение цены по категориям этажности:
#    первый самый дешёвый;
#    последний приблизительно на 10% дороже первого;
#    другой (или средний этажи) самый дорогой.
# - Наблюдается равномерное падение цены в период с 2014 по 2016 года,
# нижнее плато с 2016 по 2018 года с наименьшей точкой цени в 2017 году,
# с 2018 года цена увеличивается в симметричном темпе падению.
# В 2019 году цена не достигла уровня 2015 и 2014 годов.
# - Всплески пиковой активности продаж наблюдаются в апреле и сентябре (4 и9).
# Наименьшее число продаж наблюдается в период отпусков в июне.
# В остальные месяцы наблюдается средняя активность с не большим увеличением перед "Новым годом".
# - По графику можно с уверенностью сказать, что основная часть выставления квартир в продажу происходит перед выходными.
# Наименьшее число выставленных квартир наблюдается во вторник и далее идет постепенный рост по количеству до пятницы.

# %% [markdown]
# #### 10 населённых пунктов с наибольшим числом объявлений.

# %%
df['locality_name'].value_counts().head(10) # количество строк по значению.
# Out:
# Санкт-Петербург      15651
# посёлок Мурино         520
# посёлок Шушары         439
# Всеволожск             398
# Пушкин                 369
# Колпино                338
# посёлок Парголово      327
# Гатчина                307
# деревня Кудрово        299
# Выборг                 237
# Name: locality_name, dtype: int64

# %% [markdown]
# Посчитаем среднюю цену квадратного метра в этих населённых пунктах.

# %%
local_ten = df['locality_name'].value_counts().head(10)
local_ten_price = df.query('locality_name in (@local_ten.index)').pivot_table(values='price_m2', index='locality_name')
local_ten_price = local_ten_price.astype(int)
local_ten_price.sort_values('price_m2', ascending=False)
# Out:
#                    price_m2
# locality_name
# Санкт-Петербург      114868
# Пушкин               103125
# деревня Кудрово       92473
# посёлок Парголово     90175
# посёлок Мурино        85673
# посёлок Шушары        78551
# Колпино               75424
# Гатчина               68746
# Всеволожск            68654
# Выборг                58141

# %% [markdown]
# #### Населённый пункт с самой высокой ценой квартиры.

# %%
(
    print('Населённый пункт с самой высокой ценой квартиры:', 
          df['last_price'].max(), 'руб.,' 'index:', 
          df['locality_name'][df['last_price']==df['last_price'].max()])
)
# Out:
# Населённый пункт с самой высокой ценой квартиры: 11866860.0 руб.,index: 3165    Санкт-Петербург
# Name: locality_name, dtype: object

# %% [markdown]
# #### Населённый пункт с самой низкой ценой квартиры.

# %%
(
    print('Населённый пункт с самой низкой ценой квартиры:', 
          df['last_price'].min(), 'руб.,' 'index:', 
          df['locality_name'][df['last_price']==df['last_price'].min()])
)
# Out:
# Населённый пункт с самой низкой ценой квартиры: 12190.0 руб.,index: 8793    Санкт-Петербург
# Name: locality_name, dtype: object

# %% [markdown]
# #### Вывод 10 населённых пунктов:
# - Самая высока стоимость квадратного метра в Санкт-Петербург: 114 868 руб.;
# - Самое большёе количество продаваемых квартир в Санкт-Петербург: 15 651;
# - Самая низкая стоимость квадратного метра в Выборге: 58 141 руб.;
# - Самое маленькое из 10 населённых пунктов количество продаваемых квартир в Выборге: 237.
# - 10 самых дорогих населенных пунктов по стоимости квадратного метра и количеству продаваемых квартир:
#
# locality_name    |price_m2 | кол-во
# -----------------|---------|-------
# Санкт-Петербург	|114 868   |15 651
# Пушкин      	|103 125   |369
# деревня Кудрово	|92 473    |299
# посёлок Парголово|90 175   |327
# посёлок Мурино	|85 673    |520
# посёлок Шушары	|78 551    |439
# Колпино	        |75 424    |338
# Гатчина	        |68 746    |307
# Всеволожск	    |68 654    |398
# Выборг	        |58 141    |237
#
# - Самая дорогая квартира находится в Санкт-Петербурге: 11 866 860 руб.
# - Самая дешёвая квартира находится в Санкт-Петербурге: 12 190 руб.

# %% [markdown]
# #### Центральная область Санкт-Петербурга.

# %% [markdown]
# Добавляем столбец с расстоянием до центра в км, округляем до целого числа.

# %%
df['city_centers'] = df['city_centers_nearest'] / 1000
df['city_centers'] = df['city_centers'].fillna(value=0).astype(int)

# %% [markdown]
# Выбираем Санкт-Петербург, смотрим на график, где указана средняя стоимость для каждого км.

# %%
(
df.query('locality_name == "Санкт-Петербург"')
    .pivot_table(index='city_centers', values='last_price')
    .plot(grid=True, style='o-', xlim=(0,15), figsize=(15, 5))
)
plt.show()

# %% [markdown]
# #### Вывод центральной зоны:
# Центральная зона Санкт-Петербурга находится в радиусе 9 км., после этого расстояние график переходит в плато.

# %% [markdown]
# #### Сегмент квартир в центре.

# %% [markdown]
# Выделяем квартиры в центре в границах радиуса 9 км и за ее пределами в Санкт-Петербурге.

# %%
df_center = df.query('(locality_name == "Санкт-Петербург") & (city_centers <= 9)') 
df_not_centr = df.query('(locality_name == "Санкт-Петербург") & (city_centers > 9)')

# %%
df_center.head()
# Out:
#     total_images  last_price  total_area first_day_exposition  rooms  \
# 3              0         NaN         NaN           2015-07-24    3.0
# 4              2  10000000.0       100.0           2018-06-19    2.0
# 21            13   3200000.0        31.6           2018-03-14    1.0
# 24             8   6500000.0        97.2           2015-10-31    2.0
# 35             6         NaN         NaN           2017-06-26    5.0
#
#     ceiling_height  floors_total  living_area  floor  is_apartment  studio  \
# 3             2.65            14          0.0      9         False   False
# 4              NaN            14         32.0     13         False   False
# 21            2.65             5         16.9      2         False   False
# 24            2.65             3         46.5      1         False   False
# 35            2.65             5          NaN      4         False   False
#
#     open_plan  kitchen_area  balcony    locality_name  ...  \
# ...

# %%
df_not_centr.head()
# Out:
#     total_images  last_price  total_area first_day_exposition  rooms  \
# 0             20         NaN       108.0           2019-03-07    3.0
# 2             10   5196000.0        56.0           2015-08-20    2.0
# 7              5   7915000.0        71.6           2019-04-18    2.0
# 9             18   5400000.0        61.0           2017-02-26    3.0
# 10             5   5050000.0        39.6           2017-11-16    1.0
#
#     ceiling_height  floors_total  living_area  floor  is_apartment  studio  \
# 0             2.70            16         51.0      8         False   False
# 2             2.65             5         34.3      4         False   False
# 7             2.65            24          0.0     22         False   False
# 9             2.50             9         43.6      7         False   False
# 10            2.67            12         20.3      3         False   False
#
#     open_plan  kitchen_area  balcony    locality_name  ...  \
# ...

# %% [markdown]
# Проанализируем следующие параметры: площадь, цена, число комнат, высота потолков.

# %%
df_center[['total_area', 'last_price', 'rooms', 'ceiling_height', 'floor', 'city_centers']].describe()
# Out:
#         total_area    last_price        rooms  ceiling_height        floor  \
# count  4208.000000  3.647000e+03  4948.000000     3065.000000  5120.000000
# mean     65.083192  6.853898e+06     2.471504        2.653501     4.744531
# std      22.763173  2.311368e+06     1.094576        0.078267     3.678203
# min      12.000000  1.219000e+04     0.000000        2.460000     1.000000
# 25%      46.000000  5.000000e+06     2.000000        2.650000     2.000000
# 50%      63.000000  6.700000e+06     2.000000        2.650000     4.000000
# 75%      82.100000  8.510000e+06     3.000000        2.650000     6.000000
# max     114.200000  1.186686e+07     5.000000        2.850000    26.000000
#
#        city_centers
# count   5120.000000
# mean       5.288086
# std        2.497746
# min        0.000000
# 25%        4.000000
# 50%        5.000000
# 75%        8.000000
# max        9.000000

# %%
df_not_centr[['total_area', 'last_price', 'rooms', 'ceiling_height', 'floor', 'city_centers']].describe()
# Out:
#          total_area    last_price         rooms  ceiling_height         floor  \
# count  10301.000000  1.002900e+04  10518.000000    10032.000000  10531.000000
# mean      52.978466  5.230168e+06      1.947328        2.629758      6.943310
# std       18.119235  1.822791e+06      0.918512        0.084323      5.227504
# min       13.000000  1.190000e+06      0.000000        2.460000      1.000000
# 25%       39.000000  3.900000e+06      1.000000        2.560000      3.000000
# 50%       49.000000  4.800000e+06      2.000000        2.650000      6.000000
# 75%       63.000000  6.100000e+06      3.000000        2.650000      9.000000
# max      114.200000  1.185800e+07      5.000000        2.850000     33.000000
#
#        city_centers
# count  10531.000000
# mean      13.849017
# std        2.875444
# min       10.000000
# 25%       12.000000
# 50%       14.000000
# 75%       15.000000
# max       29.000000

# %% [markdown]
# Квартириальные показатели в центре отличаются, чем за её пределами.

# %%
print('Количество квартир выставленных на продажу в центре:', df_center.shape[0]) # количество квартир в центре
# Out:
# Количество квартир выставленных на продажу в центре: 5120

# %%
print('Количество квартир выставленных на продажу за пределами центра:',df_not_centr.shape[0]) # количество квартир за пределами центра
# Out:
# Количество квартир выставленных на продажу за пределами центра: 10531

# %% [markdown]
# Количество продаваемых квартир за пределами центра в два раза больше: 5120 и 10531.

# %% [markdown]
# Сравниваем показатели по площади.

# %%
round(df_not_centr.query('locality_name == "Санкт-Петербург"')['total_area'].median())
# Out:
# 49

# %%
round(df_center['total_area'].median())
# Out:
# 63

# %%
round(df_not_centr.query('locality_name == "Санкт-Петербург"')['total_area'].mean())
# Out:
# 53

# %%
round(df_center['total_area'].mean())
# Out:
# 65

# %% [markdown]
# Показатели по площади:
# - Площадь (медиана): 49
# - Площадь в центре (медиана): 63
# - Площадь (среднее): 53
# - Площадь в центре (среднее): 65

# %%
df['total_area'].hist(bins=30, range=(25,120), figsize=(10,5))
plt.show()

# %%
df_center['total_area'].hist(bins=30, range=(25,120), figsize=(10,5))
plt.show()

# %% [markdown]
# Медианные и средние показатели площади квартир в центре больше, чем за её пределами.

# %% [markdown]
# Сравниваем показатели по цене.

# %%
df_center['last_price'].hist(bins=100)
plt.show()

# %%
df_not_centr['last_price'].hist(bins=100)
plt.show()

# %% [markdown]
# Разброс по квартириальным показателя и цене в центре больше чем за её пределами.

# %% [markdown]
# Число вариантов в центре с ценой больше mean:

# %%
df_center.query('last_price > 6853898')['last_price'].count()
# Out:
# 1713

# %% [markdown]
# Число вариантов за пределами центра с ценой больше mean:

# %%
df_not_centr.query('last_price > 5230168')['last_price'].count()
# Out:
# 3954

# %% [markdown]
# Проверяем долю превышающую медианные показатели.

# %%
df_center.query('locality_name == "Санкт-Петербург"')['last_price'].count()
# Out:
# 3647

# %%
df_center.query('last_price > 6853898')['last_price'].count() / df_center.query('last_price > 0')['last_price'].count() *100
# Out:
# 46.97011242116808

# %% [markdown]
# Доля количества квартир превышающих медианные показатели в центральной зоне составляет: 46.97 %.
# Это говорит о большом разбросе по цене, связанной с другими показателями, таких как площадь и т.д.

# %%
df_not_centr.query('locality_name == "Санкт-Петербург"')['last_price'].count()
# Out:
# 10029

# %%
df_not_centr.query('last_price > 5230168')['last_price'].count() / df_not_centr.query('last_price > 0')['last_price'].count() *100
# Out:
# 39.42566556984744

# %% [markdown]
# Доля количества квартир, превышающих медианные показатели за пределами центральной зоны составляет: 39.42 %.
# Это говорит о большом разбросе по цене, связанной с другими показателями, таких как площадь и т.д.
# **Здесь нужно производить анализ по категориям количества комнат и площади.**

# %% [markdown]
# Отношение количества квартир в центральной зоне и за её пределами.

# %%
df.query('locality_name == "Санкт-Петербург"')['last_price'].count()
# Out:
# 13676

# %%
df_center.query('last_price > 0')['last_price'].count() / df.query('locality_name == "Санкт-Петербург"')['last_price'].count() *100
# Out:
# 26.667154138637027

# %%
df_center.query('locality_name == "Санкт-Петербург"')['last_price'].count() / df_not_centr.query('last_price > 0')['last_price'].count() *100
# Out:
# 36.36454282580516

# %%
labels = ['Центр','За пределами центра']
values = [3647,10029]
colors = ['red', 'yellow']
plt.pie(values,labels=labels,colors=colors)
plt.axis('equal')
plt.show()

# %% [markdown]
# Доля квартир в центральной зоне составляет 26.66 %.
# Соответственно и площади территорий разные, здесь нужно анализировать по плотности.

# %% [markdown]
# Создадим датафрем квартир с показателями для анализа в центральной зоне.

# %%
df_center_price = df_center.drop(['total_images', 'living_area', 'is_apartment', 'studio', 'open_plan', 'kitchen_area', 'city_centers_nearest', 'airports_nearest', 'ponds_nearest', 'parks_around3000', 'parks_nearest', 'ponds_around3000', 'living_area_part', 'kitchen_area_part', 'weekday', 'days_exposition'], axis='columns')
df_center_price.head()
# Out:
#     last_price  total_area first_day_exposition  rooms  ceiling_height  \
# 3          NaN         NaN           2015-07-24    3.0            2.65
# 4   10000000.0       100.0           2018-06-19    2.0             NaN
# 21   3200000.0        31.6           2018-03-14    1.0            2.65
# 24   6500000.0        97.2           2015-10-31    2.0            2.65
# 35         NaN         NaN           2017-06-26    5.0            2.65
#
#     floors_total  floor  balcony    locality_name   price_m2  year  month  \
# 3             14      9        0  Санкт-Петербург  408176.10  2015      7
# 4             14     13        0  Санкт-Петербург  100000.00  2018      6
# 21             5      2        1  Санкт-Петербург  101265.82  2018      3
# 24             3      1        0  Санкт-Петербург   66872.43  2015     10
# 35             5      4        0  Санкт-Петербург  104026.85  2017      6
#
#      day_week floor_category  city_centers
# 3      Friday         другой             6
# ...

# %%
df_center_price.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5120 entries, 3 to 23694
# Data columns (total 15 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   last_price            3647 non-null   float64
#  1   total_area            4208 non-null   float64
#  2   first_day_exposition  5120 non-null   datetime64[ns]
#  3   rooms                 4948 non-null   float64
#  4   ceiling_height        3065 non-null   float64
#  5   floors_total          5120 non-null   int64
#  6   floor                 5120 non-null   int64
#  7   balcony               5120 non-null   int64
#  8   locality_name         5120 non-null   object
#  9   price_m2              5120 non-null   float64
#  10  year                  5120 non-null   int64
#  11  month                 5120 non-null   int64
#  12  day_week              5120 non-null   object
#  13  floor_category        5120 non-null   object
# ...

# %% [markdown]
# Удаляем записи, где отсутствует цена, площадь и количество комнат.

# %%
df_center_price.dropna(subset=['last_price'], inplace=True)
df_center_price.dropna(subset=['total_area'], inplace=True)
df_center_price.dropna(subset=['rooms'], inplace=True)

# %% [markdown]
# Заменяем оставшиеся пустые значения высоты потолков на медианное значение по категориям и этажу.

# %%
df_center_price['ceiling_height'] = df_center_price.groupby(['floor_category', 'floors_total'])['ceiling_height'].apply(lambda x: x.fillna(x.median()))
df_center_price['ceiling_height'].fillna(df_center_price['ceiling_height'].median(), inplace=True)

# %% [markdown]
# Переводим в целые числа.

# %%
df_center_price['last_price'] = df_center_price['last_price'].astype('int')

# %%
df_center_price['rooms'] = df_center_price['rooms'].astype('int')

# %%
df_center_price.head() # прверяем.
# Out:
#     last_price  total_area first_day_exposition  rooms  ceiling_height  \
# 4     10000000       100.0           2018-06-19      2            2.65
# 21     3200000        31.6           2018-03-14      1            2.65
# 24     6500000        97.2           2015-10-31      2            2.65
# 56     4350000        41.0           2016-03-28      1            2.80
# 61     7990000        74.0           2017-08-24      2            2.65
#
#     floors_total  floor  balcony    locality_name   price_m2  year  month  \
# 4             14     13        0  Санкт-Петербург  100000.00  2018      6
# 21             5      2        1  Санкт-Петербург  101265.82  2018      3
# 24             3      1        0  Санкт-Петербург   66872.43  2015     10
# 56             7      4        2  Санкт-Петербург  106097.56  2016      3
# 61             4      4        0  Санкт-Петербург  107972.97  2017      8
#
#      day_week floor_category  city_centers
# 4     Tuesday         другой             8
# ...

# %%
df_center_price.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3548 entries, 4 to 23691
# Data columns (total 15 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   last_price            3548 non-null   int64
#  1   total_area            3548 non-null   float64
#  2   first_day_exposition  3548 non-null   datetime64[ns]
#  3   rooms                 3548 non-null   int64
#  4   ceiling_height        3548 non-null   float64
#  5   floors_total          3548 non-null   int64
#  6   floor                 3548 non-null   int64
#  7   balcony               3548 non-null   int64
#  8   locality_name         3548 non-null   object
#  9   price_m2              3548 non-null   float64
#  10  year                  3548 non-null   int64
#  11  month                 3548 non-null   int64
#  12  day_week              3548 non-null   object
#  13  floor_category        3548 non-null   object
#  14  city_centers          3548 non-null   int64
# ...

# %% [markdown]
# Считаем количество и долю квартир по комнатам.

# %%
srs_rooms = df.query('(locality_name == "Санкт-Петербург") & (rooms > 0)').pivot_table(index='rooms', values='floor', aggfunc='count')
srs_rooms.columns = ['count']
srs_rooms['rooms_fraction'] = srs_rooms['count'] / srs_rooms['count'].sum() * 100
srs_rooms_center = df.query('(locality_name == "Санкт-Петербург") & (city_centers <= 9)  & (rooms > 0)').pivot_table(index='rooms', values='floor', aggfunc='count')
srs_rooms_center.columns = ['center_count']
srs_rooms_center['center_rooms_ratio'] = srs_rooms_center['center_count'] / srs_rooms_center['center_count'].sum() * 100
rooms_alldata = pd.merge(srs_rooms, srs_rooms_center, 'left', on = 'rooms')
rooms_alldata['center_cap'] = round(rooms_alldata['center_count'] / rooms_alldata['count'] * 100)
display(rooms_alldata)
# Out:
#        count  rooms_fraction  center_count  center_rooms_ratio  center_cap
# rooms
# 1.0     4912       31.985414           991           20.138183        20.0
# 2.0     5082       33.092401          1595           32.412111        31.0
# 3.0     4107       26.743505          1524           30.969315        37.0
# 4.0      966        6.290291           579           11.765901        60.0
# 5.0      290        1.888390           232            4.714489        80.0

# %% [markdown]
# Самое большая доля в центральной зоне приходится на 2 комнатные квартиры 33.4 %,
# А от общего числа квартир большую долю занимают 3 комнатные квартиры 37 %.
# Наблюдается закономерность, увеличения доли квартир от общего числа по мере увеличения количества комнат:
# 1 - 20%, 2 - 31%, 3 - 37%, 4 - 60%, 5 - 80%.

# %% [markdown]
# Изучаем высоту потолков.

# %%
df.query('locality_name == "Санкт-Петербург"')['ceiling_height'].median()
# Out:
# 2.65

# %%
df_center_price['ceiling_height'].median()
# Out:
# 2.65

# %%
df.query('locality_name == "Санкт-Петербург"')['ceiling_height'].mean()
# Out:
# 2.63531419409025

# %%
df_center_price['ceiling_height'].mean()
# Out:
# 2.6487570462232237

# %% [markdown]
# Высота потолков находится в пределах одного показателя 2.65 метра.
# median - 2.65;
# среднее значение - 2.63;
# среднее в центре - 2.648.

# %% [markdown]
# Зависимость цены от этажа.

# %%
df_center_price.pivot_table(index='floor', values='last_price', aggfunc='median').plot(grid=True, style='o-', figsize=(10, 5))
plt.show()

# %% [markdown]
# Цена резко возрастает от 1 ко 2 этажу, далее выходит на плато до 17 этажа,
# за исключением некоторых нижних пиков зависящих от последнего 5 и 12 этажа.
# Далее стоимость резко увеличивается с некоторым падением цены на последних 23 и 25 этажах.

# %% [markdown]
# Зависимость цены по удаленности от в центральной зоне и всех квартир.
# Центральная зона:

# %%
df_center_price.pivot_table(index='city_centers', values='last_price', aggfunc='median').plot(grid=True, style='o-', figsize=(10, 5))
plt.show()

# %% [markdown]
# Общая картина зависимости по всем квартирам:

# %%
df.pivot_table(index='city_centers', values='last_price', aggfunc='median').plot(grid=True, style='o-', figsize=(10, 5))
plt.show()

# %% [markdown]
# Корреляция цены и удалённости от центра:

# %%
df.pivot_table(index='floor', values=['city_centers', 'last_price']).corr()
# Out:
#               city_centers  last_price
# city_centers      1.000000    0.835581
# last_price        0.835581    1.000000

# %% [markdown]
# По мере удаленности цена уменьшается как в центральной зоне, так и за её пределами.

# %% [markdown]
# Зависимость цены от даты размещения объявления.

# %%
df.pivot_table(index='first_day_exposition', values='last_price').plot(grid=True, style='o', figsize=(15, 5))
plt.show()

# %% [markdown]
# В зависимости цены от даты размещения наблюдается воронка по мере возрастания даты.
# Это говорит о стабильности рынка и определения более точной цены.
# Наблюдаются некоторое выбросы и всплески в периоды: 2015-1, 2015-7, 2017-1, 2018-07 и 2019-01.

# %% [markdown]
# #### Вывод время продажи квартир:
# - Средняя длительность продажи составляет 180 дней;
# Медианное значение 95, является хорошим показателем спокойного рынка недвижимости;
# Наиболее быстрым сроком продажи можно считать до 30 дней.
# - Самая высока стоимость квадратного метра в Санкт-Петербург: 5663170 руб.;
# - Самая низкая стоимость квадратного метра в Выборге: 3180055 руб.
# - 10 самых дорогих населенных пунктов по стоимости квадратного метра:
# Санкт-Петербург	5663170
# Пушкин	5334384
# посёлок Парголово	4488074
# деревня Кудрово	4204742
# посёлок Шушары	4109808
# Колпино	3839848
# Всеволожск	3737118
# посёлок Мурино	3671210
# Гатчина	3423997
# Выборг	3180055.
# - Самая дорогая квартира находится в Санкт-Петербурге: 11866860 руб.
# - Самая дешёвая квартира находится в Санкт-Петербурге: 12190 руб.
# - Центральная зона Санкт-Петербурга находится в радиусе 9 км., после этого растояние график переходит в плато.
# - Количество продаваемых квартир за пределами центра в два раза больше: 5120 и 10531.
# - Медианные и средние показатели площади квартир в центре больше, чем за её пределами.
#   Показатели по площади:
#   Площадь (медиана): 49
#   Площадь в центре (медиана): 63
#   Площадь (среднее): 53
#   Площадь в центре (среднее): 65
# - Доля квартир в центральной зоне Санкт-Петербург составляет 26.66 %.
# - Самое большая доля в центральной зоне приходится на 2 комнатные квартиры 33.4 %.
# А от общего числа квартир большую долю занимают 3 комнатные квартиры 37 %.
# Наблюдается закономерность, увеличения доли квартир в центральной зоне от общего числа
# по мере увеличения количества комнат:
# 1 - 20%, 2 - 31%, 3 - 37%, 4 - 60%, 4 - 80%.
# - По мере увеличения площади цена возрастает, а также увеличивается разброс цены.
# - По мере увеличения количества комнат цена возрастает в центре и за её пределами.
# - По мере удаленности цена уменьшается как в центральной зоне, так и за её пределами.
# - Распределение цены по категориям этажности:
#    первый самый дешёвый;
#    последний приблизительно на 10% дороже первого;
#    другой (или средний этажи) самый дорогой.
# - Высота потолков находится в пределах одного показателя 2.65 метра.
# median - 2.65;
# среднее значение - 2.63;
# среднее в центре - 2.648.
# - Наблюдается равномерное падение цены в период с 2014 по 2016 года,
# нижнее плато с 2016 по 2018 года с наименьшей точкой цени в 2017 году,
# с 2018 года цена увеличивается в симметричном темпе падению.
# В 2019 году цена не достигла уровня 2015 и 2014 годов.
# - Цена резко возрастает от 1 ко 2 этажу, далее выходит на плато до 17 этажа,
# за исключением некоторых нижних пиков, зависящих от последнего 5 и 12 этажа.
# Далее стоимость резко увеличивается с некоторым падением цены на последних 23 и 25 этажах.
# - Всплески пиковой активности продаж наблюдаются в апреле и сентябре (4 и9).
# Наименьшее число продаж наблюдается в период отпусков в июне.
# В остальные месяцы наблюдается средняя активность с не большим увеличением перед "Новым годом".
# - По графику можно с уверенностью сказать, что основная часть выставления квартир в продажу происходит перед выходными.
# Наименьшее число выставленных квартир наблюдается во вторник и далее идет постепенный рост по количеству до пятницы.
# - В зависимости цены от даты размещения наблюдается воронка по мере возрастания даты.
# Это говорит о стабильности рынка и определения более точной цены.
# Наблюдаются никоторые выбросы и всплески в периоды: 2015-1, 2015-7, 2017-1, 2018-07 и 2019-01.
# - Основные отличия квартир в центральной зоне:
# цена дороже;
# площади больше;
# большее квартир с большим количеством комнат.

# %% [markdown]
# ## Общий вывод

# %% [markdown]
# ### На основе анализа полученных данных,
# без учета выбивающихся значений, можно сделать следующее заключение:
#
# - по 11 позициям имеется большая доля пропусков от 9% до 88%.
# - произведена предобработка данных:
# заполнены некоторые пропуски медианными значениями и по логике информации;
# изменены типы данных;
# изменён формат даты;
# удалена не влияющая на исследование часть информации.
# - Успешно добавлены новые столбцы в датафрейм с расчетами и результатами.
# - Произведена категоризация этажей: первый, последний, другой:
#
# категория | кол-во
# ----------|-------
# друой     |  17326
# последний |  3330
# первый    |  2909
#
# - Добавим день недели, месяц и год публикации объявления;
# - Округлили значения float до двух знаков после запятой:
#   price_m2 до руб. коп., необходимость для точного определения стоимости всей площади;
#   living_area_part, kitchen_area_part необходимо для определения в % выражении.
# - Исследование следующих параметров: площадь, цена, число комнат, высота потолков:
# площадь квартиры min - 12, max - 900, std - 35.65 и mean - 60.32 кв.м.;
# стоимость квартиры min - 1.219000, max - 7.630000, std - 1.091093, mean - 6.540058 млн. руб.;
# количество комнат от 0 - (студия) до 19, что в полне возможно, std - 1;
# высота потолков min - 1, std - 0.99 и max - 100 метров аномальны,
# остальные показатели mean - 2.72 в норме (2.6, 2.65, 2.7).

# %% [markdown]
# ### Нормальное распределение по площади
# находится в диапазоне от 25 до 100 кв.м.
# Наибольшее число квартир продается с площадями 30 - 45, чуть меньше 45 - 65 и с выше 70 кв.м идут по убывающей.

# %%
df['total_area'].plot.hist(bins=100, range=(10, 120)).legend()

# %% [markdown]
# ### Нормальное распределение по стоимости
# находится в диапазоне от 1.2 млн. до 7.6 млн. руб.
# Наибольшее количество продаж по цене в диапазоне от 3 до 5 млн. руб. с пиком 3,5 -3,8 млн. руб.,
# практически в равной степени продаются как меньше 3 млн. так и более 5 млн. руб.,
# гистограмма плавно возрастает и затем плавно убывает. Показатели в норме.

# %%
df['last_price'].plot.hist(bins=50, range=(1219000, 7630000)).legend()

# %% [markdown]
# ### Нормальное распределение количества комнат
# находится в диапазоне от 1 до 5.
# Наибольшее число квартир занимают 1 и 2 комнатные квартиры, чуть меньше 3 коматные квартиры.
# значительно меньше 4 и 5 ком. кв. и далее идут по убывающей с большим количеством комнат.

# %%
df['rooms'].plot.hist(bins=15, range=(0, 8)).legend()

# %% [markdown]
# ### Нормальное распределение количества
# продаваемых квартир по высоте потолков находится в диапазоне от 2.5 до 2.8.
# Основную долю на рынке составляют квартиры с высотой потолка 2.65 м., значительная часть 2.5 м.
# По гистограмме можно отметить стандартизацию потолков по высоте: 2.5, 2.55, 2.6, 2.65, 2.7, 275, а также 2.8 м.

# %%
df['ceiling_height'].plot.hist(bins=50, range=(2.5, 2.85)).legend()

# %% [markdown]
# **Все гистограммы показывают нормальное распределение, данным можно доверять.**

# %% [markdown]
# ### days_exposition:
# Средняя длительность продажи составляет 180 дней;
# Медианное значение 95, является хорошим показателем спокойного рынка недвижимости;
# Наиболее быстрым сроком продажи можно считать до 30 дней;
# Средним до 95 дней;
# Долгим от 95 до 180;
# Очень долгим от 180 дней;
# Свыше одного года можно отнести в категорию не продаваемых, но продаются.
# По гистограмме можно отметить сроки пиковых продаж 7, 30, 45 и 60 дней.
# **В целом данные заслуживают доверия.**

# %%
df['days_exposition'].plot.hist(bins=100, range=(0, 500)).legend()

# %% [markdown]
# ### Зависимость цены от площади квартиры.
# По мере увеличения площади цена возрастает, а так же увеличивается разброс цены.

# %%
df.plot(x="total_area", y="last_price", kind="scatter", grid=True, style='o', figsize=(25, 5))
# Out:
# <AxesSubplot:xlabel='total_area', ylabel='last_price'>

# %% [markdown]
# ### Зависимость цены от числа комнат.
# По мере увеличения количества комнат цена возрастает.

# %%
df.query('rooms > 0').pivot_table(index='rooms', values='last_price').plot(grid=True, style='o-', figsize=(10, 3))
# Out:
# <AxesSubplot:xlabel='rooms'>

# %% [markdown]
# ### Зависимость цены по удалённости от центра.
# По мере удаленности от центра цена уменьшается.

# %%
(
    df.query('city_centers_nearest > 0').pivot_table(index='city_centers_nearest', values='last_price')
    .plot(grid=True, style='o', figsize=(25, 5))
)
# Out:
# <AxesSubplot:xlabel='city_centers_nearest'>

# %% [markdown]
# ### Зависимость цены от этажа.
# Распределение цены (млн. руб.) по категориям этажности:
#
#
#  категория  |ср. цена (млн. р.)| вывод
#  -----------|-----------|------
#  другой     |5.031206   |самый дорогой
#  первый     |4.125910   |самый дешёвый
#  последний  |4.481128   |на 9.2% дороже первого

# %%
df.pivot_table(index='floor', values='last_price').plot(grid=True, style='o-', figsize=(15, 3))
# Out:
# <AxesSubplot:xlabel='floor'>

# %%
(
    df.query('floor_category != 0').pivot_table(index = 'floor_category', values = 'last_price')
    .plot(grid=True, style='o-', figsize=(5, 3))
)
# Out:
# <AxesSubplot:xlabel='floor_category'>

# %% [markdown]
# ### Зависимость цены от даты размещения по годам.
# По графику видно равномерное падение цены в период с 2014 по 2016 года,
# нижнее плато с 2016 по 2018 года с наименьшей точкой цени в 2017 году,
# с 2018 года цена увеличивается в симметричном темпе падению.
# В 2019 году цена не достигла уровня 2015 и 2014 годов.

# %%
df.pivot_table(index='year', values='last_price').plot(grid=True, style='o-', figsize=(10, 3))
# Out:
# <AxesSubplot:xlabel='year'>

# %% [markdown]
# ### Зависимость цены от даты размещения по месяцам.
# Всплески пиковой активности продаж наблюдаются в апреле и сентябре (4 и 9).
# Наименьшее число продаж наблюдается в июне.
# В остальные месяцы наблюдается средняя активность с не большим увеличением перед "Новым годом".

# %%
df.pivot_table(index='month', values='last_price').plot(grid=True, style='o-', figsize=(10, 3))
# Out:
# <AxesSubplot:xlabel='month'>

# %% [markdown]
# ### Зависимость цены от даты размещения по дням недели.
# Основная часть выставления квартир в продажу происходит перед выходными в пятницу.
# Наименьшее число выставленных квартир наблюдается во вторник и далее идет постепенный рост по количеству до пятницы.

# %%
df.query('day_week != 0').pivot_table(index = 'day_week', values = 'last_price').plot(grid=True, style='o-', figsize=(10, 3))
# Out:
# <AxesSubplot:xlabel='day_week'>

# %% [markdown]
# ### Вывод 10 населённых пунктов:
# - Самая высока стоимость квадратного метра в Санкт-Петербург: 114 868 руб.;
# - Самое большёе количество продаваемых квартир в Санкт-Петербург: 15 651;
# - Самая низкая стоимость квадратного метра в Выборге: 58 141 руб.;
# - Самое маленькое из 10 населённых пунктов количество продаваемых квартир в Выборге: 237.
# - 10 самых дорогих населенных пунктов по средней стоимости квадратного метра и количеству продаваемых квартир:
#
# locality_name    |price_m2 | кол-во       |значение
# -----------------|---------|--------------|----
# **Санкт-Петербург**|**114 868**|**15 651**|max
# Пушкин      	|103 125   |369
# деревня Кудрово	|92 473    |299
# посёлок Парголово|90 175   |327
# посёлок Мурино	|85 673    |520
# посёлок Шушары	|78 551    |439
# Колпино	        |75 424    |338    |median(10)
# Гатчина	        |68 746    |307
# Всеволожск	    |68 654    |398
# **Выборг**	    |**58 141**|**237**|min
#
# - Самая дорогая квартира находится в Санкт-Петербурге: 11 866 860 руб.
# - Самая дешёвая квартира находится в Санкт-Петербурге: 12 190 руб.

# %% [markdown]
# ### Центральная область Санкт-Петербурга.
# Центральная зона Санкт-Петербурга находится в радиусе 9 км., после этого расстояние график переходит в плато.

# %%
(
    df.query('locality_name == "Санкт-Петербург"').pivot_table(index='city_centers', values='last_price')
    .plot(grid=True, style='o-', xlim=(0,15), ylim=(5000000,8500000), figsize=(10, 5))
)
# Out:
# <AxesSubplot:xlabel='city_centers'>

# %% [markdown]
# ### Сегмент квартир в центре.
# Показатели  по площади:
#
# показатель| площадь (кв.м)
# ----------|-------
# Площадь (медиана)| 49
# Площадь в центре (медиана)| 63
# Площадь (среднее)| 53
# Площадь в центре (среднее)| 65

# %% [markdown]
# Количество квартир по площади в центре и за её пределами.

# %%
df['total_area'].plot.hist(alpha = 0.3, bins = 30, range=(0,120), figsize=(10,5)).legend()
df_center['total_area'].plot.hist(alpha = 0.8 , bins = 30, range=(0,120), figsize=(10,5))
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %% [markdown]
# ### Количество квартир, выставленных на продажу:
# - в центре: 5 120.
# - за пределами центра: 10 531.
#
# Отношение количества квартир в центральной зоне и за её пределами: 26.7%.

# %%
labels = ['За пределами центра', 'Центр']
values = [10029, 3647]
colors = ['yellow', 'red']
explode = [0.1,0]
plt.title('Доля квартир в центре и за её пределами')
plt.pie(values,labels=labels,colors=colors,explode=explode,shadow=True,autopct='%1.1f%%',startangle=180)
plt.axis('equal')
plt.show()

# %% [markdown]
# ### Количество и доля квартир по комнатам.
#
# rooms	|count	|rooms_fraction (%)	|center_count	|center_rooms_ratio (%)	|center_cap (%)
# --------|-------|---------------|---------------|-------------------|----------
# 1	|4912	|31.98	|991	|20.13	|20
# 2	|5082	|33.09	|1595	|32.41	|31
# 3	|4107	|26.74	|1524	|30.96	|37
# 4	|966	|6.29	|579	|11.76	|60
# 5	|290	|1.88	|232	|4.71	|80

# %% [markdown]
# ### Высота потолков находится в пределах одного показателя 2.65 метра.
#
# - median - 2.65;
# - среднее значение - 2.63;
# - среднее в центре - 2.648.

# %% [markdown]
# ### Зависимость цены от этажа.
# Цена резко возрастает от 1 ко 2 этажу, далее выходит на плато до 17 этажа,
# за исключением некоторых нижних пиков зависящих от последнего 5 и 12 этажа.
# Далее стоимость резко увеличивается с некоторым падением цены на последних 23 и 25 этажах.

# %%
df_center_price.pivot_table(index='floor', values='last_price', aggfunc='median').plot(grid=True, style='o-', figsize=(10, 5))
# Out:
# <AxesSubplot:xlabel='floor'>

# %% [markdown]
# ### Зависимость цены по удаленности
# в центральной зоне и всех квартир.
# По мере удаленности цена уменьшается как в центральной зоне, так и за её пределами.
# - Центральная зона:

# %%
df_center_price.pivot_table(index='city_centers', values='last_price', aggfunc='median').plot(grid=True, style='o-', figsize=(10, 5))
# Out:
# <AxesSubplot:xlabel='city_centers'>

# %% [markdown]
# - Общая картина зависимости по всем квартирам:

# %%
df.pivot_table(index='city_centers', values='last_price', aggfunc='median').plot(grid=True, style='o-', figsize=(10, 5))
# Out:
# <AxesSubplot:xlabel='city_centers'>

# %% [markdown]
# ### Зависимость цены от даты размещения объявления.
# - В цене от даты размещения наблюдается воронка по мере возрастания даты.
# Это говорит о стабильности рынка и определения более точной цены.
# Наблюдаются некоторые выбросы и всплески в периоды: 2015-1, 2015-7, 2017-1, 2018-07 и 2019-01.

# %%
df.pivot_table(index='first_day_exposition', values='last_price').plot(grid=True, style='o', figsize=(15, 5))
# Out:
# <AxesSubplot:xlabel='first_day_exposition'>

# %% [markdown]
# **Рыночная стоимость и параметры объектов недвижимости определены.**

# %% [markdown]
# ## Чек-лист готовности проекта
#
# Поставьте 'x' в выполненных пунктах. Далее нажмите Shift+Enter.

# %% [markdown]
# - [x]  открыт файл
# - [x]  файлы изучены (выведены первые строки, метод `info()`)
# - [x]  определены пропущенные значения
# - [x]  заполнены пропущенные значения
# - [x]  есть пояснение, какие пропущенные значения обнаружены
# - [x]  изменены типы данных
# - [x]  есть пояснение, в каких столбцах изменены типы и почему
# - [x]  посчитано и добавлено в таблицу: цена квадратного метра
# - [x]  посчитано и добавлено в таблицу: день недели, месяц и год публикации объявления
# - [x]  посчитано и добавлено в таблицу: этаж квартиры; варианты — первый, последний, другой
# - [x]  посчитано и добавлено в таблицу: соотношение жилой и общей площади, а также отношение площади кухни к общей
# - [x]  изучены следующие параметры: площадь, цена, число комнат, высота потолков
# - [x]  построены гистограммы для каждого параметра
# - [x]  выполнено задание: «Изучите время продажи квартиры. Постройте гистограмму. Посчитайте среднее и медиану. Опишите, сколько обычно занимает продажа. Когда можно считать, что продажи прошли очень быстро, а когда необычно долго?»
# - [x]  выполнено задание: «Уберите редкие и выбивающиеся значения. Опишите, какие особенности обнаружили».
# - [x]  выполнено задание: «Какие факторы больше всего влияют на стоимость квартиры? Изучите, зависит ли цена от квадратного метра, числа комнат, этажа (первого или последнего), удалённости от центра. Также изучите зависимость от даты размещения: дня недели, месяца и года».
# - [x]  выполнено задание: «Выберите 10 населённых пунктов с наибольшим числом объявлений. Посчитайте среднюю цену квадратного метра в этих населённых пунктах. Выделите населённые пункты с самой высокой и низкой стоимостью жилья. Эти данные можно найти по имени в столбце `locality_name`».
# - [x]  выполнено задание: «Изучите предложения квартир: для каждой квартиры есть информация о расстоянии до центра. Выделите квартиры в Санкт-Петербурге (`locality_name`). Ваша задача — выяснить, какая область входит в центр. Создайте столбец с расстоянием до центра в километрах: округлите до целых значений. После этого посчитайте среднюю цену для каждого километра. Постройте график: он должен показывать, как цена зависит от удалённости от центра. Определите границу, где график сильно меняется — это и будет центральная зона».
# - [x]  выполнено задание: «Выделите сегмент квартир в центре. Проанализируйте эту территорию и изучите следующие параметры: площадь, цена, число комнат, высота потолков. Также выделите факторы, которые влияют на стоимость квартиры (число комнат, этаж, удалённость от центра, дата размещения объявления). Сделайте выводы. Отличаются ли они от общих выводов по всей базе?»
# - [x]  в каждом этапе есть выводы
# - [x]  есть общий вывод
