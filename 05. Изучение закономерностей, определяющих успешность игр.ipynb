# %% [markdown]
# # Исследование данных компьютерных игр

# %% [markdown]
# <h1>Содержание<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Файл-с-данными-и-общая-информация" data-toc-modified-id="Файл-с-данными-и-общая-информация-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Файл с данными и общая информация</a></span><ul class="toc-item"><li><span><a href="#Вывод" data-toc-modified-id="Вывод-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Вывод</a></span></li></ul></li><li><span><a href="#Подготовка-данных" data-toc-modified-id="Подготовка-данных-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Подготовка данных</a></span><ul class="toc-item"><li><span><a href="#Замена-названий-столбцов" data-toc-modified-id="Замена-названий-столбцов-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Замена названий столбцов</a></span></li><li><span><a href="#Дубликаты" data-toc-modified-id="Дубликаты-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Дубликаты</a></span></li><li><span><a href="#Пропущенные-значения" data-toc-modified-id="Пропущенные-значения-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>Пропущенные значения</a></span></li><li><span><a href="#Обработка-пропусщеных-значений" data-toc-modified-id="Обработка-пропусщеных-значений-2.4"><span class="toc-item-num">2.4&nbsp;&nbsp;</span>Обработка пропусщеных значений</a></span><ul class="toc-item"><li><span><a href="#year_of_release" data-toc-modified-id="year_of_release-2.4.1"><span class="toc-item-num">2.4.1&nbsp;&nbsp;</span>year_of_release</a></span></li><li><span><a href="#critic_score" data-toc-modified-id="critic_score-2.4.2"><span class="toc-item-num">2.4.2&nbsp;&nbsp;</span>critic_score</a></span></li><li><span><a href="#user_scoreuser_score-и-значение-&quot;tbd&quot;" data-toc-modified-id="user_scoreuser_score-и-значение-&quot;tbd&quot;-2.4.3"><span class="toc-item-num">2.4.3&nbsp;&nbsp;</span>user_scoreuser_score и значение "tbd"</a></span></li><li><span><a href="#Замена-в-столбце-'user_score'-тип-значения-object-на-float" data-toc-modified-id="Замена-в-столбце-'user_score'-тип-значения-object-на-float-2.4.4"><span class="toc-item-num">2.4.4&nbsp;&nbsp;</span>Замена в столбце 'user_score' тип значения object на float</a></span></li><li><span><a href="#user_score" data-toc-modified-id="user_score-2.4.5"><span class="toc-item-num">2.4.5&nbsp;&nbsp;</span>user_score</a></span></li><li><span><a href="#name" data-toc-modified-id="name-2.4.6"><span class="toc-item-num">2.4.6&nbsp;&nbsp;</span>name</a></span></li><li><span><a href="#Вывод---обработки-пропущенных-значений" data-toc-modified-id="Вывод---обработки-пропущенных-значений-2.4.7"><span class="toc-item-num">2.4.7&nbsp;&nbsp;</span>Вывод   обработки пропущенных значений</a></span></li></ul></li><li><span><a href="#Суммарные-продажи-в-регионах" data-toc-modified-id="Суммарные-продажи-в-регионах-2.5"><span class="toc-item-num">2.5&nbsp;&nbsp;</span>Суммарные продажи в регионах</a></span></li></ul></li><li><span><a href="#Исследовательский-анализ-данных" data-toc-modified-id="Исследовательский-анализ-данных-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Исследовательский анализ данных</a></span><ul class="toc-item"><li><span><a href="#Количество-игр-выпускаемое-в-разные-годы" data-toc-modified-id="Количество-игр-выпускаемое-в-разные-годы-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Количество игр выпускаемое в разные годы</a></span><ul class="toc-item"><li><span><a href="#Вывод:" data-toc-modified-id="Вывод:-3.1.1"><span class="toc-item-num">3.1.1&nbsp;&nbsp;</span>Вывод:</a></span></li></ul></li><li><span><a href="#Продажи-по-платформам" data-toc-modified-id="Продажи-по-платформам-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Продажи по платформам</a></span><ul class="toc-item"><li><span><a href="#Вывод:" data-toc-modified-id="Вывод:-3.2.1"><span class="toc-item-num">3.2.1&nbsp;&nbsp;</span>Вывод:</a></span></li></ul></li><li><span><a href="#Актуальный-период" data-toc-modified-id="Актуальный-период-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>Актуальный период</a></span><ul class="toc-item"><li><span><a href="#Вывод:" data-toc-modified-id="Вывод:-3.3.1"><span class="toc-item-num">3.3.1&nbsp;&nbsp;</span>Вывод:</a></span></li></ul></li><li><span><a href="#Глобальные-продажи-игр-в-разбивке-по-платформам" data-toc-modified-id="Глобальные-продажи-игр-в-разбивке-по-платформам-3.4"><span class="toc-item-num">3.4&nbsp;&nbsp;</span>Глобальные продажи игр в разбивке по платформам</a></span><ul class="toc-item"><li><span><a href="#Вывод" data-toc-modified-id="Вывод-3.4.1"><span class="toc-item-num">3.4.1&nbsp;&nbsp;</span>Вывод</a></span></li></ul></li><li><span><a href="#Диаграмма-рассеяния-и-корреляция" data-toc-modified-id="Диаграмма-рассеяния-и-корреляция-3.5"><span class="toc-item-num">3.5&nbsp;&nbsp;</span>Диаграмма рассеяния и корреляция</a></span><ul class="toc-item"><li><span><a href="#Вывод:" data-toc-modified-id="Вывод:-3.5.1"><span class="toc-item-num">3.5.1&nbsp;&nbsp;</span>Вывод:</a></span></li><li><span><a href="#Вывод:" data-toc-modified-id="Вывод:-3.5.2"><span class="toc-item-num">3.5.2&nbsp;&nbsp;</span>Вывод:</a></span></li></ul></li><li><span><a href="#Матрица-кореляции" data-toc-modified-id="Матрица-кореляции-3.6"><span class="toc-item-num">3.6&nbsp;&nbsp;</span>Матрица кореляции</a></span><ul class="toc-item"><li><span><a href="#Вывод:" data-toc-modified-id="Вывод:-3.6.1"><span class="toc-item-num">3.6.1&nbsp;&nbsp;</span>Вывод:</a></span></li></ul></li><li><span><a href="#Корреляция-между-отзывами-и-продажами" data-toc-modified-id="Корреляция-между-отзывами-и-продажами-3.7"><span class="toc-item-num">3.7&nbsp;&nbsp;</span>Корреляция между отзывами и продажами</a></span><ul class="toc-item"><li><span><a href="#Вывод:" data-toc-modified-id="Вывод:-3.7.1"><span class="toc-item-num">3.7.1&nbsp;&nbsp;</span>Вывод:</a></span></li></ul></li><li><span><a href="#Общее-распределение-игр-по-жанрам" data-toc-modified-id="Общее-распределение-игр-по-жанрам-3.8"><span class="toc-item-num">3.8&nbsp;&nbsp;</span>Общее распределение игр по жанрам</a></span></li><li><span><a href="#Вывод:" data-toc-modified-id="Вывод:-3.9"><span class="toc-item-num">3.9&nbsp;&nbsp;</span>Вывод:</a></span></li></ul></li><li><span><a href="#Портрет-пользователя-каждого-региона" data-toc-modified-id="Портрет-пользователя-каждого-региона-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Портрет пользователя каждого региона</a></span><ul class="toc-item"><li><span><a href="#Популярные-платформы-(топ-5)" data-toc-modified-id="Популярные-платформы-(топ-5)-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Популярные платформы (топ-5)</a></span><ul class="toc-item"><li><span><a href="#Вывод" data-toc-modified-id="Вывод-4.1.1"><span class="toc-item-num">4.1.1&nbsp;&nbsp;</span>Вывод</a></span></li></ul></li><li><span><a href="#Популярные-жанры-(топ-5)" data-toc-modified-id="Популярные-жанры-(топ-5)-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>Популярные жанры (топ-5)</a></span><ul class="toc-item"><li><span><a href="#Вывод" data-toc-modified-id="Вывод-4.2.1"><span class="toc-item-num">4.2.1&nbsp;&nbsp;</span>Вывод</a></span></li></ul></li><li><span><a href="#Влияние-рейтинга-ESRB-на-продажи-в-отдельном-регионе." data-toc-modified-id="Влияние-рейтинга-ESRB-на-продажи-в-отдельном-регионе.-4.3"><span class="toc-item-num">4.3&nbsp;&nbsp;</span>Влияние рейтинга ESRB на продажи в отдельном регионе.</a></span></li></ul></li><li><span><a href="#Гипотезы" data-toc-modified-id="Гипотезы-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Гипотезы</a></span><ul class="toc-item"><li><span><a href="#Средние-пользовательские-рейтинги-платформ-Xbox-One-и-PC" data-toc-modified-id="Средние-пользовательские-рейтинги-платформ-Xbox-One-и-PC-5.1"><span class="toc-item-num">5.1&nbsp;&nbsp;</span>Средние пользовательские рейтинги платформ Xbox One и PC</a></span><ul class="toc-item"><li><span><a href="#Вывод" data-toc-modified-id="Вывод-5.1.1"><span class="toc-item-num">5.1.1&nbsp;&nbsp;</span>Вывод</a></span></li></ul></li><li><span><a href="#Средние-пользовательские-рейтинги-жанров-Action-и-Sports" data-toc-modified-id="Средние-пользовательские-рейтинги-жанров-Action-и-Sports-5.2"><span class="toc-item-num">5.2&nbsp;&nbsp;</span>Средние пользовательские рейтинги жанров Action и Sports</a></span><ul class="toc-item"><li><span><a href="#Вывод" data-toc-modified-id="Вывод-5.2.1"><span class="toc-item-num">5.2.1&nbsp;&nbsp;</span>Вывод</a></span></li></ul></li></ul></li><li><span><a href="#Общий-вывод" data-toc-modified-id="Общий-вывод-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Общий вывод</a></span><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#Общее-количество-проданных-копий-во-всех-регионах:-8915.71-млн." data-toc-modified-id="Общее-количество-проданных-копий-во-всех-регионах:-8915.71-млн.-6.0.1"><span class="toc-item-num">6.0.1&nbsp;&nbsp;</span>Общее количество проданных копий во всех регионах: 8915.71 млн.</a></span></li><li><span><a href="#Распределение-суммарной-продажи-по-годам" data-toc-modified-id="Распределение-суммарной-продажи-по-годам-6.0.2"><span class="toc-item-num">6.0.2&nbsp;&nbsp;</span>Распределение суммарной продажи по годам</a></span></li><li><span><a href="#Динамика-продаж" data-toc-modified-id="Динамика-продаж-6.0.3"><span class="toc-item-num">6.0.3&nbsp;&nbsp;</span>Динамика продаж</a></span></li><li><span><a href="#Глобальные-продажи-игр-в-разбивке-по-платформам" data-toc-modified-id="Глобальные-продажи-игр-в-разбивке-по-платформам-6.0.4"><span class="toc-item-num">6.0.4&nbsp;&nbsp;</span>Глобальные продажи игр в разбивке по платформам</a></span></li><li><span><a href="#Матрица-кореляции" data-toc-modified-id="Матрица-кореляции-6.0.5"><span class="toc-item-num">6.0.5&nbsp;&nbsp;</span>Матрица кореляции</a></span></li><li><span><a href="#Данные-корреляции-по-топовым-платформам" data-toc-modified-id="Данные-корреляции-по-топовым-платформам-6.0.6"><span class="toc-item-num">6.0.6&nbsp;&nbsp;</span>Данные корреляции по топовым платформам</a></span></li><li><span><a href="#Общее-распределение-игр-по-жанрам" data-toc-modified-id="Общее-распределение-игр-по-жанрам-6.0.7"><span class="toc-item-num">6.0.7&nbsp;&nbsp;</span>Общее распределение игр по жанрам</a></span></li><li><span><a href="#Популярные-платформы-(топ-5)" data-toc-modified-id="Популярные-платформы-(топ-5)-6.0.8"><span class="toc-item-num">6.0.8&nbsp;&nbsp;</span>Популярные платформы (топ-5)</a></span></li><li><span><a href="#Популярные-жанры-(топ-5)" data-toc-modified-id="Популярные-жанры-(топ-5)-6.0.9"><span class="toc-item-num">6.0.9&nbsp;&nbsp;</span>Популярные жанры (топ-5)</a></span></li><li><span><a href="#Влияние-рейтинга-ESRB-на-продажи-в-отдельном-регионе." data-toc-modified-id="Влияние-рейтинга-ESRB-на-продажи-в-отдельном-регионе.-6.0.10"><span class="toc-item-num">6.0.10&nbsp;&nbsp;</span>Влияние рейтинга ESRB на продажи в отдельном регионе.</a></span></li><li><span><a href="#Гипотезы" data-toc-modified-id="Гипотезы-6.0.11"><span class="toc-item-num">6.0.11&nbsp;&nbsp;</span>Гипотезы</a></span></li></ul></li></ul></li></ul></div>

# %% [markdown]
# **Описание проекта**
#
# Вы работаете в интернет-магазине «Стримчик», который продаёт по всему миру компьютерные игры. Из открытых источников доступны исторические данные о продажах игр, оценки пользователей и экспертов, жанры и платформы (например, Xbox или PlayStation). Вам нужно выявить определяющие успешность игры закономерности. Это позволит сделать ставку на потенциально популярный продукт и спланировать рекламные кампании.
#
# Перед вами данные до 2016 года. Представим, что сейчас декабрь 2016 г., и вы планируете кампанию на 2017-й. Нужно отработать принцип работы с данными. Неважно, прогнозируете ли вы продажи на 2017 год по данным 2016-го или же 2027-й — по данным 2026 года.
#
# В наборе данных попадается аббревиатура ESRB (Entertainment Software Rating Board) — это ассоциация, определяющая возрастной рейтинг компьютерных игр. ESRB оценивает игровой контент и присваивает ему подходящую возрастную категорию, например, «Для взрослых», «Для детей младшего возраста» или «Для подростков».

# %% [markdown]
# **Инструкция по выполнению проекта**
#
# Шаг 1. Откройте файл с данными и изучите общую информацию
# Путь к файлу: /datasets/games.csv. Скачать датасет
#
# Шаг 2. Подготовьте данные
# Замените названия столбцов (приведите к нижнему регистру);
# Преобразуйте данные в нужные типы. Опишите, в каких столбцах заменили тип данных и почему;
# Обработайте пропуски при необходимости:
# Объясните, почему заполнили пропуски определённым образом или почему не стали это делать;
# Опишите причины, которые могли привести к пропускам;
# Обратите внимание на аббревиатуру 'tbd' в столбце с оценкой пользователей. Отдельно разберите это значение и опишите, как его обработать;
# Посчитайте суммарные продажи во всех регионах и запишите их в отдельный столбец.
#
# Шаг 3. Проведите исследовательский анализ данных
# Посмотрите, сколько игр выпускалось в разные годы. Важны ли данные за все периоды?
# Посмотрите, как менялись продажи по платформам. Выберите платформы с наибольшими суммарными продажами и постройте распределение по годам. За какой характерный срок появляются новые и исчезают старые платформы?
# Возьмите данные за соответствующий актуальный период. Актуальный период определите самостоятельно в результате исследования предыдущих вопросов. Основной фактор — эти данные помогут построить прогноз на 2017 год.
# Не учитывайте в работе данные за предыдущие годы.
# Какие платформы лидируют по продажам, растут или падают? Выберите несколько потенциально прибыльных платформ.
# Постройте график «ящик с усами» по глобальным продажам игр в разбивке по платформам. Опишите результат.
# Посмотрите, как влияют на продажи внутри одной популярной платформы отзывы пользователей и критиков. Постройте диаграмму рассеяния и посчитайте корреляцию между отзывами и продажами. Сформулируйте выводы.
# Соотнесите выводы с продажами игр на других платформах.
# Посмотрите на общее распределение игр по жанрам. Что можно сказать о самых прибыльных жанрах? Выделяются ли жанры с высокими и низкими продажами?
#
# Шаг 4. Составьте портрет пользователя каждого региона
# Определите для пользователя каждого региона (NA, EU, JP):
# Самые популярные платформы (топ-5). Опишите различия в долях продаж.
# Самые популярные жанры (топ-5). Поясните разницу.
# Влияет ли рейтинг ESRB на продажи в отдельном регионе?
#
# Шаг 5. Проверьте гипотезы
# Средние пользовательские рейтинги платформ Xbox One и PC одинаковые;
# Средние пользовательские рейтинги жанров Action (англ. «действие», экшен-игры) и Sports (англ. «спортивные соревнования») разные.
# Задайте самостоятельно пороговое значение alpha.
# Поясните:
# Как вы сформулировали нулевую и альтернативную гипотезы;
# Какой критерий применили для проверки гипотез и почему.
#
# Шаг 6. Напишите общий вывод
# Оформление: Выполните задание в Jupyter Notebook.
# Заполните программный код в ячейках типа code, текстовые пояснения — в ячейках типа markdown.
# Примените форматирование и заголовки.
#
# **Описание данных**
# Name — название игры
# Platform — платформа
# Year_of_Release — год выпуска
# Genre — жанр игры
# NA_sales — продажи в Северной Америке (миллионы проданных копий)
# EU_sales — продажи в Европе (миллионы проданных копий)
# JP_sales — продажи в Японии (миллионы проданных копий)
# Other_sales — продажи в других странах (миллионы проданных копий)
# Critic_Score — оценка критиков (максимум 100)
# User_Score — оценка пользователей (максимум 10)
# Rating — рейтинг от организации ESRB (англ. Entertainment Software Rating Board). Эта ассоциация определяет рейтинг компьютерных игр и присваивает им подходящую возрастную категорию.

# %% [markdown]
# ### Файл с данными и общая информация

# %%
import pandas as pd
import numpy as np
from scipy import stats as st
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# открываем файл
df = pd.read_csv('/datasets/games.csv')
df
# Out:
#                                 Name Platform  Year_of_Release         Genre  \
# 0                         Wii Sports      Wii           2006.0        Sports
# 1                  Super Mario Bros.      NES           1985.0      Platform
# 2                     Mario Kart Wii      Wii           2008.0        Racing
# 3                  Wii Sports Resort      Wii           2009.0        Sports
# 4           Pokemon Red/Pokemon Blue       GB           1996.0  Role-Playing
# ...                              ...      ...              ...           ...
# 16710  Samurai Warriors: Sanada Maru      PS3           2016.0        Action
# 16711               LMA Manager 2007     X360           2006.0        Sports
# 16712        Haitaka no Psychedelica      PSV           2016.0     Adventure
# 16713               Spirits & Spells      GBA           2003.0      Platform
# 16714            Winning Post 8 2016      PSV           2016.0    Simulation
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16715 entries, 0 to 16714
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Name             16713 non-null  object
#  1   Platform         16715 non-null  object
#  2   Year_of_Release  16446 non-null  float64
#  3   Genre            16713 non-null  object
#  4   NA_sales         16715 non-null  float64
#  5   EU_sales         16715 non-null  float64
#  6   JP_sales         16715 non-null  float64
#  7   Other_sales      16715 non-null  float64
#  8   Critic_Score     8137 non-null   float64
#  9   User_Score       10014 non-null  object
#  10  Rating           9949 non-null   object
# dtypes: float64(6), object(5)
# memory usage: 1.4+ MB

# %% [markdown]
# #### Вывод
# Датасет состоит из 11 колонок и 16715 строк с данными.
# Нужно привести названия столбцов к нижнему регисту.
# Обработать пропущенные значения.
# Проверить на наличие дубликатов.
# Бросается в глаза User_Score тип данных object, заменить на float.
# В столбце  имеется значение **tbd**, проанализировать и заменить.
# Формат год привести в int.

# %% [markdown]
# ### Подготовка данных
# #### Замена названий столбцов

# %%
df.columns = df.columns.str.lower()

df.head()
# Out:
#                        name platform  year_of_release         genre  na_sales  \
# 0                Wii Sports      Wii           2006.0        Sports     41.36
# 1         Super Mario Bros.      NES           1985.0      Platform     29.08
# 2            Mario Kart Wii      Wii           2008.0        Racing     15.68
# 3         Wii Sports Resort      Wii           2009.0        Sports     15.61
# 4  Pokemon Red/Pokemon Blue       GB           1996.0  Role-Playing     11.27
#
#    eu_sales  jp_sales  other_sales  critic_score user_score rating
# 0     28.96      3.77         8.45          76.0          8      E
# 1      3.58      6.81         0.77           NaN        NaN    NaN
# 2     12.76      3.79         3.29          82.0        8.3      E
# 3     10.93      3.28         2.95          80.0          8      E
# 4      8.89     10.22         1.00           NaN        NaN    NaN

# %% [markdown]
# #### Дубликаты

# %%
# Посчитаем количество дубликатов

print('Количество дубликатов:', df.duplicated().sum())
# Out:
# Количество дубликатов: 0

# %% [markdown]
# #### Пропущенные значения

# %%
# Выводим пропущенные значения

df.isna().sum()
# Out:
# name                  2
# platform              0
# year_of_release     269
# genre                 2
# na_sales              0
# eu_sales              0
# jp_sales              0
# other_sales           0
# critic_score       8578
# user_score         6701
# rating             6766
# dtype: int64

# %% [markdown]
# **Вывод:**
# Имеются пропущенные значения в столбцах: year_of_release, critic_score, user_score, rating.
# Дубликаты отсутствуют.

# %% [markdown]
# #### Обработка пропусщеных значений
# ##### year_of_release

# %%
# Рассмотрим характер пропущенных значении в столбце "year_of_release"

df[df['year_of_release'].isna()]
# Out:
#                                     name platform  year_of_release  \
# 183                      Madden NFL 2004      PS2              NaN
# 377                     FIFA Soccer 2004      PS2              NaN
# 456           LEGO Batman: The Videogame      Wii              NaN
# 475           wwe Smackdown vs. Raw 2006      PS2              NaN
# 609                       Space Invaders     2600              NaN
# ...                                  ...      ...              ...
# 16373  PDC World Championship Darts 2008      PSP              NaN
# 16405                      Freaky Flyers       GC              NaN
# 16448                          Inversion       PC              NaN
# 16458        Hakuouki: Shinsengumi Kitan      PS3              NaN
# 16522                       Virtua Quest       GC              NaN
#
#               genre  na_sales  eu_sales  jp_sales  other_sales  critic_score  \
# 183          Sports      4.26      0.26      0.01         0.71          94.0
# ...

# %% [markdown]
# Взаимосвязь с другими данными не наблюдается, скорей всего технический фактор.
#
# Попробуем заполнить года сопоставимые с годами по названию игр.

# %%
import warnings # убираем предупреждения

warnings.filterwarnings('ignore')

for i in df[df['year_of_release'].isnull() == True].index:  
    df['year_of_release'][i] = df.loc[df['name'] == df['name'][i], 'year_of_release'].max()

# %% [markdown]
# Посмотрим характер оставшихся пропусков

# %%
df[df['year_of_release'].isna()]
# Out:
#                                            name platform  year_of_release  \
# 475                  wwe Smackdown vs. Raw 2006      PS2              NaN
# 627                                   Rock Band     X360              NaN
# 657    Frogger's Adventures: Temple of the Frog      GBA              NaN
# 805                                   Rock Band      Wii              NaN
# 1142                                  Rock Band      PS3              NaN
# ...                                         ...      ...              ...
# 16277           Homeworld Remastered Collection       PC              NaN
# 16288                                    Shorts       DS              NaN
# 16348              Agarest Senki: Re-appearance      PS3              NaN
# 16458               Hakuouki: Shinsengumi Kitan      PS3              NaN
# 16522                              Virtua Quest       GC              NaN
#
#               genre  na_sales  eu_sales  jp_sales  other_sales  critic_score  \
# ...

# %% [markdown]
# Посмотрим характер оставшихся пропусков
# Попробуем заполнить года сопоставимые с годами по появлению игр на платформах.

# %%
for i in df[df['year_of_release'].isnull() == True].index:  
    df['year_of_release'][i] = df.loc[df['genre'] == df['genre'][i], 'year_of_release'].max()

# %%
# Посмотрим сколько удалось заполнить пустых значений

df['year_of_release'].isna().sum()
# Out:
# 0

# %% [markdown]
# Доля не значительная, оставим пока как есть.

# %%
# Рассмотрим характер пропущенных значении в столбце "critic_score"

df[df['critic_score'].isna()]
# Out:
#                                 name platform  year_of_release         genre  \
# 1                  Super Mario Bros.      NES           1985.0      Platform
# 4           Pokemon Red/Pokemon Blue       GB           1996.0  Role-Playing
# 5                             Tetris       GB           1989.0        Puzzle
# 9                          Duck Hunt      NES           1984.0       Shooter
# 10                        Nintendogs       DS           2005.0    Simulation
# ...                              ...      ...              ...           ...
# 16710  Samurai Warriors: Sanada Maru      PS3           2016.0        Action
# 16711               LMA Manager 2007     X360           2006.0        Sports
# 16712        Haitaka no Psychedelica      PSV           2016.0     Adventure
# 16713               Spirits & Spells      GBA           2003.0      Platform
# 16714            Winning Post 8 2016      PSV           2016.0    Simulation
#
# ...

# %% [markdown]
# ##### critic_score

# %% [markdown]
# Взаимосвязь с другими данными не наблюдается, возможно технический фактор. По годам период разброса большой.
#
# Заполним значение сопоставимые с critic_score по названию игр.

# %%
for i in df[df['critic_score'].isnull() == True].index:  
    df['critic_score'][i] = df.loc[df['name'] == df['name'][i], 'critic_score'].max()

# %%
# Посмотрим сколько удалось заполнить пустых значений

df['critic_score'].isna().sum()
# Out:
# 7617

# %% [markdown]
# Оставшиеся значения заменим на (-1), это даст нам возможность фильтрации и не перепутать с другими значениями.

# %%
df['critic_score'] = df['critic_score'].fillna(-1)

print('Пропущенных значений в critic_score:',  df['critic_score'].isna().sum())
# Out:
# Пропущенных значений в critic_score: 0

# %% [markdown]
# ##### user_scoreuser_score и значение "tbd"

# %%
# Рассмотрим характер пропущенных значении в столбце "user_score"

df[df['user_score'].isna()]
# Out:
#                                 name platform  year_of_release         genre  \
# 1                  Super Mario Bros.      NES           1985.0      Platform
# 4           Pokemon Red/Pokemon Blue       GB           1996.0  Role-Playing
# 5                             Tetris       GB           1989.0        Puzzle
# 9                          Duck Hunt      NES           1984.0       Shooter
# 10                        Nintendogs       DS           2005.0    Simulation
# ...                              ...      ...              ...           ...
# 16710  Samurai Warriors: Sanada Maru      PS3           2016.0        Action
# 16711               LMA Manager 2007     X360           2006.0        Sports
# 16712        Haitaka no Psychedelica      PSV           2016.0     Adventure
# 16713               Spirits & Spells      GBA           2003.0      Platform
# 16714            Winning Post 8 2016      PSV           2016.0    Simulation
#
# ...

# %% [markdown]
# Взаимосвязь с другими данными не наблюдается, скорей всего технический фактор.
#
# Проверим на уникальные значения.

# %%
df['user_score'].value_counts()
# Out:
# tbd    2424
# 7.8     324
# 8       290
# 8.2     282
# 8.3     254
#        ...
# 1.1       2
# 1.9       2
# 9.6       2
# 0         1
# 9.7       1
# Name: user_score, Length: 96, dtype: int64

# %% [markdown]
# Имеется значение **tbd**
# 'tbd' означает to be determinated, то есть пока не определен.
#
# **TBD - аббревиатура от английского To Be Determined (будет определено) или To Be Decided (будет решено).
# Используется, если какая-то информация еще не определена или решение по вопросу не принято.
# Акроним служит для отметки неясностей или пропусков, которые надо заполнить, в информации требований.**
#
# По логики неопределённости значение отсутствует, tbd заменяем на NaN для дальнейшего анализа.

# %%
df = df.replace({'user_score' : 'tbd' }, np.nan)

# %%
# check
len(df[df['user_score'] == 'tbd'])
# Out:
# 0

# %% [markdown]
# ##### Замена в столбце 'user_score' тип значения object на float

# %%
df['user_score'] = df['user_score'].astype('float')

# %% [markdown]
# Заполним значение сопоставимые с user_score по названию игр.

# %%
for i in df[df['user_score'].isnull() == True].index:  
    df['user_score'][i] = df.loc[df['name'] == df['name'][i], 'user_score'].max()

# %%
# Посмотрим сколько удалось заполнить пустых значений

df['user_score'].isna().sum()
# Out:
# 8026

# %% [markdown]
# Оставшиеся значения заменим на (-1), это даст нам возможность фильтрации и не перепутать с другими значениями.

# %%
df['user_score'] = df['user_score'].fillna(-1)

print('Пропущенных значений в user_score:',  df['user_score'].isna().sum())
# Out:
# Пропущенных значений в user_score: 0

# %% [markdown]
# ##### user_score

# %%
# Рассмотрим характер пропущенных значении в столбце "user_score"

df[df['rating'].isna()]
# Out:
#                                 name platform  year_of_release         genre  \
# 1                  Super Mario Bros.      NES           1985.0      Platform
# 4           Pokemon Red/Pokemon Blue       GB           1996.0  Role-Playing
# 5                             Tetris       GB           1989.0        Puzzle
# 9                          Duck Hunt      NES           1984.0       Shooter
# 10                        Nintendogs       DS           2005.0    Simulation
# ...                              ...      ...              ...           ...
# 16710  Samurai Warriors: Sanada Maru      PS3           2016.0        Action
# 16711               LMA Manager 2007     X360           2006.0        Sports
# 16712        Haitaka no Psychedelica      PSV           2016.0     Adventure
# 16713               Spirits & Spells      GBA           2003.0      Platform
# 16714            Winning Post 8 2016      PSV           2016.0    Simulation
#
# ...

# %% [markdown]
# Взаимосвязь с другими данными не наблюдается, скорей всего технический фактор.

# %%
df['rating'].value_counts()
# Out:
# E       3990
# T       2961
# M       1563
# E10+    1420
# EC         8
# K-A        3
# RP         3
# AO         1
# Name: rating, dtype: int64

# %%
df['rating'] = df['rating'].fillna('Unknown') # pаменяем пропущенные значения в столбце 'rating' на 'Unknown'.

print('Пропущенных значений в rating:',  df['rating'].isna().sum())
# Out:
# Пропущенных значений в rating: 0

# %%
# Выводим пропущенные значения

df.isna().sum()
# Out:
# name               2
# platform           0
# year_of_release    0
# genre              2
# na_sales           0
# eu_sales           0
# jp_sales           0
# other_sales        0
# critic_score       0
# user_score         0
# rating             0
# dtype: int64

# %% [markdown]
# ##### name

# %%
# Рассмотрим характер пропущенных значении в столбце "name"

df[df['name'].isna()]
# Out:
#       name platform  year_of_release genre  na_sales  eu_sales  jp_sales  \
# 659    NaN      GEN           1993.0   NaN      1.78      0.53      0.00
# 14244  NaN      GEN           1993.0   NaN      0.00      0.00      0.03
#
#        other_sales  critic_score  user_score   rating
# 659           0.08          -1.0        -1.0  Unknown
# 14244         0.00          -1.0        -1.0  Unknown

# %% [markdown]
# Пропущенные значения на платформе "GEN" в 1993 году совпадают с пропусками в genre
#
# Посмотрим какие игры появились на платформе "GEN" в 1993 году

# %%
df_gen_1993 = df.loc[(df['platform'] == 'GEN') & (df['year_of_release'] == 1993.0)]

df_gen_1993
# Out:
#                                                     name platform  \
# 659                                                  NaN      GEN
# 7885                                    Shining Force II      GEN
# 8893                             Super Street Fighter II      GEN
# 11986                            Ecco: The Tides of Time      GEN
# 12098  Street Fighter II': Special Champion Edition (...      GEN
# 12264                                  Streets of Rage 3      GEN
# 12984                                    Dynamite Headdy      GEN
# 13343                                       Beyond Oasis      GEN
# 14244                                                NaN      GEN
#
#        year_of_release         genre  na_sales  eu_sales  jp_sales  \
# 659             1993.0           NaN      1.78      0.53      0.00
# 7885            1993.0      Strategy      0.00      0.00      0.19
# 8893            1993.0      Fighting      0.00      0.00      0.15
# ...

# %%
print('На платформе GEN в 1993 году игр появилось:', df_gen_1993['name'].value_counts().sum())
# Out:
# На платформе GEN в 1993 году игр появилось: 7

# %% [markdown]
# Посмотрим какие игры появильь в 1993 году

# %%
df_1993 = df.loc[df['year_of_release'] == 1993.0] 

df_1993
# Out:
#                           name platform  year_of_release         genre  \
# 56       Super Mario All-Stars     SNES           1993.0      Platform
# 476                   Star Fox     SNES           1993.0       Shooter
# 659                        NaN      GEN           1993.0           NaN
# 852    Super Street Fighter II     SNES           1993.0      Fighting
# 892           Mortal Kombat II     SNES           1993.0      Fighting
# ...                        ...      ...              ...           ...
# 12997         Pachinko Wars II     SNES           1993.0          Misc
# 13189      Keiba Eight Special     SNES           1993.0        Sports
# 13343             Beyond Oasis      GEN           1993.0  Role-Playing
# 14244                      NaN      GEN           1993.0           NaN
# 16207      Rock N' Roll Racing     SNES           1993.0        Racing
#
#        na_sales  eu_sales  jp_sales  other_sales  critic_score  user_score  \
# ...

# %%
print('В 1993 году новых игр появилось:', df_1993['name'].value_counts().sum())
# Out:
# В 1993 году новых игр появилось: 60

# %%
# check name duplicated

df_1993['name'].duplicated().sum()
# Out:
# 2

# %% [markdown]
# Посмотрим перечень других игр

# %%
n = set(df_1993.name) - set(df_gen_1993.name)
print('Оставшийся количество игр:', len(n)) 
print()
print('Cписок игр:', n)
# Out:
# Оставшийся количество игр: 52
#
# ...

# %% [markdown]
# Выяснить к какой игре и какому жанру принадлежат пропущенные значения не удалось, скорей всего по техническим причинам.

# %% [markdown]
# Заменим пропущенные значения в столбцах 'name' и 'genre' на 'Unknown'.

# %%
df['name'] = df['name'].fillna('Unknown')

print('Пропущенных значений в name:',  df['name'].isna().sum())
# Out:
# Пропущенных значений в name: 0

# %%
df['genre'] = df['genre'].fillna('Unknown')

print('Пропущенных значений в genre:',  df['genre'].isna().sum())
# Out:
# Пропущенных значений в genre: 0

# %% [markdown]
# Визуализируем пропущенные значения

# %%
def percent_hbar(df, old_threshold=None):
    percent_of_nulls = (df.isnull().sum()/len(df)*100).sort_values().round(2)
    threshold = percent_of_nulls.mean()
    ax = percent_of_nulls.plot(kind='barh', figsize=(17, 5), title='% of NaN (из {} строк)'.format(len(df)), 
                               color='#86bf91', legend=False, fontsize=12)
    ax.set_xlabel('Count of NaN')
    dict_percent = dict(percent_of_nulls)
    i = 0
    for k in dict_percent:
        color = 'blue'
        if dict_percent[k] > 0:
            if dict_percent[k] > threshold:
                color = 'red'
            ax.text(dict_percent[k]+0.1, i + 0.09, str(dict_percent[k])+'%', color=color, 
                    fontweight='bold', fontsize='large')
        i += 0.98
    if old_threshold is not None:
        plt.axvline(x=old_threshold,linewidth=1, color='r', linestyle='--')
        ax.text(old_threshold+0.3, 10, '{0:.2%}'.format(old_threshold/100), color='r', fontweight='bold', fontsize='large')
        plt.axvline(x=threshold,linewidth=1, color='green', linestyle='--')
        ax.text(threshold+0.3, 7, '{0:.2%}'.format(threshold/100), color='green', fontweight='bold', fontsize='large')
    else:
        plt.axvline(x=threshold,linewidth=1, color='r', linestyle='--')
        ax.text(threshold+0.3, 7, '{0:.2%}'.format(threshold/100), color='r', fontweight='bold', fontsize='large')
    ax.set_xlabel('')
    return ax, threshold

plot, threshold = percent_hbar(df)
plt.title("ДОЛЯ ПРОПУСКОВ")
plt.xlabel("Проценты")
plt.ylabel("ПОЗИЦИИ")
plt.show()

# %%
# check
df.isna().sum()
# Out:
# name               0
# platform           0
# year_of_release    0
# genre              0
# na_sales           0
# eu_sales           0
# jp_sales           0
# other_sales        0
# critic_score       0
# user_score         0
# rating             0
# dtype: int64

# %% [markdown]
# ##### Вывод   обработки пропущенных значений
#
# Пропущенные значения удалось заполнит по аналогии совпадающих данных и путем прямой замены на (-1).
# Пропущенные значения удалось заполнит в столбце 'rating' путем прямой замены на 'Unknown'.
# Заменил пропущенные значения в столбцах 'name' и 'genre' на 'Unknown'
# Характер пропущенных значений и данные по другим позициям не позволили избавиться от пропусков ценой потери других данных.
# 0.00 % составляет доля пропусков.
# В целом датафрейм готов к дальнейшему анализу и обработки данных.

# %% [markdown]
# #### Суммарные продажи в регионах
#
# Добавляем столбец 'total_sales' с суммой продаж игр во всех регионах.

# %%
df['total_sales'] = df[['na_sales','eu_sales', 'jp_sales','other_sales']].sum(axis = 1)
df.head()
# Out:
#                        name platform  year_of_release         genre  na_sales  \
# 0                Wii Sports      Wii           2006.0        Sports     41.36
# 1         Super Mario Bros.      NES           1985.0      Platform     29.08
# 2            Mario Kart Wii      Wii           2008.0        Racing     15.68
# 3         Wii Sports Resort      Wii           2009.0        Sports     15.61
# 4  Pokemon Red/Pokemon Blue       GB           1996.0  Role-Playing     11.27
#
#    eu_sales  jp_sales  other_sales  critic_score  user_score   rating  \
# 0     28.96      3.77         8.45          76.0         8.0        E
# 1      3.58      6.81         0.77          -1.0        -1.0  Unknown
# 2     12.76      3.79         3.29          82.0         8.3        E
# 3     10.93      3.28         2.95          80.0         8.0        E
# 4      8.89     10.22         1.00          -1.0        -1.0  Unknown
#
#    total_sales
# 0        82.54
# 1        40.24
# 2        35.52
# ...

# %%
# check
print('Общее количество проданных копий во всех регионах:', df['total_sales'].sum(), 'млн. копий')
# Out:
# Общее количество проданных копий во всех регионах: 8915.71 млн. копий

# %% [markdown]
# ### Исследовательский анализ данных
# #### Количество игр выпускаемое в разные годы

# %%
sales_years =  df.groupby(['year_of_release'])['name'].count()

sales_years.sort_index(ascending = False).head(15)
# Out:
# year_of_release
# 2016.0     648
# 2015.0     606
# 2014.0     582
# 2013.0     547
# 2012.0     662
# 2011.0    1153
# 2010.0    1271
# 2009.0    1431
# 2008.0    1440
# 2007.0    1202
# 2006.0    1020
# 2005.0     947
# 2004.0     765
# 2003.0     785
# 2002.0     845
# Name: name, dtype: int64

# %% [markdown]
# Для визуализации напишем функцию построения диаграммы

# %%
def create_any_bar(groupby_column, func, y='name'):
    plt.style.use('seaborn-pastel')
    df_to_plot = df.groupby(groupby_column)[y]
    if func == 'count':
        df_to_plot_calculated = df_to_plot.count()
        figsize = (15,5)
        plot = df_to_plot_calculated.plot(kind='bar', y=y, figsize=figsize, ec='black')
    elif func == 'sum':
        df_to_plot_calculated = df_to_plot.sum().sort_values()
        figsize = (15,10)
        plot = df_to_plot_calculated.plot(kind='barh', y=y, figsize=figsize, ec='black')

# %%
# визуализируем
create_any_bar('year_of_release', 'count')
plt.title("КОЛИЧЕСТВО ИГР ВЫПУЩЕННЫХ В РАЗНЫЕ ГОДЫ")
plt.xlabel("year_of_release")
plt.ylabel("Количество млн.")
plt.show()

# %% [markdown]
# ##### Вывод:
# Из графика видно:
# 1980 - 1990 года выпуски игр не значительны;
# 1991 - 2008 наблюдаетс рост объема выпуска игр;
# 2008 - 2009 пиковое значение количества игр;
# 2010 - 2016 резкое снижения с незначительным положительным скачком в 2014 -2015 годах.

# %% [markdown]
# #### Продажи по платформам

# %%
# Суммарные продажи по платформам
groupby_platform = df.groupby(['platform'])['total_sales'].sum().sort_values(ascending = False)
top_platforms = groupby_platform.head(6)

print('Платформы с наибольшими суммарными продажами:')
top_platforms
# Out:
# Платформы с наибольшими суммарными продажами:
# platform
# PS2     1255.77
# X360     971.42
# PS3      939.65
# Wii      907.51
# DS       806.12
# PS       730.86
# Name: total_sales, dtype: float64

# %%
# визуализируем
create_any_bar('platform', 'sum', 'total_sales')
plt.title("СУММАРНЫЕ ПРОДАЖИ ИГР ПО ПЛАТФОРМАМ")
plt.xlabel("Количество млн.")
plt.ylabel("platform")
plt.show()

# %%
# Словарь с платформами с наибольшими продажами
dict_platforms  =  top_platforms.reset_index()['platform']
dict_platforms.head(6)
# Out:
# 0     PS2
# 1    X360
# 2     PS3
# 3     Wii
# 4      DS
# 5      PS
# Name: platform, dtype: object

# %% [markdown]
# Распределение суммарной продажи по годам

# %%
# Срез данных по словарю с большим количеством продаж и его группировка по платформам
platforms = df.query('platform in @top_platforms.index')[['year_of_release' , 'platform']].groupby('platform')

# Построение плотностей частоты для платформ с большим количеством суммарными продажами
for platform, platforms_df in platforms:
    subset = platforms.get_group(platform) 
    subset['year_of_release'].plot(  kind = 'density' ,  grid = True, figsize = (15,7),
                                    linewidth = 4, alpha = 1, xlim = (1993, 2018), legend = True, 
                                  )
    plt.legend( dict_platforms)
plt.title("Полтночть частоты для платформ с большем количеством сумарных продаж")
plt.xlabel("ГОД")
plt.ylabel("ПЛОТНОСТЬ")
plt.show()

# %% [markdown]
# ##### Вывод:
# Наибольшая пиковая плотность наблюдается в период с 2006 по 2011 года.
# Жизненный цикл игр находится в промежутке 5 - 7, максимум 10 лет.
# Через каждые 5 лет появляются новые платформы, наибольшее количество новых платформ появилось в 2005 году.
#
# #### Актуальный период
# Исходя из предыдущего вывода можно определить, что актуальный период анализа для прогнозирование на 2017 год целесообразно определить период с 2012 г, для того чтобы нагляднее посмотреть на динамику продаж.
#
# Сформируем датасет с актуальным периодом.

# %%
actual_period = df.query(' year_of_release > 2012')
actual_period.head()
# Out:
#                          name platform  year_of_release         genre  \
# 16         Grand Theft Auto V      PS3           2013.0        Action
# 23         Grand Theft Auto V     X360           2013.0        Action
# 31  Call of Duty: Black Ops 3      PS4           2015.0       Shooter
# 33        Pokemon X/Pokemon Y      3DS           2013.0  Role-Playing
# 42         Grand Theft Auto V      PS4           2014.0        Action
#
#     na_sales  eu_sales  jp_sales  other_sales  critic_score  user_score  \
# 16      7.02      9.09      0.98         3.96          97.0         8.2
# 23      9.66      5.14      0.06         1.41          97.0         8.1
# 31      6.03      5.86      0.36         2.38          -1.0        -1.0
# 33      5.28      4.19      4.35         0.78          -1.0        -1.0
# 42      3.96      6.31      0.38         1.97          97.0         8.3
#
#      rating  total_sales
# 16        M        21.05
# 23        M        16.27
# 31  Unknown        14.63
# ...

# %% [markdown]
# Выведим платформы лидируют по продажам после 2012 года.

# %%
purchase_rating = actual_period.groupby('platform')['total_sales'].sum().sort_values(ascending = False )
print('Лидирующие платформы после 2012 года')
purchase_rating
# Out:
# Лидирующие платформы после 2012 года
# platform
# PS4     314.14
# PS3     185.89
# XOne    159.32
# 3DS     143.72
# X360    141.61
# WiiU     64.63
# PC       40.72
# PSV      33.25
# Wii      17.86
# PS2       8.61
# 2600      7.97
# PSP       4.22
# GBA       4.12
# DS        3.38
# PS        3.28
# XB        1.05
# GB        1.03
# GC        0.27
# N64       0.20
# Name: total_sales, dtype: float64

# %% [markdown]
# Формируем распределение суммарной продажи по годам за период с 2013 - 2016 годы.

# %%
purchase_dinamics = actual_period.groupby(['platform' , 'year_of_release'])['total_sales'].sum()
purchase_dinamics
# Out:
# platform  year_of_release
# 2600      2016.0               7.97
# 3DS       2013.0              56.57
#           2014.0              43.76
#           2015.0              27.78
#           2016.0              15.61
# DS        2013.0               1.54
#           2016.0               1.84
# GB        2016.0               1.03
# GBA       2016.0               4.12
# GC        2016.0               0.27
# N64       2016.0               0.20
# PC        2013.0              12.66
#           2014.0              13.63
#           2015.0               8.52
#           2016.0               5.91
# PS        2016.0               3.28
# PS2       2016.0               8.61
# PS3       2013.0             113.25
#           2014.0              47.76
#           2015.0              16.82
#           2016.0               8.06
# PS4       2013.0              25.99
#           2014.0             100.00
#           2015.0             118.90
#           2016.0              69.25
# ...

# %% [markdown]
# Создадим словарь платформ с наибольшими продажами после 2012 года

# %%
dict_platforms = purchase_rating.reset_index().platform
dict_platforms
# Out:
# 0      PS4
# 1      PS3
# 2     XOne
# 3      3DS
# 4     X360
# 5     WiiU
# 6       PC
# 7      PSV
# 8      Wii
# 9      PS2
# 10    2600
# 11     PSP
# 12     GBA
# 13      DS
# 14      PS
# 15      XB
# 16      GB
# 17      GC
# 18     N64
# Name: platform, dtype: object

# %% [markdown]
# Сгруппируем по платформам и построим график суммарных продаж.

# %%
dinamics = purchase_dinamics.groupby('platform')

for platform, purchase_df in dinamics :
    subset = dinamics.get_group(platform) 
    subset.plot( x= 'year_of_release'  ,  y = 'sales_total',  kind = 'line' ,  grid = True, figsize = (15,7),
                                    linewidth = 4, alpha = 1,  legend = True, 
                                  )
    plt.legend(dict_platforms)
plt.title("Суммарная продажа по платформам")

plt.show()

# %%
actual_period_2016 = df.query(' year_of_release == 2016')
purchase_rating_2016 = actual_period_2016.groupby('platform')['total_sales'].sum().sort_values(ascending = False )
print('За последний год лидируют по продажам:')
purchase_rating_2016.head(4)
# Out:
# За последний год лидируют по продажам:
# platform
# PS4     69.25
# XOne    26.15
# 3DS     15.61
# PS2      8.61
# Name: total_sales, dtype: float64

# %% [markdown]
# ##### Вывод:
# У всех платформ наблюдается отрицательная динамика продаж, стремящееся к нулю в одной точке 2017-2018.
# **С большей вероятностью к 2018 году все платформы прекратят свое существование.**

# %% [markdown]
# #### Глобальные продажи игр в разбивке по платформам

# %% [markdown]
# Построим график

# %%
for column in ['platform']:    
    g = sns.catplot(y='platform', x='total_sales', kind="box", data = actual_period, orient='h', palette = 'pastel')
    plt.xlim(0,2)
    g.fig.set_figwidth(25)
    g.fig.set_figheight(10)
plt.title("ГЛОБАЛЬНЫЕ ПРОДАЖИ ИГР В РАЗБИВКЕ ПО ПЛАТФОРМАМ")
plt.xlabel("sales_total")
plt.ylabel("platform")
plt.show()

# %% [markdown]
# ##### Вывод
# Медиана по топовым платформам варьируется от 0,2 до 0,25 млн. копий.
# Это говорит о высокой конкуренций среды разных платформ.
# Верхняя граница предела, за которыми уже определяются аномалии, у двух платформ - PS4 и X360 - на уровне 1,7 млн. сопий.
# У 4 платформ от 1, 2 до 1,5 млн.
# Среди всех выделяется PSP: показатели ниже всех. Медиана совпадает с нижним показателем,
# верхняя граница - 0,15 млн.,
# выбросы не превышают 0,25

# %% [markdown]
# #### Диаграмма рассеяния и корреляция

# %% [raw]
# Возьмём для анализа платформу по max показателям платформу "x360".
# Постоим диаграмму рассеяния продажи от отзывов критиков.

# %%
x360_df = actual_period.query('platform == "X360"')

x360_df .plot(x='total_sales', y='critic_score', kind='hexbin', 
              gridsize=30, figsize=(15, 7), sharex=False, grid=True)
plt.title("Диаграмма рассеяния critic_score")
plt.show()

# %%
# sheck
actual_period.isna().sum()
# Out:
# name               0
# platform           0
# year_of_release    0
# genre              0
# na_sales           0
# eu_sales           0
# jp_sales           0
# other_sales        0
# critic_score       0
# user_score         0
# rating             0
# total_sales        0
# dtype: int64

# %%
from matplotlib.axes._axes import _log as matplotlib_axes_logger
matplotlib_axes_logger.setLevel('ERROR')

games_ps3 = actual_period[(actual_period['platform'] == 'PS3') & (actual_period['critic_score'] > 0)].copy()
games_ps3.plot(kind='scatter', x='total_sales', y='critic_score', ec='black', figsize=(10,6))
plt.title("Диаграмма рассеяния critic_score")
plt.show()

# %% [markdown]
# ##### Вывод:
# Не смотря на большое количество отсутствующих значений:
# Из диаграммы рассеяния следует что отзывов критиков не вляют сушественно на продажи по скольку практически весь диапазон отзивов не меняет тенденци продаж.

# %% [markdown]
# Диаграмма рассеяния продажи от отзывов пользователей

# %%
x360_df .plot(x='total_sales', y='user_score', kind='hexbin', 
              gridsize=30, figsize=(15, 7), sharex=False, grid=True )
plt.title("Диаграмма рассеяния user_score")
plt.show()

# %%
from matplotlib.axes._axes import _log as matplotlib_axes_logger
matplotlib_axes_logger.setLevel('ERROR')

games_ps3 = actual_period[(actual_period['platform'] == 'PS3') & (actual_period['critic_score'] > 0)].copy()
games_ps3.plot(kind='scatter', x='total_sales', y='critic_score', ec='black', figsize=(10,6))
plt.title("Диаграмма рассеяния critic_score")
plt.show()

# %% [markdown]
# ##### Вывод:
# Не смотря на большое количество отсутствующих значений:
# Из диаграммы рассеяния следует что отзывов пользователей не вляют сушественно на продажи по скольку практически весь диапазон отзивов не меняет тенденци продаж.

# %% [markdown]
# #### Матрица кореляции

# %% [markdown]
# Создадим матрицу кореляции

# %%
plt.figure(figsize=(15,5))
sns.heatmap(actual_period.corr(), annot=True, cmap="Greens", fmt='.2f', annot_kws={'size':20})
plt.title("Матрица корреляции")
plt.show()

# %% [markdown]
# ##### Вывод:
# Значение r – Пирсона характеризует уровень связи между переменными:
# Коэффициент корреляции со знаком (-0.07) означает слабую отрицательную корреляцию;
# в остальных случаях:
# 0,75 – 1.00 очень высокая положительная
# 0,50 – 0.74 высокая положительная
# 0,25 – 0.49 средняя положительная
# 0,00 – 0.24 слабая положительная

# %% [markdown]
# #### Корреляция между отзывами и продажами

# %% [markdown]
# Выводим корреляцию между отзывами критиков и продажами.

# %%
corelation = actual_period.groupby('platform')
for platform, purchase_df in corelation :
    subset = corelation.get_group(platform) 
    coef_corr = subset.total_sales.corr(subset.critic_score).round(3)
    print('Коэффициент кореляции отзывов критиков' , platform , ':', coef_corr.round(3))
    print()
# Out:
# Коэффициент кореляции отзывов критиков 2600 : nan
#
# Коэффициент кореляции отзывов критиков 3DS : 0.05
#
# Коэффициент кореляции отзывов критиков DS : 0.456
#
# Коэффициент кореляции отзывов критиков GB : nan
#
# Коэффициент кореляции отзывов критиков GBA : -0.004
#
# Коэффициент кореляции отзывов критиков GC : -0.98
#
# Коэффициент кореляции отзывов критиков N64 : nan
#
# Коэффициент кореляции отзывов критиков PC : 0.196
#
# Коэффициент кореляции отзывов критиков PS : 0.04
#
# Коэффициент кореляции отзывов критиков PS2 : -0.008
#
# Коэффициент кореляции отзывов критиков PS3 : 0.271
#
# Коэффициент кореляции отзывов критиков PS4 : 0.219
#
# Коэффициент кореляции отзывов критиков PSP : 0.486
#
# Коэффициент кореляции отзывов критиков PSV : 0.355
#
# Коэффициент кореляции отзывов критиков Wii : 0.546
#
# Коэффициент кореляции отзывов критиков WiiU : 0.254
#
# Коэффициент кореляции отзывов критиков X360 : 0.205
#
# Коэффициент кореляции отзывов критиков XB : 0.742
#
# ...

# %% [markdown]
# Выводим корреляцию между отзывами пользователей и продажами.

# %%
corelation = actual_period.groupby('platform')
for platform, purchase_df in corelation :
    subset = corelation.get_group(platform) 
    coef_corr = subset.total_sales.corr(subset.user_score).round(3)
    print('Коэффициент кореляции отзывов пользователей' , platform , ':', coef_corr.round(3))
    print()
# Out:
# Коэффициент кореляции отзывов пользователей 2600 : nan
#
# Коэффициент кореляции отзывов пользователей 3DS : 0.033
#
# Коэффициент кореляции отзывов пользователей DS : 0.457
#
# Коэффициент кореляции отзывов пользователей GB : nan
#
# Коэффициент кореляции отзывов пользователей GBA : -0.394
#
# Коэффициент кореляции отзывов пользователей GC : -0.625
#
# Коэффициент кореляции отзывов пользователей N64 : nan
#
# Коэффициент кореляции отзывов пользователей PC : 0.056
#
# Коэффициент кореляции отзывов пользователей PS : 0.032
#
# Коэффициент кореляции отзывов пользователей PS2 : -0.041
#
# Коэффициент кореляции отзывов пользователей PS3 : 0.174
#
# Коэффициент кореляции отзывов пользователей PS4 : 0.101
#
# Коэффициент кореляции отзывов пользователей PSP : 0.452
#
# Коэффициент кореляции отзывов пользователей PSV : 0.322
#
# Коэффициент кореляции отзывов пользователей Wii : 0.468
#
# Коэффициент кореляции отзывов пользователей WiiU : 0.219
#
# ...

# %%
games_ps3_filtered = actual_period[['total_sales' ,'critic_score', 'user_score']]

# %%
plt.figure(figsize=(3,3))
sns.heatmap(games_ps3_filtered.corr()[['total_sales']].sort_values(by='total_sales', ascending=False), cmap="Greens", 
            annot=True, annot_kws={'size':15})
# Out:
# <AxesSubplot:>

# %% [markdown]
# Сильнее всего на конечную стоимость влияет оценка критиков. Меньше всего влияет - оценка пользователей.

# %%
dict_platforms
# Out:
# 0      PS4
# 1      PS3
# 2     XOne
# 3      3DS
# 4     X360
# 5     WiiU
# 6       PC
# 7      PSV
# 8      Wii
# 9      PS2
# 10    2600
# 11     PSP
# 12     GBA
# 13      DS
# 14      PS
# 15      XB
# 16      GB
# 17      GC
# 18     N64
# Name: platform, dtype: object

# %% [markdown]
# Данные корреляции по топовым платформам

# %%
top_platforms = ['PS4', 'PS3', 'XOne', '3DS', 'X360', 'WiiU', 'PC', 'PSV']
  
rows = len(top_platforms) // 2
cols = 2
fig, axes = plt.subplots(rows, cols, figsize=(10,10))
count = 0

for r in range(rows):
    for c in range(cols):
        curr_platform = top_platforms[count]
        df_prep = actual_period[(actual_period['platform'] == curr_platform) & (actual_period['user_score'] > 0)].copy()
        
        df_filtered = df_prep[['total_sales' ,'critic_score', 'user_score']]
        sns.set(font_scale=1.0)
        ax = sns.heatmap(df_filtered.corr()[['total_sales']].sort_values(by='total_sales', ascending=False), 
                         cmap="Greens", annot=True, annot_kws={'size':15}, ax=axes[r,c])
        ax.set_title(curr_platform, fontsize=20)
        ax.set_yticklabels(ax.get_yticklabels(), rotation=0)
        plt.tight_layout(pad=3)        
        count += 1

# %% [markdown]
# ##### Вывод:
# Данные по корреляции между выручкой и оценкой по платформам PS4, XOne, 3DS, WiiU более или менее совпадает с общими данными по датафрейму.
# Выделяются PS и PSV, по которым зависимость не такая большая.
# Кстати, есть платформы, где оценка критиков, согласно данных, сильнее "определяет" конечную выручку продукта, чем оценка пользователей. Это платформы DS, PS4 и Xone. В случае с DS полагаю, что дело в том, что приставка азиатская, большую популярность она имеет там, соответственно, далеко не большая часть игроков принимает участие в оценке игр на эту платформу.
# Про PS и PSV - платформы довольно новые, вполне вероятно, что пользователи пока не "освоились", поэтому большого количества отзывов, особенно качественных от них нет.
#
# Так же можно отметить что положительные отзывы критиков влияет на продажи, но ее вклад является существенным.
# Коэффициент корреляции продаж от отзывов критиков больше чем коэффициент корреляция продажи от отзывов пользователей,
# это означает, что критики больше влияют на количество продаж.

# %% [markdown]
# #### Общее распределение игр по жанрам

# %% [markdown]
# Группируем датафрэйм по жанрам

# %%
purchase_genres = actual_period.groupby('genre')

dict_genres = purchase_genres.genre.unique()

for genre, purchase_df in purchase_genres :
    subset = purchase_genres.get_group(genre) 
    subset.total_sales.plot(  kind = 'density' , grid = True, figsize = (15,7),
                                    linewidth = 3, alpha = 1, legend = True , xlim = (-1,2)
                                  )
    plt.legend( dict_genres)
    plt.title("Плотьность распределения сумммарных продаж по жанрам")
plt.xlabel("sales_total")
plt.ylabel("Densiti")
plt.show()

# %%
ax = plt.gca()

pivot = actual_period.groupby('genre').agg({'name': 'count', 'total_sales': 'sum'}).sort_values(by='name', ascending=False)

plot1 = pivot['name']
plot1.plot(kind='bar', figsize=(15,5), ec='black', ax=ax, width=0.4, position=1)

plot2 = pivot['total_sales']
plot2.plot(kind='bar', figsize=(15,5), ec='black', ax=ax, width=0.4, color='#97F0AA', position=0)

ax.legend(['Количество продаж', 'Общая сумма продаж'])
plt.title("Распределение игр по жанрам")
plt.xlabel("sales_total")
plt.ylabel("Количество и сумма")
plt.show()

# %% [markdown]
# Выведем распределение игр по жанрам в цыфрах.

# %%
genre_count =  actual_period.groupby(['genre'])['name'].count().sort_values(ascending = False )
print('Лидеры по количеству:')
genre_count
# Out:
# Лидеры по количеству:
# genre
# Action          796
# Role-Playing    306
# Adventure       254
# Sports          229
# Shooter         199
# Misc            171
# Racing           98
# Fighting         87
# Platform         83
# Simulation       75
# Strategy         61
# Puzzle           24
# Name: name, dtype: int64

# %%
purchase_rating = actual_period.groupby('genre')['total_sales'].sum().sort_values(ascending = False )
print('Лидеры продаж:')
purchase_rating
# Out:
# Лидеры продаж:
# genre
# Action          331.04
# Shooter         235.41
# Sports          155.21
# Role-Playing    148.68
# Misc             71.16
# Platform         44.37
# Racing           42.74
# Fighting         39.25
# Adventure        27.88
# Simulation       23.27
# Strategy         11.06
# Puzzle            5.20
# Name: total_sales, dtype: float64

# %% [markdown]
# #### Вывод:
# Из графика следует что больше выпускается игры по жанрам Action, Role-Playing и Adventure, но в то же время продажи двух последних не отличаются высокими показателями.
#
# По выручке от продаж можно отметить самые прибыльные жанры Action, Shooter, Sports.
#
# Стоит отметить жанр Shooter, новых игр выпускаются меньше: 187, но количество проданных копий больше: 232.98 млн.,
# следовательно выручка выше чем у других жанров.
#
# Жанры с минимальными и максимальными показателями:
# По количеству выпускаемых игр
# Action          769
# Puzzle           17
# По количеству проданных копий (млн. копий)
# Action          322.5
# Puzzle            3.17

# %% [markdown]
# ### Портрет пользователя каждого региона
# #### Популярные платформы (топ-5)

# %% [markdown]
# Построим сводную таблицу по платформам и проддажам

# %%
rating_region = df.pivot_table(index = 'platform' , 
                            values = ['na_sales','eu_sales','jp_sales',
                                      'total_sales'], aggfunc = 'sum')

rating_region.head()
# Out:
#           eu_sales  jp_sales  na_sales  total_sales
# platform
# 2600          5.47      0.00     90.60        96.98
# 3DO           0.00      0.10      0.00         0.10
# 3DS          61.48    100.67     83.49       259.00
# DC            1.69      8.56      5.43        15.95
# DS          188.89    175.57    382.40       806.12

# %% [markdown]
# Добавляем столбцы с долями продажи

# %%
rating_region['na_ratio'] = rating_region.na_sales / rating_region.total_sales
rating_region['eu_ratio'] = rating_region.eu_sales / rating_region.total_sales
rating_region['jp_ratio'] = rating_region.jp_sales / rating_region.total_sales

rating_region.head()
# Out:
#           eu_sales  jp_sales  na_sales  total_sales  na_ratio  eu_ratio  \
# platform
# 2600          5.47      0.00     90.60        96.98  0.934213  0.056403
# 3DO           0.00      0.10      0.00         0.10  0.000000  0.000000
# 3DS          61.48    100.67     83.49       259.00  0.322355  0.237375
# DC            1.69      8.56      5.43        15.95  0.340439  0.105956
# DS          188.89    175.57    382.40       806.12  0.474371  0.234320
#
#           jp_ratio
# platform
# 2600      0.000000
# 3DO       1.000000
# 3DS       0.388687
# DC        0.536677
# DS        0.217796

# %% [markdown]
# Выводим топ 5 платформ по регионам

# %%
rating_na = rating_region[['na_sales', 'na_ratio']].sort_values(ascending = False,by = 'na_sales').head()
rating_eu = rating_region[['eu_sales', 'eu_ratio']].sort_values(ascending = False,by = 'eu_sales').head()
rating_jp = rating_region[['jp_sales', 'jp_ratio']].sort_values(ascending = False,by = 'jp_sales').head()

print('Продажи в Северной Америке (млн. проданных копий)')
print(rating_na) 
print()
print('Продажи в Европе (млн. проданных копий)')
print(rating_eu)
print()
print('Продажи в Японии (млн. проданных копий)')
print(rating_jp)
# Out:
# Продажи в Северной Америке (млн. проданных копий)
#           na_sales  na_ratio
# platform
# X360        602.47  0.620195
# PS2         583.84  0.464926
# Wii         496.90  0.547542
# PS3         393.49  0.418762
# DS          382.40  0.474371
#
# Продажи в Европе (млн. проданных копий)
#           eu_sales  eu_ratio
# platform
# PS2         339.29  0.270185
# PS3         330.29  0.351503
# X360        270.76  0.278726
# Wii         262.21  0.288933
# PS          213.61  0.292272
#
# Продажи в Японии (млн. проданных копий)
#           jp_sales  jp_ratio
# platform
# DS          175.57  0.217796
# PS          139.82  0.191309
# PS2         139.20  0.110848
# SNES        116.55  0.582633
# 3DS         100.67  0.388687

# %% [markdown]
# Визуализируем

# %%
def top_in_regions_plot(groupby, region_sales, ax):
    pivot = df.groupby(groupby).agg({region_sales: 'sum'}).sort_values(by=region_sales, ascending=False)[:5]
    title_dict = {'na_sales': 'North America Sales', 'eu_sales': 'Europe Sales', 'jp_sales': 'Japan Sales'}
    color_dict = {'na_sales': 'blue', 'eu_sales': 'green', 'jp_sales': 'red'}
    plot = pivot.plot(kind='bar', ec='black', title=title_dict[region_sales], ax=axes[ax], 
                   fontsize=18, color=color_dict[region_sales], rot=20)
    plot.legend(prop={'size':17})
    plot.set_xlabel('')
    plot.title.set_size(20)
    
fig, axes = plt.subplots(1, 3, figsize=(25,6))

top_in_regions_plot('platform', 'na_sales', 0)
top_in_regions_plot('platform', 'eu_sales', 1)
top_in_regions_plot('platform', 'jp_sales', 2)

# %% [markdown]
# ##### Вывод
# На основании полученных результатов можно сделать следующее заключение:
# В Северной Америке и Европе самыми популярными являются платформы: X360, PS2, Wii, PS3.
# Лидирует:
# в Северной Америке: X360 с показателем 602.47 и долей рынка 0.620195, это в два раза больше, чем в Европе;
# в Европе: PS2 с показателем 339.29 и долей рынка 0.270185.
#
# В Японии самыми популярными платформами являются DS, PS, PS2.
# Лидирует DS с показателем 175.57 и долей рынка 0.217796.
#
# Европейский и Азиатский сильно различаются по объему продаж и предпочтению платформ.
#
# Лидирует по всем показателем рынок Северной Америки, это самый большой рынок.

# %% [markdown]
# #### Популярные жанры (топ-5)

# %% [markdown]
# Выводим сводную таблицу по жанрам и и продажам.

# %%
purchase_genres = df.pivot_table(
    index = 'genre', 
    values= ['na_sales','eu_sales','jp_sales'], 
    aggfunc = ('sum'))

purchase_genres
# Out:
#               eu_sales  jp_sales  na_sales
# genre
# Action          519.13    161.43    879.01
# Adventure        63.54     52.30    105.26
# Fighting        100.33     87.48    223.36
# Misc            212.74    108.11    407.27
# Platform        200.35    130.83    445.50
# Puzzle           50.01     57.31    122.87
# Racing          236.51     56.71    359.35
# Role-Playing    188.71    355.41    330.81
# Shooter         317.34     38.76    592.24
# Simulation      113.52     63.80    181.92
# Sports          376.79    135.54    684.43
# Strategy         45.17     49.66     68.55
# Unknown           0.53      0.03      1.78

# %% [markdown]
# Выведим топ 5 жанров по регионам.

# %%
for row in purchase_genres:
    subset =  purchase_genres.reset_index()[['genre', row]].sort_values(by=row, ascending =False).head()
    print(subset)
    print()
# Out:
#       genre  eu_sales
# 0    Action    519.13
# 10   Sports    376.79
# 8   Shooter    317.34
# 6    Racing    236.51
# 3      Misc    212.74
#
#            genre  jp_sales
# 7   Role-Playing    355.41
# 0         Action    161.43
# 10        Sports    135.54
# 4       Platform    130.83
# 3           Misc    108.11
#
#        genre  na_sales
# 0     Action    879.01
# 10    Sports    684.43
# 8    Shooter    592.24
# 4   Platform    445.50
# 3       Misc    407.27

# %%
esrb_dict = {'E': 'Для всех', 'M': '> 17 лет', 'T': '13-19 лет', 'E10+': '>10 лет', 'K-A': 'E(шир.ауд.)'}

# %%
df['ESRB_description'] = df[df['rating'].notnull()]['rating'].map(esrb_dict)

# %%
fig, axes = plt.subplots(1, 3, figsize=(25,6))

top_in_regions_plot('genre', 'na_sales', 0)
top_in_regions_plot('genre', 'eu_sales', 1)
top_in_regions_plot('genre', 'jp_sales', 2)

# %% [markdown]
# ##### Вывод
# В регионах Северной Америки и Европы популярные жанры одинаковые, тройка жанров: Action, Sports, Shooter полностью совпадают.
# В Японии самым популярным жанром является Role-Playing , порядок популярности отличается, а именно жанр Role Playing занимает первое место.
#
# Стоит отметить, что одинаковый интерес проявляется во всех регионах к жанрам **Action и Sports**, это интересный факт.

# %% [markdown]
# #### Влияние рейтинга ESRB на продажи в отдельном регионе.

# %% [markdown]
# Выводим сводную таблицу рейтинга

# %%
rating_esrb = df.pivot_table(index = 'rating' , 
                            values = ['na_sales','eu_sales','jp_sales',
                                      'total_sales'], aggfunc = 'sum')

rating_esrb
# Out:
#          eu_sales  jp_sales  na_sales  total_sales
# rating
# AO           0.61      0.00      1.26         1.96
# E          710.25    198.11   1292.99      2435.52
# E10+       188.52     40.20    353.32       655.60
# EC           0.11      0.00      1.53         1.75
# K-A          0.27      1.46      2.56         4.32
# M          483.97     64.24    748.48      1473.79
# RP           0.08      0.00      0.00         0.09
# T          427.03    151.40    759.75      1493.35
# Unknown    613.83    841.96   1242.46      2849.33

# %% [markdown]
# Визуализируем
#
# Добавим новый столбец в основной датафрейм с разъяснением, какая буква рейтинга что означает:

# %%
esrb_dict = {'E': 'Для всех', 'M': '> 17 лет', 'T': '13-19 лет', 'E10+': '>10 лет', 'K-A': 'E(шир.ауд.)', 'Unknown': 'Unknown'}

# %%
df['ESRB_description'] = df[df['rating'].notnull()]['rating'].map(esrb_dict)

# %%
fig, axes = plt.subplots(1, 3, figsize=(25,6))

top_in_regions_plot('ESRB_description', 'na_sales', 0)
top_in_regions_plot('ESRB_description', 'eu_sales', 1)
top_in_regions_plot('ESRB_description', 'jp_sales', 2)

# %% [markdown]
# ### Гипотезы
#
# - Средние пользовательские рейтинги платформ Xbox One и PC одинаковые;
# - Средние пользовательские рейтинги жанров Action (англ. «действие», экшен-игры) и Sports (англ. «спортивные соревнования») разные.
#
# Для проверки гипотезы исползаем гипотезу о равенстве средних двух средних генеральных совокупностей.
#
# Для проверки обеих гипотез будем использовать **t-критерий Стьюдента**, т.к. в обоих случаях выборки независимы между собой.
# Определим пороговое значение alpha = 0.05
#
# #### Средние пользовательские рейтинги платформ Xbox One и PC

# %% [markdown]
# **Н0 (нулевая гипотеза)** - средние пользовательские рейтинги платформ Xbox One и PC одинаковые.
# **Н1 (альтернативная гипотеза)** - средние пользовательские рейтинги платформ Xbox One и PC отличаются между собой.

# %% [markdown]
# Сравниваем две совокупности рейтинга платформ Xbox One и PC

# %%
# Улалить
from scipy import stats as st
alpha = 0.05
results = st.ttest_ind(
    df['platform'] == 'XOne', 
    df['platform'] == 'PC')

print('p-значение: ', results.pvalue)

if (results.pvalue < alpha):
    print("Отвергаем нулевую гипотезу")
else:
    print("Не получилось отвергнуть нулевую гипотезу")
# Out:
# p-значение:  2.292409441369541e-100
# Отвергаем нулевую гипотезу

# %%
from scipy import stats as st
alpha = 0.05
results = st.ttest_ind(
    actual_period['platform'] == 'XOne', 
    actual_period['platform'] == 'PC')

print('p-значение: ', results.pvalue)

if (results.pvalue < alpha):
    print("Отвергаем нулевую гипотезу")
else:
    print("Не получилось отвергнуть нулевую гипотезу")
# Out:
# p-значение:  0.010946392265796474
# Отвергаем нулевую гипотезу

# %% [markdown]
# ##### Вывод
# **Средние пользовательские рейтинги платформ Xbox One и PC отличаются между собой.**
#
# Компьютерные игры получают оценки статистически значимо выше, чем игры для Xbox One.

# %% [markdown]
# #### Средние пользовательские рейтинги жанров Action и Sports
#
# - **Н0 (нулевая гипотеза)** - средние пользовательские рейтинги жанров Action и Sports одинаковые.
# - **Н1 (альтернативная гипотеза)** - средние пользовательские рейтинги жанров Action и Sports отличаются между собой.

# %%
# Улалить
from scipy import stats as st
alpha = 0.05
results = st.ttest_ind(
    df['genre'] == 'Action', 
    df['genre'] == 'Sports')

print('p-значение: ', results.pvalue)

if (results.pvalue < alpha):
    print("Отвергаем нулевую гипотезу")
else:
    print("Не получилось отвергнуть нулевую гипотезу")
# Out:
# p-значение:  6.471616971623874e-50
# Отвергаем нулевую гипотезу

# %%
from scipy import stats as st
alpha = 0.05
results = st.ttest_ind(
    actual_period['genre'] == 'Action', 
    actual_period['genre'] == 'Sports')

print('p-значение: ', results.pvalue)

if (results.pvalue < alpha):
    print("Отвергаем нулевую гипотезу")
else:
    print("Не получилось отвергнуть нулевую гипотезу")
# Out:
# p-значение:  1.0356179478871075e-92
# Отвергаем нулевую гипотезу

# %% [markdown]
# ##### Вывод
# **Средние пользовательские рейтинги жанров Action и Sports отличаются между собой.**

# %% [markdown]
# ### Общий вывод

# %% [markdown]
# ##### Общее количество проданных копий во всех регионах: 8915.71 млн.

# %%
create_any_bar('platform', 'sum', 'total_sales')
plt.title("СУММАРНЫЕ ПРОДАЖИ ИГР ПО ПЛАТФОРМАМ")
plt.xlabel("Количество млн.")
plt.ylabel("platform")
plt.show()

# %% [markdown]
# - Наибольшая пиковая плотность продаж наблюдается в период с 2006 по 2011 года.
# - Жизненный цикл игр находится в промежутке 5 - 7, максимум 10 лет.
# - Через каждые 5 лет появляются новые платформы, наибольшее количество новых платформ появилось в 2005 году.

# %% [markdown]
# ##### Распределение суммарной продажи по годам

# %%
for platform, platforms_df in platforms:
    subset = platforms.get_group(platform) 
    subset['year_of_release'].plot(  kind = 'density' ,  grid = True, figsize = (15,5),
                                    linewidth = 3, alpha = 1, xlim = (1993, 2018), legend = True, 
                                  )
    plt.legend( dict_platforms)
plt.title("Полтночть частоты для платформ с большем количеством сумарных продаж")
plt.xlabel("ГОДА")
plt.ylabel("ПЛОТНОСТЬ")
plt.show()

# %% [markdown]
# ##### Динамика продаж

# %%
for platform, purchase_df in dinamics :
    subset = dinamics.get_group(platform) 
    subset.plot( x= 'year_of_release'  ,  y = 'sales_total',  kind = 'line' ,  grid = True, figsize = (15,5),
                                    linewidth = 4, alpha = 1,  legend = True, 
                                  )
    plt.legend(dict_platforms)
plt.title("Суммарная продажа по платформам")

plt.show()

# %% [markdown]
# - У всех платформ наблюдается отрицательная динамика продаж, стремящееся к нулю в одной точке 2017-2018.
# **С большей вероятностью к 2018 году все платформы прекратят свое существование.**

# %% [markdown]
# ##### Глобальные продажи игр в разбивке по платформам

# %%
for column in ['platform']:    
    g = sns.catplot(y='platform', x='total_sales', kind="box", data = actual_period, orient='h', palette = 'pastel')
    plt.xlim(0,2)
    g.fig.set_figwidth(25)
    g.fig.set_figheight(10)
plt.title("ГЛОБАЛЬНЫЕ ПРОДАЖИ ИГР В РАЗБИВКЕ ПО ПЛАТФОРМАМ")
plt.xlabel("sales_total")
plt.ylabel("platform")
plt.show()

# %% [markdown]
# - Медиана по топовым платформам варьируется от 0,2 до 0,24 млн. копий.
# Это говорит о высокой конкуренций среды разных платформ.
# - Верхняя граница предела, за которыми уже определяются аномалии, у двух платформ - PS4 и X360 - на уровне 1,7 млн. сопий.
# У 4 платформ от 1, 2 до 1,5 млн.
# - Среди всех выделяется PSP: показатели ниже всех. Медиана совпадает с нижним показателем,
# верхняя граница - 0,15 млн.,
# выбросы не превышают 0,25

# %% [markdown]
# ##### Матрица кореляции

# %%
plt.figure(figsize=(15,5))
sns.heatmap(actual_period.corr(), annot=True, cmap="Greens", fmt='.2f', annot_kws={'size':20})
plt.title("Матрица корреляции")
plt.show()

# %% [markdown]
# Значение r – Пирсона характеризует уровень связи между переменными:
# - Коэфициент кореляции со знаком (-0.07) означает слабую отрицательную кореляцию;
# в остальных случаях:
# 0,75 – 1.00 очень высокая положительная
# 0,50 – 0.74 высокая положительная
# 0,25 – 0.49 средняя положительная
# 0,00 – 0.24 слабая положительная

# %% [markdown]
# ##### Данные корреляции по топовым платформам

# %%
rows = len(top_platforms) // 2
cols = 2
fig, axes = plt.subplots(rows, cols, figsize=(10,10))
count = 0

for r in range(rows):
    for c in range(cols):
        curr_platform = top_platforms[count]
        df_prep = actual_period[(actual_period['platform'] == curr_platform) & (actual_period['user_score'] > 0)].copy()
        
        df_filtered = df_prep[['total_sales' ,'critic_score', 'user_score']]
        sns.set(font_scale=1.0)
        ax = sns.heatmap(df_filtered.corr()[['total_sales']].sort_values(by='total_sales', ascending=False), 
                         cmap="Greens", annot=True, annot_kws={'size':15}, ax=axes[r,c])
        ax.set_title(curr_platform, fontsize=20)
        ax.set_yticklabels(ax.get_yticklabels(), rotation=0)
        plt.tight_layout(pad=3)        
        count += 1

# %% [markdown]
# Данные по корреляции между выручкой и оценкой по платформам PS4, XOne, 3DS, WiiU более или менее совпадает с общими данными по датафрейму.
# Выделяются PS и PSV, по которым зависимость не такая большая.
# Кстати, есть платформы, где оценка критиков, согласно данных, сильнее "определяет" конечную выручку продукта, чем оценка пользователей. Это платформы DS, PS4 и Xone. В случае с DS полагаю, что дело в том, что приставка азиатская, большую популярность она имеет там, соответственно, далеко не большая часть игроков принимает участие в оценке игр на эту платформу.
# Про PS и PSV - платформы довольно новые, вполне вероятно, что пользователи пока не "освоились", поэтому большого количества отзывов, особенно качественных от них нет.
#
# Так же можно отметить что положительные отзывы критиков влияет на продажи, но ее вклад является существенным.
# Коэффициент корреляции продаж от отзывов критиков больше чем коэффициент корреляция продажи от отзывов пользователей,
# это означает, что критики больше влияют на количество продаж.

# %% [markdown]
# ##### Общее распределение игр по жанрам

# %%
ax = plt.gca()

pivot = actual_period.groupby('genre').agg({'name': 'count', 'total_sales': 'sum'}).sort_values(by='name', ascending=False)

plot1 = pivot['name']
plot1.plot(kind='bar', figsize=(15,5), ec='black', ax=ax, width=0.4, position=1)

plot2 = pivot['total_sales']
plot2.plot(kind='bar', figsize=(15,5), ec='black', ax=ax, width=0.4, color='#97F0AA', position=0)

ax.legend(['Количество продаж', 'Общая сумма продаж'])
plt.title("Распределение игр по жанрам")
plt.xlabel("sales_total")
plt.ylabel("Количество и сумма")
plt.show()

# %% [markdown]
# Из графика следует что больше выпускается игри по жанарам Action, Role-Playing и Adventure, но в то же время продажи двух последних не отличаются высокими показателями.
#
# По выручке от продаж можно отметить самые прибыльные жанры Action, Shooter, Sports.
#
# Стоит отметить жанр Shooter, новых игр выпускаются меньше: 187, но количество продавных копий больше: 232.98 млн.,
# следовательно выручка высше чем у других жанров.
#
# Жанры с минимальными и максимальными показателями:
# По количеству выпускаемых игр
# Action          769
# Puzzle           17
# По количеству проданных копий (млн. копий)
# Action          322.5
# Puzzle            3.17

# %% [markdown]
# ##### Популярные платформы (топ-5)

# %%
fig, axes = plt.subplots(1, 3, figsize=(25,6))

top_in_regions_plot('platform', 'na_sales', 0)
top_in_regions_plot('platform', 'eu_sales', 1)
top_in_regions_plot('platform', 'jp_sales', 2)

# %% [markdown]
# На основании полученных результатов можно сделать следующее заключение:
# В Северной Америке и Европе самыми популярными являются платформы: X360, PS2, Wii, PS3.
# Лидирует:
# в Северной Америке: X360 с показателем 602.47 и долей рынка 0.620195, это в два раза больше, чем в Европе;
# в Европе: PS2 с показателем 339.29 и долей рынка 0.270185.
#
# В Японии самыми популярными платформами являются DS, PS, PS2.
# Лидирует DS с показателем 175.57 и долей рынка 0.217796.
#
# Европейский и Азиатский сильно различаются по объему продаж и предпочтению платформ.
#
# Лидирует по всем показателем рынок Северной Америки, это самый большой рынок.

# %% [markdown]
# ##### Популярные жанры (топ-5)

# %%
fig, axes = plt.subplots(1, 3, figsize=(25,6))

top_in_regions_plot('genre', 'na_sales', 0)
top_in_regions_plot('genre', 'eu_sales', 1)
top_in_regions_plot('genre', 'jp_sales', 2)

# %% [markdown]
# В регионах Северной Америки и Европы популярные жанры одинаковые, тройка жанров: Action, Sports, Shooter полностью совпадают.
# В Японии самым популярным жанром является Role-Playing , порядок популярности отличается, а именно жанр Role Playing занимает первое место.
#
# Стоит отметить, что одинаковый интерес проявляется во всех регионах к жанрам **Action и Sports**, это интересный факт.

# %% [markdown]
# ##### Влияние рейтинга ESRB на продажи в отдельном регионе.

# %%
fig, axes = plt.subplots(1, 3, figsize=(25,6))

top_in_regions_plot('ESRB_description', 'na_sales', 0)
top_in_regions_plot('ESRB_description', 'eu_sales', 1)
top_in_regions_plot('ESRB_description', 'jp_sales', 2)

# %% [markdown]
# В Северной Америке и в Европе картина практически одинаковая.
# Большая часть выручки получено с игр с рейтингом "Для всех": (1292.99 и 710.25),
# поровну - с рейтингом "13-19 лет": (759.75 и 427.03)
# и "для лиц старше 17 лет": (748.48 и 427.03).
#
# В Японии есть отличие от европейского рынка.
# Первое место по выручке - "Для всех": 198.11;
# второе - игры для лиц от 13 до 19 лет: 151.40, относительная доля болше, чем в Северной Америке и Европе;
# третье - > 17 лет: 64.24.
#
# В заключении к выводу:
# **Прослеживается факт неизвестного рейтинга, который во всех регионах замимает доминирующее положение.**
# **А в Японии значительно лидирует.**
# Считаю что этому факту нужно уделить особое внимание.
# К примеру постораться добыть отсутствующие данный, так как их доля очень велика.

# %% [markdown]
# ##### Гипотезы
#
# **Средние пользовательские рейтинги платформ Xbox One и PC отличаются между собой.**
#
# **Средние пользовательские рейтинги жанров Action и Sports отличаются между собой.**

# %% [markdown]
# Сегмент который предполагает рост - это те платформы которые их жизненный цикл больше 3 года но меньше 8 лет.
# Следует обратить внимание на отзывы критиков, поскольку их рейтинг косвенно влияет на продажи.
#
# Так же нужно учитывать особенности регионов по платформам и жанрам для того чтобы выстроить рекламную компанию.
